# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Plotting Footballer Data with Pandas & Matplotlb
#
##########################################################################################

# %%
import pylab as plt
# %matplotlib widget

# %% [markdown]
# # Pandas and DataFrames

# %% [markdown]
# # Python used in this exercise
# - Read CSV data into a data frame
# - Dataframe slicing
# - dataframe EDA (plots & summaries)
#
# Pandas Reference:  https://pandas.pydata.org/
#
# You are strongly encouraged to read sections of the following tutorials based on your own background
# https://pandas.pydata.org/docs/getting_started/index.html

# %%
# Goal: Analyze Players' info in subsets based on nationality
#  
#
# General info & data here:
#   https://www.kaggle.com/datasets/maso0dahmed/football-players-data
#
# I unzipped mine put it in the data folder
data = '../data/fifa_players.csv'

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\chl_b\\BIOS6644_Spring_2024_OLD\\Modules\\students\\Module_1\\notebooks'

# %%
data = 'C:/Users/chl_b/BIOS6644_Spring_2024_OLD/Modules/students/Module_1/data/fifa_players.csv'

# %%
df = pd.read_csv(data)
df
# Out:
#                  name                         full_name birth_date  age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 2            P. Pogba                        Paul Pogba  3/15/1993   25
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ...               ...                               ...        ...  ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# ...

# %%
# See all columns
print(f"Column Names:  {df.columns}")
# Out:
# Column Names:  Index(['name', 'full_name', 'birth_date', 'age', 'height_cm', 'weight_kgs',
#        'positions', 'nationality', 'overall_rating', 'potential', 'value_euro',
#        'wage_euro', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'body_type',
#        'release_clause_euro', 'national_team', 'national_rating',
#        'national_team_position', 'national_jersey_number', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %%
# Get  summaries of numerical fields
df.describe()
# Out:
#                 age     height_cm    weight_kgs  overall_rating     potential  \
# count  17954.000000  17954.000000  17954.000000    17954.000000  17954.000000
# mean      25.565445    174.946921     75.301047       66.240169     71.430935
# std        4.705708     14.029449      7.083684        6.963730      6.131339
# min       17.000000    152.400000     49.900000       47.000000     48.000000
# 25%       22.000000    154.940000     69.900000       62.000000     67.000000
# 50%       25.000000    175.260000     74.800000       66.000000     71.000000
# 75%       29.000000    185.420000     79.800000       71.000000     75.000000
# max       46.000000    205.740000    110.200000       94.000000     95.000000
#
#          value_euro      wage_euro  international_reputation(1-5)  \
# count  1.769900e+04   17708.000000                   17954.000000
# mean   2.479280e+06    9902.134628                       1.111674
# std    5.687014e+06   21995.593750                       0.392168
# ...

# %%
import numpy as np

# %%
# loc is "label based"  iloc is "location based"

dfi = df.copy()
dfi.index = pd.Index(np.array(dfi['age']))  #np.array strips of pandas-specific stuff like the column name
dfi
# Out:
#               name                         full_name birth_date  age  \
# 31        L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 27      C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 25        P. Pogba                        Paul Pogba  3/15/1993   25
# 27      L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 27    K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ..             ...                               ...        ...  ...
# 25     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 23       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 22      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 21      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 19  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#     height_cm  weight_kgs  positions   nationality  overall_rating  potential  \
# ...

# %%
dfi.iloc[42]
# Out:
# name                                   D. Sánchez
# full_name                        Davinson Sánchez
# birth_date                              6/12/1996
# age                                            22
# height_cm                                  187.96
# weight_kgs                                   78.9
# positions                                      CB
# nationality                              Colombia
# overall_rating                                 84
# potential                                      88
# value_euro                             34000000.0
# wage_euro                                105000.0
# preferred_foot                              Right
# international_reputation(1-5)                   2
# weak_foot(1-5)                                  3
# skill_moves(1-5)                                2
# body_type                                    Lean
# release_clause_euro                    65500000.0
# national_team                            Colombia
# ...

# %%
dfi.loc[42]
# Out:
#             name                           full_name birth_date  age  \
# 42  H. Sulaimani  Hussein Omar Abdul Ghani Sulaimani  1/21/1977   42
# 42      B. Nivet                      Benjamin Nivet   1/2/1977   42
#
#     height_cm  weight_kgs positions   nationality  overall_rating  potential  \
# 42     172.72        69.9        LB  Saudi Arabia              64         64
# 42     152.40        74.8    CAM,CM        France              69         69
#
#     ...  long_shots  aggression interceptions  positioning  vision  penalties  \
# 42  ...          63          92            65           64      69         60
# 42  ...          69          58            54           65      84         76
#
#    composure  marking standing_tackle  sliding_tackle
# 42        67       62              66              63
# 42        82       58              48              38
#
# [2 rows x 51 columns]

# %%
dfi.boxplot(column='wage_euro', by='age')
# Out:
# <Axes: title={'center': 'wage_euro'}, xlabel='age'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#import pylab as plt
plt.figure()
plt.plot(df.age, df.wage_euro)
#what is wrong with this initial plot? it connects dots by default so next asks for dots and not lines in red
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import pylab as plt

# %%
plt.figure()
plt.plot(df.age, df.wage_euro, 'r.', markersize=1, alpha=0.2)
plt.title('Footballer Wage by Age')
plt.xlabel('Age (years)')
plt.ylabel(r'Wage (Euros)')
# Out:
# Text(0, 0.5, 'Wage (Euros)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
