# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Wrangle CDC "Rare Diseases" data
#
##########################################################################################

# %%
##################################################################################################################
#
# YouDo:
#    1) Make a copy of this notebook with your name as a prefix:  
#       YourName_BIOS6644_XML_RareDiseases.ipynb
#    2) Do all work in this new notebook.
#    3) Submit completed work via GitHub
#
##################################################################################################################

# %% [markdown]
# # Setup Local Environment
# - Ensure you have pandas and xml2dict installed (via pip, conda, etc.)
# - Make a folder in the same directory as this notebook to hold the data.  Mine is ./Data

# %%
# set up local file tree
#!mkdir Data

# %% [markdown]
# ## Get Data data.gov
#
# Data available at https://data.cdc.gov/api/views/45b4-9j7u/rows.xml

# %%
# Download with:
# Info: 
#     https://data.cdc.gov/NNDSS/NNDSS-Table-I-infrequently-reported-notifiable-dis/45b4-9j7u
#
# Also available here: https://data.cdc.gov/api/odata/v4/45b4-9j7u

# The following lines are prefixed with a "!" which tells jupyter that these are shell 
# commands and not meant for python.
# Wget is a command line application that fetches webpages and files
# mv just moves the downloaded file to the Data folder
# 
# You can do this part manually if you prefer

! wget https://data.cdc.gov/api/views/45b4-9j7u/rows.xml
! mv rows.xml ./Data/
# Out:
# Will not apply HSTS. The HSTS database must be a regular and non-world-writable file.
# ERROR: could not open HSTS store at '/home/james/.wget-hsts'. HSTS will be disabled.
# --2024-03-24 12:55:27--  https://data.cdc.gov/api/views/45b4-9j7u/rows.xml
# Resolving data.cdc.gov (data.cdc.gov)... 52.206.140.205, 52.206.68.26, 52.206.140.199
# Connecting to data.cdc.gov (data.cdc.gov)|52.206.140.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/xml]
# Saving to: ‘rows.xml’
#
# rows.xml                [     <=>            ]   2.26M  2.38MB/s    in 0.9s
#
# 2024-03-24 12:55:29 (2.38 MB/s) - ‘rows.xml’ saved [2373297]

# %% [markdown]
# XML is basically a generaliztion of HTML, which describes most web pages
#
# Thus, web browsers can display XML in a relatively easy-to-read way.
#
# Open rows.xml with your browser: [open the file](./Data/rows.xml)
#
# XML has all kinds of "features" which make it ugly and complicated and which have never been useful to me.   You can use a library called [ElementTree] if you want to get into those nuances, but it's not very fun.
#
# I use a library called xmltodict which converts the xml data into native-to-python dictionaries.

# %% [markdown]
# ## Review:  Python Dictionaries

# %%
# empty dictionary

d = dict()
print(d)
# Out:
# {}

# %%
{'firstname':'James', 'surname':'King'}
# Out:
# {'firstname': 'James', 'surname': 'King'}

# %%
# Dictionaries make 1-to-1 maps from "keys" to "values"

# keys can be anything that's "hashable" (strings, numbers, dicts, ...)
# Values can be any Python type (including custom-made)

name={'firstname':'James', 'surname':'King'}

d['name'] = name
d['age'] = 'Younger than Greg'
d['Favorite number'] = 3
print(d)
# Out:
# {'name': {'firstname': 'James', 'surname': 'King'}, 'age': 'Younger than Greg', 'Favorite number': 3}

# %%
# handy dict methods

print(f'The keys are: {d.keys()}')
print(f'The values are: {d.values()}')
# Out:
# The keys are: dict_keys(['name', 'age', 'Favorite number'])
# The values are: dict_values([{'firstname': 'James', 'surname': 'King'}, 'Younger than Greg', 3])

# %%
# XML stores data in a similar, but much more difficult-to-read way:
X="""
<Favorite_number>3</Favorite_number>
<age>Younger than Greg</age>
<name>
  <firstname>James</firstname>
  <surname>King</surname>
</name>
"""

# %%
# xmltodict reads in XML files and converts them to dicts, which are easier in Python

# %%
# Read in the data file with xmltodict

# %%
fname = './Data/rows.xml'
with open(fname, 'rb') as thefile:
    dd = xmltodict.parse(thefile)

# %%
# Notice there are two levels with the tag "row"  This sort of thing is common in 
# XML and really annoying.  
# This sort of display makes it stand out, though.
# We'll need to remember that for later.

# %%
# This data seems to be organized by an attribute called "row", each of 
#  which has several children (probably the columns)

print(dd.keys())
# Out:
# dict_keys(['response'])

# %%
print(dd['response'].keys())
# Out:
# dict_keys(['row'])

# %%
print(dd['response']['row'].keys())
# Out:
# dict_keys(['row'])

# %%
print(dd['response']['row']['row'].keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-451eb7b64945> in <module>
# ----> 1 print(dd['response']['row']['row'].keys())
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
print(dd['response']['row']['row'])
# Out:
# [{'@_id': 'row-skhd-7gcj-bknc', '@_uuid': '00000000-0000-0000-8068-71B30911A10A', '@_position': '0', '@_address': 'https://data.cdc.gov/resource/_45b4-9j7u/row-skhd-7gcj-bknc', 'disease': 'Anthrax', 'mmwr_year': '2017', 'mmwr_week': '1', 'current_week_flag': '-', 'cum_2017_flag': '-', '_5_year_weekly_average_flag': '-', 'total_cases_reported_2016_flag': '-', 'total_cases_reported_2015_flag': '-', 'total_cases_reported_2014_flag': '-', 'total_cases_reported_2013_flag': '-', 'total_cases_reported_2012_flag': '-'}, {'@_id': 'row-vyec_dmte-gwmz', '@_uuid': '00000000-0000-0000-F7D9-05250D543B3D', '@_position': '0', '@_address': 'https://data.cdc.gov/resource/_45b4-9j7u/row-vyec_dmte-gwmz', 'disease': 'Arboviral diseases¶,** Chikungunya virus disease', 'mmwr_year': '2017', 'mmwr_week': '1', 'current_week_flag': '-', 'cum_2017_flag': '-', '_5_year_weekly_average': '6', 'total_cases_reported_2016': '167', 'total_cases_reported_2015': '896', 'total_cases_reported_2014_flag': 'NN', 'total_cases_reported_2013_flag': 'NN', 'total_cases_reported_2012_flag': 'NN'}, {'@_id': 'row-hdxc_43ap~n6yz', '@_uuid': '00000000-0000-0000-0F1A-DE0D93986652', '@_position': '0', '@_address': 'https://data.cdc.gov/resource/_45b4-9j7u/row-hdxc_43ap~n6yz', 'disease': 'Arboviral diseases¶,** Eastern equine encephalitis virus disease', 'mmwr_year': '2017', 'mmwr_week': '1', 'current_week_flag': '-', 'cum_2017_flag': '-', '_5_year_weekly_average': '0', 'total_cases_reported_2016': '6', 'total_cases_reported_2015': '6', 'total_cases_reported_2014': '8', 'total_cases_reported_2013': '8', 'total_cases_reported_2012': '15'}, {'@_id': 'row-t9wt_thhz_94py', '@_uuid': '00000000-0000-0000-E750-7726E41C0121', '@_position': '0', '@_address': 'https://data.cdc.gov/resource/_45b4-9j7u/row-t9wt_thhz_94py', 'disease': 'Arboviral diseases¶,** Jamestown Canyon virus disease', 'mmwr_year': '2017', 'mmwr_week': '1', 'current_week_flag': '-', 'cum_2017_flag': '-', '_5_year_weekly_average_flag': '-', 'total_cases_reported_2016': '4', 'total_cases_reported_2015': '11', 'total_cases_reported_2014': '11', 'total_cases_reported_2013': '22', 'total_cases_reported_2012': '2'}, {'@_id': 'row-bkgt~e7aa.8vhi', '@_uuid': '00000000-0000-0000-84F0-A42719F7BCF1', '@_position': '0', '@_address': 'https://data.cdc.gov/resource/_45b4-9j7u/row-bkgt~e7aa.8vhi', 'disease': 'Arboviral diseases¶,** La Crosse virus disease', 'mmwr_year': '2017', 'mmwr_week': '1', 'current_week_flag': '-', 'cum_2017_flag': '-', '_5_year_weekly_average_flag': '-', 'total_cases_reported_2016': '34', 'total_cases_reported_2015': '55', 'total_cases_reported_2014': '80', 'total_cases_reported_2013': '85', 'total_cases_reported_2012': '78'}, {'@_id': 'row-sztx_txbm~vsg3', '@_uuid': '00000000-0000-0000-0260-B2410C02B184', '@_position': '0', '@_address': 'https://data.cdc.gov/resource/_45b4-9j7u/row-sztx_txbm~vsg3', 'disease': 'Arboviral diseases¶,** Powassan virus disease', 'mmwr_year': '2017', 'mmwr_week': '1', 'current_week_flag': '-', 'cum_2017_flag': '-', '_5_year_weekly_average_flag': '-', 'total_cases_reported_2016': '13', 'total_cases_reported_2015': '7', 'total_cases_reported_2014': '8', 'total_cases_reported_2013': '12', 'total_cases_reported_2012': '7'}, {'@_id': 'row-6khc.wagz.utpy', '@_uuid': '00000000-0000-0000-7A43-62A153C6B72D', '@_position': '0', '@_address': 'https://data.cdc.gov/resource/_45b4-9j7u/row-6khc.wagz.utpy', 'disease': 'Arboviral diseases¶,** St. Louis encephalitis virus disease', 'mmwr_year': '2017', 'mmwr_week': '1', 'current_week_flag': '-', 'cum_2017_flag': '-', '_5_year_weekly_average_flag': '-', 'total_cases_reported_2016': '9', 'total_cases_reported_2015': '23', 'total_cases_reported_2014': '10', 'total_cases_reported_2013': '1', 'total_cases_reported_2012': '3'}, {'@_id': 'row-m6tc.gzn9-t86m', '@_uuid': '00000000-0000-0000-6D21-E71EC58407C8', '@_position': '0', '@_address': 'https://data.cdc.gov/resource/_45b4-9j7u/row-m6tc.gzn9-t86m', 'disease': 'Arboviral diseases¶,** Western equine enceph ...

# %%
# Ok--here's where the data starts

# %%
datlist = dd['response']['row']['row']

# %%
len(datlist), type(datlist[0]), datlist[0].keys()
# Out:
# (3329,
#  dict,
#  dict_keys(['@_id', '@_uuid', '@_position', '@_address', 'disease', 'mmwr_year', 'mmwr_week', 'current_week_flag', 'cum_2017_flag', '_5_year_weekly_average_flag', 'total_cases_reported_2016_flag', 'total_cases_reported_2015_flag', 'total_cases_reported_2014_flag', 'total_cases_reported_2013_flag', 'total_cases_reported_2012_flag']))

# %%
# One of the keys is "disease" which might contain the name of the disease
datlist[0]['disease']
# Out:
# 'Anthrax'

# %%
##################################################################################################################
#
# YouDo:
#
# 1) Loop through the list of nodes and extract the text attribute of each node into a list called diz
#    
#   Stretch goal:  do this with a list comprehension
#
# 2) Make a second list called udiz containing only the unique members of this data set 

#######################################  BEGIN STUDENT CODE  #####################################################

# 1)
diz = [xx['disease'] for xx in datlist]
#print(diz)

#2)

#  Enter the Set Comprehension.  dun. Dun. DUUUUUUN.
udiz = {xx['disease'] for xx in datlist}
udiz
#######################################   END STUDENT CODE   #####################################################
# Out:
# {'Anthrax',
#  'Arboviral diseases¶,** Chikungunya virus disease',
#  'Arboviral diseases¶,** Chikungunya virus††',
#  'Arboviral diseases¶,** Eastern equine encephalitis virus',
#  'Arboviral diseases¶,** Eastern equine encephalitis virus disease',
#  'Arboviral diseases¶,** Jamestown Canyon virus disease',
#  'Arboviral diseases¶,** Jamestown Canyon virus§§',
#  'Arboviral diseases¶,** La Crosse virus disease',
#  'Arboviral diseases¶,** La Crosse virus§§',
#  'Arboviral diseases¶,** Powassan virus',
#  'Arboviral diseases¶,** Powassan virus disease',
#  'Arboviral diseases¶,** St. Louis encephalitis virus',
#  'Arboviral diseases¶,** St. Louis encephalitis virus disease',
#  'Arboviral diseases¶,** Western equine encephalitis virus',
#  'Arboviral diseases¶,** Western equine encephalitis virus disease',
#  'Botulism, foodborne',
#  'Botulism, infant',
#  'Botulism, other (wound and unspecified)',
#  'Botulism, total',
#  'Brucellosis',
#  'Chancroid',
#  'Cholera',
#  'Cyclosporiasis**',
#  'Diphtheria',
#  'Haemophilus influenzae invasive disease (age <5 yrs)¶¶, non typeable serotype',
#  'Haemophilus influenzae invasive disease (age <5 yrs)¶¶, other serotype',
#  'Haemophilus influenzae invasive disease (age <5 yrs)¶¶, serotype b',
#  'Haemophilus influenzae invasive disease (age <5 yrs)¶¶, unknown serotype',
#  'Haemophilus influenzae invasive disease (age <5 yrs)††, non-b serotype',
#  'Haemophilus influenzae invasive disease (age <5 yrs)††, nontypeable',
#  'Haemophilus influenzae invasive disease (age <5 yrs)††, serotype b',
#  'Haemophilus influenzae invasive disease (age <5 yrs)††, unknown serotype',
#  "Hansen's disease**",
#  'Hantavirus infections**, Hantavirus Pulmonary Syndrome (HPS)',
#  'Hantavirus infections**, Hantavirus infection (non-HPS)††',
#  'Hantavirus**, Hantavirus Pulmonary Syndrome (HPS)',
#  'Hantavirus**, Hantavirus infection, non-HPS',
#  'Hemolytic uremic syndrome, postdiarrheal**',
#  'Hepatitis B, perinatal virus infection§§',
#  'Hepatitis B, virus infection perinatal',
#  'Influenza-associated pediatric mortality**,***',
#  'Influenza-associated pediatric mortality**,¶¶',
#  'Leptospirosis**',
#  'Listeriosis',
#  'Measles***',
#  'Measles†††',
#  'Meningococcal disease (Neisseria meningitidis)†††, other serogroup',
#  'Meningococcal disease (Neisseria meningitidis)†††, serogroup B',
#  'Meningococcal disease (Neisseria meningitidis)†††, serogroups ACWY',
#  'Meningococcal disease(Neisseria meningitidis)†††, unknown serogroup',
#  'Meningococcal disease, invasive§§§, other serogroup',
#  'Meningococcal disease, invasive§§§, serogroup ACWY',
#  'Meningococcal disease, invasive§§§, serogroup B',
#  'Meningococcal disease, invasive§§§, unknown serogroup',
#  'Novel influenza A virus infections§§§',
#  'Novel influenza A virus infections¶¶¶',
#  'Plague',
#  'Polio virus Infection, nonparalytic**',
#  'Poliomyelitis, paralytic',
#  'Psittacosis**',
#  'Q fever, acute**',
#  'Q fever, chronic**',
#  'Q fever, total**',
#  'Rabies, human',
#  'SARS-CoV',
#  'Smallpox',
#  'Streptococcal toxic-shock syndrome**',
#  'Syphilis, congenital****',
#  'Syphilis, congenital¶¶¶',
#  'Toxic-shock syndrome (other than staphylococcal)**',
#  'Toxic-shock syndrome (staphylococcal)**',
#  'Trichinellosis**',
#  'Tularemia',
#  'Typhoid fever',
#  'Typhoid fever (caused by Salmonella typhi)',
#  'Vancomycin-intermediate Staphylococcus aureus**',
#  'Vancomycin-resistant Staphylococcus aureus**',
#  'Viral hemorrhagic fever****, Crimean-Congo hemorrhagic fever',
#  'Viral hemorrhagic fever****, Ebola hemorrhagic fever',
#  'Viral hemorrhagic fever****, Guanarito hemorrhagic fever',
#  'Viral hemorrhagic fever****, Junin hemorrhagic fever',
#  'Viral hemorrhagic fever****, Lassa fever',
#  'Viral hemorrhagic fever****, Lujo virus',
#  'Viral hemorrhagic fever****, Machupo hemorrhagic fever',
#  'Viral hemorrhagic fever****, Marburg fever',
#  'Viral hemorrhagic fever****, Sabia-associated hemorrhagic fever',
#  'Viral hemorrhagic fever††††, Crimean-Congo hemorrhagic fever',
#  'Viral hemorrhagic fever††††, Ebola hemorrhagic fever',
#  'Viral hemorrhagic fever††††, Guanarito hemorrhagic fever',
#  'Viral hemorrhagic fever††††, Junin hemorrhagic fever',
#  'Viral hemorrhagic fever††††, Lassa fever',
#  'Viral hemorrhagic fever††††, Lujo virus',
#  'Viral hemorrhagic fever††††, Machupo hemorrhagic fever',
#  'Viral hemorrhagic fever††††, Marburg fever',
#  'Viral hemorrhagic fever††††, Sabia-associated hemorrhagic fever',
#  'Yellow fever',
#  'Zika virus disease, non-congenital††††',
#  'Zika virus††,§§§§, Zika virus congenital infection',
#  'Zika virus††,§§§§, Zika virus disease, non-congenital infection'}

# %%
# A list of shallow dicts can be imported directly into pandas

df = pd.DataFrame(datlist)
df
# Out:
#                     @_id                                @_uuid @_position  \
# 0     row-skhd-7gcj-bknc  00000000-0000-0000-8068-71B30911A10A          0
# 1     row-vyec_dmte-gwmz  00000000-0000-0000-F7D9-05250D543B3D          0
# 2     row-hdxc_43ap~n6yz  00000000-0000-0000-0F1A-DE0D93986652          0
# 3     row-t9wt_thhz_94py  00000000-0000-0000-E750-7726E41C0121          0
# 4     row-bkgt~e7aa.8vhi  00000000-0000-0000-84F0-A42719F7BCF1          0
# ...                  ...                                   ...        ...
# 3324  row-wcgm~868t.94ae  00000000-0000-0000-A93D-857517E6E098          0
# 3325  row-k8nd-iu8c_pd4z  00000000-0000-0000-0FAD-23CDA12DFDA2          0
# 3326  row-er6u~tvsv-s3mi  00000000-0000-0000-7224-762A5A5F1A4F          0
# 3327  row-3k5p.gsvb~vap3  00000000-0000-0000-F4A7-C02DDA0683C6          0
# 3328  row-re74-d342_f5qk  00000000-0000-0000-E890-4E8D38E04EE6          0
#
#                                               @_address  \
# 0     https://data.cdc.gov/resource/_45b4-9j7u/row-s...
# 1     https://data.cdc.gov/resource/_45b4-9j7u/row-v...
# 2     https://data.cdc.gov/resource/_45b4-9j7u/row-h...
# 3     https://data.cdc.gov/resource/_45b4-9j7u/row-t...
# 4     https://data.cdc.gov/resource/_45b4-9j7u/row-b...
# ...                                                 ...
# 3324  https://data.cdc.gov/resource/_45b4-9j7u/row-w...
# 3325  https://data.cdc.gov/resource/_45b4-9j7u/row-k...
# 3326  https://data.cdc.gov/resource/_45b4-9j7u/row-e...
# 3327  https://data.cdc.gov/resource/_45b4-9j7u/row-3...
# 3328  https://data.cdc.gov/resource/_45b4-9j7u/row-r...
#
#                                                 disease mmwr_year mmwr_week  \
# 0                                               Anthrax      2017         1
# 1      Arboviral diseases¶,** Chikungunya virus disease      2017         1
# 2     Arboviral diseases¶,** Eastern equine encephal...      2017         1
# 3     Arboviral diseases¶,** Jamestown Canyon virus ...      2017         1
# 4        Arboviral diseases¶,** La Crosse virus disease      2017         1
# ...                                                 ...       ...       ...
# 3324                                   Trichinellosis**      2017        52
# 3325  Hantavirus**, Hantavirus Pulmonary Syndrome (HPS)      2017        52
# 3326                           Poliomyelitis, paralytic      2017        52
# 3327  Haemophilus influenzae invasive disease (age <...      2017        51
# 3328            Botulism, other (wound and unspecified)      2017        52
#
#      current_week_flag cum_2017_flag _5_year_weekly_average_flag  ...  \
# 0                    -             -                           -  ...
# 1                    -             -                         NaN  ...
# 2                    -             -                         NaN  ...
# 3                    -             -                           -  ...
# 4                    -             -                           -  ...
# ...                ...           ...                         ...  ...
# 3324                 -           NaN                         NaN  ...
# 3325                 -           NaN                         NaN  ...
# 3326                 -             -                           -  ...
# 3327                 -           NaN                         NaN  ...
# 3328                 -           NaN                         NaN  ...
#
#      total_cases_reported_2012_flag _5_year_weekly_average  \
# 0                                 -                    NaN
# 1                                NN                      6
# 2                               NaN                      0
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 3324                            NaN                      1
# 3325                            NaN                      0
# 3326                              -                    NaN
# 3327                            NaN                      1
# 3328                            NaN                      0
#
#      total_cases_reported_2016 total_cases_reported_2015  \
# 0                          NaN                       NaN
# 1                          167                       896
# 2                            6                         6
# 3                            4                        11
# 4                           34                        55
# ...                        ...                       ...
# 3324                        26                        14
# 3325                        31                        21
# 3326                       NaN                       NaN
# 3327                        30                        29
# 3328                        26                        20
#
#      total_cases_reported_2014 total_cases_reported_2013  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                            8                         8
# 3                           11                        22
# 4                           80                        85
# ...                        ...                       ...
# 3324                        14                        22
# 3325                        32                        21
# 3326                       NaN                         1
# 3327                        40                        31
# 3328                        19                        12
#
#      total_cases_reported_2012 current_week cum_2017  \
# 0                          NaN          NaN      NaN
# 1                          NaN          NaN      NaN
# 2                           15          NaN      NaN
# 3                            2          NaN      NaN
# 4                           78          NaN      NaN
# ...                        ...          ...      ...
# 3324                        18          NaN       14
# 3325                        30          NaN        8
# 3326                       NaN          NaN      NaN
# 3327                        30          NaN       21
# 3328                        18          NaN        3
#
#      states_reporting_cases_during_current_week_no
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3324                                           NaN
# 3325                                           NaN
# 3326                                           NaN
# 3327                                           NaN
# 3328                                           NaN
#
# [3329 rows x 24 columns]

# %%
##################################################################################################################
#
# YouDo:  try reading the reports dictionary into a data frame, try importing
# reports into a data frame and sorting it.

#######################################  BEGIN STUDENT CODE  #####################################################

dcounts = df[['disease', 'total_cases_reported_2016']].copy()
dcounts.dropna(inplace=True)
dcounts.drop_duplicates(inplace=True)
dcounts.sort_values('total_cases_reported_2016', inplace=True)
#dcounts.iloc[0:5]
dcounts
#######################################   END STUDENT CODE   #####################################################
# Out:
#                                                disease  \
# 52        Vancomycin-resistant Staphylococcus aureus**
# 13                                           Chancroid
# 372  Meningococcal disease (Neisseria meningitidis)...
# 370    Vancomycin-intermediate Staphylococcus aureus**
# 403    Vancomycin-intermediate Staphylococcus aureus**
# ..                                                 ...
# 123  Meningococcal disease (Neisseria meningitidis)...
# 85     Vancomycin-intermediate Staphylococcus aureus**
# 51     Vancomycin-intermediate Staphylococcus aureus**
# 132  Meningococcal disease (Neisseria meningitidis)...
# 211  Meningococcal disease (Neisseria meningitidis)...
#
#     total_cases_reported_2016
# 52                          1
# 13                         10
# 372                       100
# 370                       100
# 403                       101
# ..                        ...
# 123                        97
# 85                         97
# 51                         98
# 132                        98
# 211                        99
#
# [515 rows x 2 columns]

# %%
dcounts.index
# Out:
# Index(['Anthrax', 'Hansen's disease**', 'Leptospirosis**', 'Listeriosis',
#        'Plague', 'Poliomyelitis, paralytic',
#        'Polio virus Infection, nonparalytic**', 'Psittacosis**',
#        'Q fever, total**', 'Q fever, acute**', 'Q fever, chronic**',
#        'Rabies, human', 'SARS-CoV', 'Smallpox',
#        'Streptococcal toxic-shock syndrome**', 'Trichinellosis**',
#        'Vancomycin-intermediate Staphylococcus aureus**',
#        'Vancomycin-resistant Staphylococcus aureus**', 'Yellow fever',
#        'Hemolytic uremic syndrome, postdiarrheal**', 'Tularemia',
#        'Botulism, total', 'Botulism, foodborne', 'Botulism, infant',
#        'Botulism, other (wound and unspecified)', 'Brucellosis', 'Chancroid',
#        'Cholera', 'Cyclosporiasis**', 'Diphtheria',
#        'Haemophilus influenzae invasive disease (age <5 yrs)††, unknown serotype',
#        'Arboviral diseases¶,** Powassan virus disease',
#        'Typhoid fever (caused by Salmonella typhi)',
#        'Arboviral diseases¶,** La Crosse virus disease',
#        'Arboviral diseases¶,** Jamestown Canyon virus disease',
#        'Viral hemorrhagic fever****, Crimean-Congo hemorrhagic fever',
#        'Viral hemorrhagic fever****, Ebola hemorrhagic fever',
#        'Viral hemorrhagic fever****, Guanarito hemorrhagic fever',
#        'Viral hemorrhagic fever****, Junin hemorrhagic fever',
#        'Viral hemorrhagic fever****, Lassa fever',
#        'Viral hemorrhagic fever****, Lujo virus',
#        'Viral hemorrhagic fever****, Machupo hemorrhagic fever',
#        'Hantavirus**, Hantavirus infection, non-HPS',
#        'Viral hemorrhagic fever****, Sabia-associated hemorrhagic fever',
#        'Arboviral diseases¶,** Eastern equine encephalitis virus disease',
#        'Zika virus disease, non-congenital††††',
#        'Arboviral diseases¶,** Chikungunya virus disease',
#        'Viral hemorrhagic fever****, Marburg fever',
#        'Toxic-shock syndrome (other than staphylococcal)**',
#        'Meningococcal disease (Neisseria meningitidis)†††, serogroups ACWY',
#        'Hantavirus**, Hantavirus Pulmonary Syndrome (HPS)',
#        'Haemophilus influenzae invasive disease (age <5 yrs)††, non-b serotype',
#        'Hepatitis B, perinatal virus infection§§',
#        'Influenza-associated pediatric mortality**,¶¶',
#        'Haemophilus influenzae invasive disease (age <5 yrs)††, serotype b',
#        'Measles***',
#        'Haemophilus influenzae invasive disease (age <5 yrs)††, nontypeable',
#        'Meningococcal disease (Neisseria meningitidis)†††, serogroup B',
#        'Meningococcal disease (Neisseria meningitidis)†††, other serogroup',
#        'Meningococcal disease(Neisseria meningitidis)†††, unknown serogroup',
#        'Novel influenza A virus infections§§§',
#        'Arboviral diseases¶,** Western equine encephalitis virus disease',
#        'Arboviral diseases¶,** St. Louis encephalitis virus disease',
#        'Syphilis, congenital¶¶¶',
#        'Meningococcal disease, invasive§§§, unknown serogroup',
#        'Viral hemorrhagic fever††††, Junin hemorrhagic fever',
#        'Arboviral diseases¶,** Chikungunya virus††',
#        'Arboviral diseases¶,** St. Louis encephalitis virus',
#        'Meningococcal disease, invasive§§§, other serogroup',
#        'Viral hemorrhagic fever††††, Sabia-associated hemorrhagic fever',
#        'Haemophilus influenzae invasive disease (age <5 yrs)¶¶, unknown serotype',
#        'Hepatitis B, virus infection perinatal',
#        'Viral hemorrhagic fever††††, Guanarito hemorrhagic fever',
#        'Measles†††', 'Novel influenza A virus infections¶¶¶',
#        'Toxic-shock syndrome (staphylococcal)**',
#        'Viral hemorrhagic fever††††, Lujo virus',
#        'Hantavirus infections**, Hantavirus Pulmonary Syndrome (HPS)',
#        'Zika virus††,§§§§, Zika virus congenital infection',
#        'Haemophilus influenzae invasive disease (age <5 yrs)¶¶, serotype b',
#        'Viral hemorrhagic fever††††, Ebola hemorrhagic fever',
#        'Zika virus††,§§§§, Zika virus disease, non-congenital infection',
#        'Viral hemorrhagic fever††††, Crimean-Congo hemorrhagic fever',
#        'Viral hemorrhagic fever††††, Lassa fever',
#        'Haemophilus influenzae invasive disease (age <5 yrs)¶¶, other serotype',
#        'Syphilis, congenital****', 'Arboviral diseases¶,** La Crosse virus§§',
#        'Meningococcal disease, invasive§§§, serogroup ACWY',
#        'Arboviral diseases¶,** Eastern equine encephalitis virus',
#        'Typhoid fever',
#        'Viral hemorrhagic fever††††, Machupo hemorrhagic fever',
#        'Arboviral diseases¶,** Powassan virus',
#        'Hantavirus infections**, Hantavirus infection (non-HPS)††',
#        'Influenza-associated pediatric mortality**,***',
#        'Arboviral diseases¶,** Jamestown Canyon virus§§',
#        'Meningococcal disease, invasive§§§, serogroup B',
#        'Haemophilus influenzae invasive disease (age <5 yrs)¶¶, non typeable serotype',
#        'Arboviral diseases¶,** Western equine encephalitis virus',
#        'Viral hemorrhagic fever††††, Marburg fever'],
#       dtype='object', name='disease')

# %%
df.iloc[:5,:]
# Out:
#                  @_id                                @_uuid @_position  \
# 0  row-skhd-7gcj-bknc  00000000-0000-0000-8068-71B30911A10A          0
# 1  row-vyec_dmte-gwmz  00000000-0000-0000-F7D9-05250D543B3D          0
# 2  row-hdxc_43ap~n6yz  00000000-0000-0000-0F1A-DE0D93986652          0
# 3  row-t9wt_thhz_94py  00000000-0000-0000-E750-7726E41C0121          0
# 4  row-bkgt~e7aa.8vhi  00000000-0000-0000-84F0-A42719F7BCF1          0
#
#                                            @_address  \
# 0  https://data.cdc.gov/resource/_45b4-9j7u/row-s...
# 1  https://data.cdc.gov/resource/_45b4-9j7u/row-v...
# 2  https://data.cdc.gov/resource/_45b4-9j7u/row-h...
# 3  https://data.cdc.gov/resource/_45b4-9j7u/row-t...
# 4  https://data.cdc.gov/resource/_45b4-9j7u/row-b...
#
#                                              disease mmwr_year mmwr_week  \
# 0                                            Anthrax      2017         1
# 1   Arboviral diseases¶,** Chikungunya virus disease      2017         1
# 2  Arboviral diseases¶,** Eastern equine encephal...      2017         1
# 3  Arboviral diseases¶,** Jamestown Canyon virus ...      2017         1
# 4     Arboviral diseases¶,** La Crosse virus disease      2017         1
#
#   current_week_flag cum_2017_flag _5_year_weekly_average_flag  ...  \
# 0                 -             -                           -  ...
# 1                 -             -                         NaN  ...
# 2                 -             -                         NaN  ...
# 3                 -             -                           -  ...
# 4                 -             -                           -  ...
#
#   total_cases_reported_2012_flag _5_year_weekly_average  \
# 0                              -                    NaN
# 1                             NN                      6
# 2                            NaN                      0
# 3                            NaN                    NaN
# 4                            NaN                    NaN
#
#   total_cases_reported_2016 total_cases_reported_2015  \
# 0                       NaN                       NaN
# 1                       167                       896
# 2                         6                         6
# 3                         4                        11
# 4                        34                        55
#
#   total_cases_reported_2014 total_cases_reported_2013  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                         8                         8
# 3                        11                        22
# 4                        80                        85
#
#   total_cases_reported_2012 current_week cum_2017  \
# 0                       NaN          NaN      NaN
# 1                       NaN          NaN      NaN
# 2                        15          NaN      NaN
# 3                         2          NaN      NaN
# 4                        78          NaN      NaN
#
#   states_reporting_cases_during_current_week_no
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
# [5 rows x 24 columns]

# %%
##################################################################################################################
#
# YouDo: 
#  Make a visualization showing week vs cum_2017 for all of the top 5 diseases
#  Ensure it has appropriate labels, etc. for pulblication
#######################################  BEGIN STUDENT CODE  #####################################################

#######################################   END STUDENT CODE   #####################################################
