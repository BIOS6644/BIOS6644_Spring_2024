# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Wrangling Footballer Names Data
#
##########################################################################################

# %%
##################################################################################################################
#
# YouDo:
#    1) Make a copy of this notebook with your name as a suffix:  
#       BIOS6644_Fottballer_FirstLast.ipynb
#    2) Do all work in this new notebook.
#    3) Submit completed work via GitHub push
#
##################################################################################################################

# %% [markdown]
# # Python used in this exercise
# - File Input/Output
# - for loop
# - list
#     - list methods:
#         - join()
#     - list comprehension
# - string
#     - string methods
#         - split()
#         - strip()
#         - slice

# %%
# Python stuff used here:


the_things = [1, 2, 'A', "B", 9.4, set([1,2])]

# for loops repeat code once for each thing in the_things
for this_thing in the_things:
    print('The current thing is: ', this_thing)

# %%
# Strings can be "split" into a list, on a boundary marker which you provide
string2split = '''Hello.  My name is Inigo Montoya. You killed my brother.  Prepare to die'''
print(string2split)

# split on "." 
# Note that a list of strings is returned.
# and that the split boundary character is removed.
string2split.split(".")

# %%
# Mini wrangle goals:
#  1) remove stray space characters
#  2) Correct "brother" to be "father"
#  3) Write as 4 sentences, returning the "." characters

for chunk in string2split.split("."):
    print(chunk)
    chunk=chunk.strip()
    print(chunk) # strip removes whitespace from the ends

    chunk = chunk.replace('brother', 'father')
    print(chunk+'.')

# %%
for chunk in string2split.split("."):
    chunk=chunk.strip()

    chunk = chunk.replace('brother', 'father')
    print(chunk+'.')

# %%
#A different approach using a for-loop shortcut called
#    a List Comprehension - where list comprehention is expression for item in iterable if condition == 'True'
output = [xx.strip().replace("brother", "father") for xx in string2split.split(".")]
print(output)

print('.\n'.join(output))

# %%
# as a 1-liner
print('.\n'.join([xx.strip().replace("brother", "father") for xx in string2split.split(".")]))

# %% [markdown]
# # Wrangling Footballer Names

# %%
# Goal: extract footballer's names into format Last, First, other & discard
#  other data
#
# General info & data here:
#   https://www.kaggle.com/datasets/maso0dahmed/football-players-data
#
# I unzipped mine put it in the data folder
#data = '../data/fifa_players.csv'
dataq = 'D:/Working/BIOS6644/data/fifa_playersUTF8.csv'

# %%
#read data
# (g)i modified this by adding encoding='UTF8'
with open(dataq,'r', encoding='UTF8') as thefile:
    lines = thefile.readlines()

# %%
test_line = lines[33]
header = lines[0]
print(header, test_line)
# Out:
# ﻿name,full_name,birth_date,age,height_cm,weight_kgs,positions,nationality,overall_rating,potential,value_euro,wage_euro,preferred_foot,international_reputation(1-5),weak_foot(1-5),skill_moves(1-5),body_type,release_clause_euro,national_team,national_rating,national_team_position,national_jersey_number,crossing,finishing,heading_accuracy,short_passing,volleys,dribbling,curve,freekick_accuracy,long_passing,ball_control,acceleration,sprint_speed,agility,reactions,balance,shot_power,jumping,stamina,strength,long_shots,aggression,interceptions,positioning,vision,penalties,composure,marking,standing_tackle,sliding_tackle
#  Kepa,Kepa Arrizabalaga,10/3/1994,24,185.42,84.8,GK,Spain,84,90,31000000,92000,Right,1,4,1,Lean,63600000,Spain,85,SUB,13,25,11,17,32,18,10,25,19,36,16,34,33,41,79,39,25,71,37,51,14,18,21,15,55,24,63,19,18,16

# %%
# Notice that the player name is in the 2nd field (field 1)
# The string split(',') method divides a string into a list of strings, 
# breaking on commas. 
print(test_line.split(','))
# Out:
# ['Kepa', 'Kepa Arrizabalaga', '10/3/1994', '24', '185.42', '84.8', 'GK', 'Spain', '84', '90', '31000000', '92000', 'Right', '1', '4', '1', 'Lean', '63600000', 'Spain', '85', 'SUB', '13', '25', '11', '17', '32', '18', '10', '25', '19', '36', '16', '34', '33', '41', '79', '39', '25', '71', '37', '51', '14', '18', '21', '15', '55', '24', '63', '19', '18', '16\n']

# %%
test_line.split(',')[1]  # split and grab position-1 entry
# Out:
# 'Kepa Arrizabalaga'

# %%
# Split the name up into a list
test_line.split(',')[1].split(' ')
# Out:
# ['Kepa', 'Arrizabalaga']

# %%
# Save the names as split so we can re-arrange them
name_list = test_line.split(',')[1].split(' ')
print(name_list)
# Out:
# ['Kepa', 'Arrizabalaga']

# %%
# Re-arrange them
print(name_list[1], name_list[0])
# Out:
# Arrizabalaga Kepa

# %%
# Add a comma
print(name_list[1]+ ', ' +name_list[0])
# Out:
# Arrizabalaga, Kepa

# %%
for this_player in lines:
    name_list = this_player.split(',')[1].split(' ')
    print(name_list)
# Out:
# ['full_name']
# ['Lionel', 'AndrÃ©s', 'Messi', 'Cuccittini']
# ['Christian', '', 'Dannemann', 'Eriksen']
# ['Paul', 'Pogba']
# ['Lorenzo', 'Insigne']
# ['Kalidou', 'Koulibaly']
# ['Virgil', 'van', 'Dijk']
# ['Kylian', 'MbappÃ©']
# ['Sergio', 'Leonel', 'AgÃ¼ero', 'del', 'Castillo']
# ['Manuel', 'Neuer']
# ['Edinson', 'Roberto', 'Cavani', 'GÃ³mez']
# ['Sergio', 'Busquets', 'i', 'Burgos']
# ['Thibaut', 'Courtois']
# ['Marc-AndrÃ©', 'ter', 'Stegen']
# ['Antoine', 'Griezmann']
# ['Mohamed', '', 'Salah', 'Ghaly']
# ['Paulo', 'Bruno', 'Exequiel', 'Dybala']
# ['Milan', 'Å\xa0kriniar']
# ['Fernando', 'Luiz', 'Rosa']
# ['Gonzalo', 'Gerardo', 'HiguaÃ\xadn']
# ['Ivan', 'RakitiÄ‡']
# ['Jan', 'Vertonghen']
# ['Dries', 'Mertens']
# ['Marcelo', 'Vieira', 'da', 'Silva', 'JÃºnior']
# ['Toby', 'Alderweireld']
# ['Jordi', 'Alba', 'Ramos']
# ['Thiago', 'AlcÃ¢ntara', 'do', 'Nascimento']
# ['Ciro', 'Immobile']
# ['Keylor', 'Navas']
# ['Francisco', 'RomÃ¡n', 'AlarcÃ³n', 'SuÃ¡rez']
# ['James', 'David', 'RodrÃ\xadguez', 'Rubio']
# ['Carlos', 'Henrique', 'Venancio', 'Casimiro']
# ['Mauro', 'Emanuel', 'Icardi', 'Rivero']
# ['Kepa', 'Arrizabalaga']
# ['Hakim', 'Ziyech']
# ['FÃ¡bio', 'Henrique', 'Tavares']
# ['Anthony', 'Martial']
# ['Timo', 'Werner']
# ['Niklas', 'SÃ¼le']
# ['Bruno', 'Miguel', 'Borges', 'Fernandes']
# ['Alex', 'Nicolao', 'Telles']
# ['JosÃ©', 'MarÃ\xada', 'GimÃ©nez', 'de', 'Vargas']
# ['Nabil', 'Fekir']
# ['Davinson', 'SÃ¡nchez']
# ['Marco', 'Asensio', 'Willemsen']
# ['Ousmane', 'DembÃ©lÃ©']
# ['AndrÃ©s', 'Iniesta', 'LujÃ¡n']
# ['Zlatan', 'IbrahimoviÄ‡']
# ['Luiz', 'Frello', 'Filho', 'Jorge']
# ['Edin', 'ViÅ¡Ä‡a']
# ['Serge', 'Gnabry']
# ['Mateo', 'KovaÄ\x8diÄ‡']
# ['William', 'Silva', 'de', 'Carvalho']
# ['Felipe', 'Augusto', 'de', 'Almeida', 'Monteiro']
# ['Yannick', 'Ferreira', 'Carrasco']
# ['Lucas', 'VÃ¡zquez', 'Iglesias']
# ['Quincy', 'Anton', 'Promes']
# ['Leon', 'Goretzka']
# ['Adrien', 'Rabiot']
# ['Alessio', 'Romagnoli']
# ['JoÃ£o', 'Pedro', 'Cavaco', 'Cancelo']
# ['Anderson', 'Souza', 'ConceiÃ§Ã£o']
# ['Kingsley', 'Coman']
# ['Thomas', 'Lemar']
# ['Jonathan', 'Tah']
# ['Matteo', 'Politano']
# ['ClÃ©ment', 'Lenglet']
# ['Pau', 'LÃ³pez', 'Sabata']
# ['Hirving', 'Rodrigo', 'Lozano', 'Bahena']
# ['Malcom', 'Filipe', 'Silva', 'de', 'Oliveira']
# ['Lucas', 'Torreira', 'Di', 'Pascua']
# ['GonÃ§alo', 'Manuel', 'Ganchinho', 'Guedes']
# ['Giovani', 'Lo', 'Celso']
# ['FabiÃ¡n', 'Ruiz', 'PeÃ±a']
# ['Frenkie', 'de', 'Jong']
# ['Raphael', 'William', 'Anjos', 'Rochedo']
# ['Juan', 'Everton', 'Mestres', 'de', 'Mesquita']
# ['Rosberto', 'J.', 'Dourado', 'Santos']
# ['Arthur', 'Henrique', 'Ramos', 'Oliveira', 'Melo']
# ['Rodrigo', 'HernÃ¡ndez', 'Cascante']
# ['Marco', 'Parolo']
# ['Max', 'Kruse']
# ['Jordan', 'Brian', 'Henderson']
# ['Osvaldo', 'NicolÃ¡s', 'FabiÃ¡n', 'GaitÃ¡n']
# ['Marko', 'ArnautoviÄ‡']
# ['Sebastian', 'Giovinco']
# ['Gylfi', 'ÃžÃ³r', 'SigurÃ°sson']
# ['Giuliano', 'Victor', 'de', 'Paula']
# ['PÃ©ter', 'GulÃ¡csi']
# ['Luiz', 'Gustavo', 'Dias']
# ['Kieran', 'Trippier']
# ['Aaron', 'Ramsey']
# ['Mario', '', 'Barwuah', 'Balotelli']
# ['Marlos', 'Romero', 'Bonfim']
# ['Taison', 'Barcellos', 'Freda']
# ['Giacomo', 'Bonaventura']
# ['Geoffrey', 'Kondogbia']
# ['JÃ©rÃ´me', 'Roussillon']
# ['Simone', 'Zaza']
# ['Å\xa0ime', 'Vrsaljko']
# ['Christoph', 'Kramer']
# ['Benjamin', 'Mendy']
# ['Marcel', 'Sabitzer']
# ['Matija', 'NastasiÄ‡']
# ['Alassane', 'Plea']
# ['Matthias', 'Ginter']
# ['Gerard', 'Moreno', 'BalaguerÃ³']
# ['Abdoulaye', 'DoucourÃ©']
# ['RaphaÃ«l', 'Guerreiro']
# ['Ricardo', 'Barbosa', 'Pereira']
# ['Samuel', 'Castillejo', 'Azuaga']
# ['Julian', 'Brandt']
# ['Nicolas', 'PÃ©pÃ©']
# ['Steven', 'Bergwijn']
# ['AndrÃ©', 'Onana']
# ['FabiÃ¡n', 'Balbuena']
# ['AndrÃ©', 'Miguel', 'Valente', 'da', 'Silva']
# ['Mikel', 'Oyarzabal', 'Ugarte']
# ['Everton', 'Jorge', 'Andrade', 'Zanon']
# ['Welington', 'KauÃª', 'Dano', 'Nascimento']
# ['Richarlison', 'de', 'Andrade']
# ['Ã\x81lvaro', 'Odriozola', 'Arzalluz']
# ['Carlos', 'Soler', 'BarragÃ¡n']
# ['Houssem', 'Aouar']
# ['Tanguy', 'NDombÃ¨lÃ©', 'Alvaro']
# ['Maximiliano', 'GÃ³mez']
# ['JoaquÃ\xadn', 'SÃ¡nchez', 'RodrÃ\xadguez']
# ['JÃ©rÃ©my', 'Mathieu']
# ['JoÃ«l', 'Andre', 'Job', 'Matip']
# ['Serge', 'Aurier']
# ['Josuha', 'Guilavogui']
# ['Alex', 'Oxlade-Chamberlain']
# ['Mathew', 'Ryan']
# ['Vincent', 'PatÃ©', 'Aboubakar']
# ['Luis', 'Fernando', 'Muriel', 'Fruto']
# ['Domagoj', 'Vida']
# ['Ibai', 'GÃ³mez', 'PÃ©rez']
# ['Cristian', 'Tello', 'Herrera']
# ['Ismaily', 'GonÃ§alves', 'dos', 'S.']
# ['AÃ¯ssa', 'Mandi']
# ['Anton', 'Ciprian', 'TÄƒtÄƒruÈ™anu']
# ['Jeison', 'FabiÃ¡n', 'Murillo', 'CerÃ³n']
# ['Eric', 'Dier']
# ['Jack', 'Butland']
# ['Stefano', 'Sorrentino']
# ['Wayne', 'Mark', 'Rooney']
# ['Miguel', 'Ã\x81ngel', 'MoyÃ¡', 'Rumbo']
# ['Lisandro', 'LÃ³pez']
# ['Javier', 'Alejandro', 'Mascherano']
# ['Raffael', 'Caetano', 'de', 'AraÃºjo']
# ['Diego', 'LÃ³pez', 'RodrÃ\xadguez']
# ['Juan', 'Francisco', 'Torres', 'BelÃ©n']
# ['Igor', 'Denisov']
# ['Igor', 'Akinfeev']
# ['AndrÃ©-Pierre', 'Gignac']
# ['Andreas', 'Granqvist']
# ['Manuel', 'Henrique', 'Tavares', 'Fernandes']
# ['Dante', 'Bonfim', 'da', 'Costa', 'Santos']
# ['LoÃ¯c', 'Perrin']
# ['Borja', 'Valero', 'Iglesias']
# ['Adnan', 'Januzaj']
# ['Jonas', 'Hector']
# ['Moanes', 'Dabour']
# ['Ã“liver', 'Torres', 'MuÃ±oz']
# ['Yassine', 'Bounou']
# ['Jonas', 'Hofmann']
# ['OtÃ¡vio', 'Edmilson', 'da', 'Silva', 'Monteiro']
# ['Jonathan', 'Castro', 'Otto']
# ['Leander', 'Dendoncker']
# ['Roman', 'Zobnin']
# ['Ricardo', 'Jorge', 'da', 'Luz', 'Horta']
# ['Thiago', 'Henrique', 'Mendes', 'Ribeiro']
# ['Jefferson', 'AndrÃ©s', 'Lerma', 'SolÃ\xads']
# ['Jean-Philippe', 'Gbamin']
# ['IvÃ¡n', 'Marcone']
# ['DarÃ\xado', 'Benedetto']
# ['Marwin', 'Hitz']
# ['Nathaniel', 'Edwin', 'Clyne']
# ['Adem', 'LjajiÄ‡']
# ['Johann', '', 'Berg', 'GuÃ°mundsÂ\xadson']
# ['Elkeson', 'de', 'Oliveira', 'Cardoso']
# ['Enrique', 'GarcÃ\xada', 'MartÃ\xadnez']
# ['Sergio', 'Escudero', 'Palomo']
# ['Iago', 'HerrerÃ\xadn', 'BuisÃ¡n']
# ['VÃ\xadctor', 'RuÃ\xadz', 'Torre']
# ['Gary', 'Alexis', 'Medel', 'Soto']
# ['YounÃ¨s', 'Belhanda']
# ['Hugo', 'Mallo', 'Novegil']
# ['Borja', 'GarcÃ\xada', 'Freire']
# ['Wahbi', 'Khazri']
# ['Phil', 'Jones']
# ['AlfreÃ°', 'Finnbogason']
# ['VinÃ\xadcius', 'JosÃ©', 'de', 'Oliveira', 'JÃºnior']
# ['HÃ©ctor', 'Junior', 'Firpo', 'AdamÃ©s']
# ['Emre', 'BelÃ¶zoÄŸlu']
# ['Fernando', 'JosÃ©', 'Torres', 'Sanz']
# ['Bastian', 'Schweinsteiger']
# ['Burak', 'YÄ±lmaz']
# ['Mario', 'GÃ³mez', 'GarcÃ\xada']
# ['Ashley', 'Young']
# ['Ryan', 'Guno', 'Babel']
# ['BenoÃ®t', 'Costil']
# ['Salomon', 'Armand', 'Magloire', 'Kalou']
# ['Ezequiel', 'IvÃ¡n', 'Lavezzi']
# ['Hatem', 'Ben', 'Arfa']
# ['Ben', 'Foster']
# ['Tom', 'Heaton']
# ['Charles', 'Dias', 'De', 'Oliveira']
# ['Gary', 'Cahill']
# ['Alex', 'Iwobi']
# ['Ruben', 'Loftus-Cheek']
# ['Alexandr', 'Selikhov']
# ['Johan', 'AndrÃ©s', 'Mojica', 'Palacio']
# ['WÃ\xadlmar', 'Enrique', 'Barrios', 'TerÃ¡n']
# ['Carlos', 'Roberto', 'Izquierdoz']
# ['Walter', 'BenÃ\xadtez']
# ['Nikola', 'MaksimoviÄ‡']
# ['Aleksandar', 'MitroviÄ‡']
# ['Marco', 'Sportiello']
# ['Ander', 'Capa', 'RodrÃ\xadguez']
# ['Marcelo', 'Augusto', 'Ferreira', 'Teixeira']
# ['Youri', 'Tielemans']
# ['Stanislav', 'Lobotka']
# ['Maximilian', 'Philipp']
# ['LÃ©o', 'Dubois']
# ['Lewis', 'Dunk']
# ['Christopher', 'Schindler']
# ['Yevhen', 'Konoplyanka']
# ['Pedro', 'Filipe', 'TeodÃ³sio', 'Mendes']
# ['Riccardo', 'Saponara']
# ['Layvin', 'Kurzawa']
# ['Martin', 'Hinteregger']
# ['Danny', '', 'Vieira', 'da', 'Costa']
# ['Fernando', 'Lucas', 'Martins']
# ['Willy', 'Boly']
# ['Alexander', 'Schwolow']
# ['Gregoire', 'Defrel']
# ['Ã\x81lvaro', 'GonzÃ¡lez', 'SoberÃ³n']
# ['Leonardo', 'Bittencourt']
# ['AndrÃ©', 'MartÃ\xadn', 'Carrillo', 'DÃ\xadaz']
# ['Mohamed', 'Elyounoussi']
# ['Orestis', 'Karnezis']
# ['Ã“scar', 'de', 'Marcos', 'Arana']
# ['RÃ©my', 'Cabella']
# ['Joe', 'Hart']
# ['JosÃ©', 'Manuel', 'Jurado', 'MarÃ\xadn']
# ['ElÃ\xadas', 'HernÃ¡n', 'HernÃ¡ndez', 'Jacuinde']
# ['Daniel', 'Ginczek']
# ['Lucas', 'PÃ©rez', 'MartÃ\xadnez']
# ['Jefferson', 'AgustÃ\xadn', 'FarfÃ¡n', 'Guadalupe']
# ['Asmir', 'BegoviÄ‡']
# ['Vitorino', 'Hilton', 'da', 'Silva']
# ['Julian', 'Baumgartlinger']
# ['Esteban', 'FÃ©lix', 'Granero', 'Molina']
# ['Zlatko', 'JunuzoviÄ‡']
# ['Victor', 'Moses']
# ['Mathieu', 'Debuchy']
# ['Guillermo', 'Alfonso', 'MaripÃ¡n', 'Loaysa']
# ['IvÃ¡n', 'CuÃ©llar', 'SacristÃ¡n']
# ['Fabian', 'Johnson']
# ['AarÃ³n', 'MartÃ\xadn', 'Caricol']
# ['GastÃ³n', 'Rodrigo', 'Pereiro', 'LÃ³pez']
# ['Benjamin', 'Moukandjo', 'BilÃ©']
# ['Martin', 'Harnik']
# ['James', '', 'Ward-Prowse']
# ['Romain', 'Alessandrini']
# ['Manuel', 'Alejandro', 'GarcÃ\xada', 'SÃ¡nchez']
# ['Michail', 'Antonio']
# ['Adrien', 'Sebastian', 'Perruchet', 'Silva']
# ['Steve', 'Cook']
# ['Ben', 'Mee']
# ['Adriano', 'Correia', 'Claro']
# ['Jeremain', 'Lens']
# ['JosÃ©', 'SalomÃ³n', 'RondÃ³n', 'GimÃ©nez']
# ['Andreas', 'Hugo', 'Hoelgebaum', 'Pereira']
# ['Vedad', 'IbiÅ¡eviÄ‡']
# ['Lucas', 'Ocampos']
# ['Nicolai', 'MÃ¼ller']
# ['SimÃ£o', 'Alvin', 'Acunha', 'Bardini']
# ['Jonathan', 'Calleri']
# ['Alireza', 'Jahanbakhsh']
# ['Aleksandar', 'PrijoviÄ‡']
# ['Fabricio', 'MartÃ\xadn', 'Agosto', 'RamÃ\xadrez']
# ['Mohamed', 'Elneny']
# ['Jorge', 'MerÃ©', 'PÃ©rez']
# ['Wilson', 'Bruno', 'Naval', 'Costa', 'Eduardo']
# ['Alejandro', 'Remiro', 'Gargallo']
# ['TeÃ³filo', 'GutiÃ©rrez']
# ['Andriy', 'Pyatov']
# ['Diego', 'Javier', 'Llorente', 'RÃ\xados']
# ['Ignazio', 'Abate']
# ['Thomas', 'Vermaelen']
# ['Niclas', 'FÃ¼llkrug']
# ['Pedro', '', 'Mba', 'Obiang', 'Avomo']
# ['Wallace', 'Fortuna', 'dos', 'Santos']
# ['Jorge', 'Djaniny', '', 'Tavares', 'Semedo']
# ['Roberto', 'JimÃ©nez', 'Gago']
# ['Serdar', 'TaÅŸÃ§Ä±']
# ['Lasse', 'SchÃ¸ne']
# ['Jermain', '', 'Defoe']
# ['Volkan', 'Babacan']
# ['Odion', 'Jude', 'Ighalo']
# ['AndrÃ©', 'SchÃ¼rrle']
# ['Ellyes', 'Skhiri']
# ['Waldemar', 'Anton']
# ['Rodrigo', 'SebastiÃ¡n', 'Palacio']
# ['Kevin', 'Lasagna']
# ['DarÃ\xado', 'Cvitanich']
# ['Sebastian', 'De', 'Maio']
# ['Simon', 'Terodde']
# ['Jonathan', '', 'de', 'GuzmÃ¡n']
# ['Renato', 'Civelli']
# ['Pablo', 'Maffeo', 'Becerra']
# ['CÃ©dric', 'Ricardo', 'Alves', 'Soares']
# ['Kyriakos', 'Papadopoulos']
# ['Alexander', 'Szymanowski']
# ['Juraj', 'Kucka']
# ['Phil', 'Jagielka']
# ['Marco', 'Benassi']
# ['Pontus', 'Jansson']
# ['Bernardo', 'JosÃ©', 'Espinosa', 'ZÃºÃ±iga']
# ['JosÃ©', 'Pedro', 'Malheiro', 'de', 'SÃ¡']
# ['Matz', 'Sels']
# ['Yuri', 'Berchiche', 'Izeta']
# ['Rafael', 'Santos', 'BorrÃ©']
# ['JoÃ£o', 'Paulo', 'Dias', 'Fernandes']
# ['Cristiano', 'Piccini']
# ['Benjamin', 'AndrÃ©']
# ['Antonio', 'BarragÃ¡n', 'FernÃ¡ndez']
# ['Mbwana', 'Ally', 'Samatta']
# ['Issa', 'Diop']
# ['Matthew', 'Lowton']
# ['Theo', 'Bernard', 'FranÃ§ois', 'HernÃ¡ndez']
# ['Juan', 'Pedro', 'RamÃ\xadrez', 'LÃ³pez']
# ['Kenny', 'Tete']
# ['Blerim', 'DÅ¾emaili']
# ['AndrÃ©', 'Filipe', 'BrÃ¡s', 'AndrÃ©']
# ['Mikel', 'Balenziaga', 'Oruesagasti']
# ['Valon', 'Behrami']
# ['Diego', 'Antonio', 'Reyes', 'Rosales']
# ['Caiuby', 'Francisco', 'da', 'Silva']
# ['Seydou', 'Doumbia']
# ['JoÃ£o', 'FÃ©lix', 'Sequeira']
# ['Lisandro', 'LÃ³pez']
# ['Mario', 'SuÃ¡rez', 'Mata']
# ['Jonas', 'LÃ¶ssl']
# ['Gonzalo', 'Castro', 'Randon']
# ['Matt', 'Phillips']
# ['Gabriel', 'Boschilia']
# ['æ\xad¦ç£Š']
# ['NicolÃ¡s', 'Blandi']
# ['Lovre', 'KaliniÄ‡']
# ['Federico', 'FernÃ¡ndez']
# ['Jackson', 'MartÃ\xadnez']
# ['Emerson', 'Palmieri', 'dos', 'Santos']
# ['RÃ´mulo', '', 'Souza', 'Orestes', 'Caldeira']
# ['Christian', 'Benteke', 'Liolo']
# ['Milot', 'Rashica']
# ['Leighton', 'Baines']
# ['Mark', 'Noble']
# ['Filip', 'BenkoviÄ‡']
# ['Cristian', 'Miguel', 'Riveros', 'NÃºÃ±ez']
# ["M'Baye", 'Babacar', 'Niang']
# ['Davide', 'Santon']
# ['Ivan', 'Ordets']
# ['Francisco', 'Geraldes']
# ['Robert', 'Snodgrass']
# ['Vitor', 'Hugo', 'Franchescoli', 'de', 'Souza']
# ['Mario', 'PaÅ¡aliÄ‡']
# ['Fabio', 'Borini']
# ['Nikola', 'VukÄ\x8deviÄ‡']
# ['Atiba', 'Hutchinson']
# ['Maximiliano', 'Nicol', 'Moralez']
# ['Charlie', 'Austin']
# ['Robert', 'Kenedy', 'Nunes', 'do', 'Nascimento']
# ['Eltildo', 'Lucas', 'Correia', 'Pitta']
# ['JoÃ£o', 'Pedro', 'Geraldino', 'dos', 'Santos', 'GalvÃ£o']
# ['Alessandro', 'Diamanti']
# ['Guilherme', 'dos', 'Santos', 'Torres']
# ['JÃ©rÃ©my', 'Morel']
# ['Fernando', 'Javier', 'Llorente', 'Torres']
# ['GÃ¶khan', 'GÃ¶nÃ¼l']
# ['Alberto', 'Paloschi']
# ['Julio', 'Leonardo', 'Dourado', 'de', 'Freitas']
# ['Markel', 'Bergara', 'LarraÃ±aga']
# ['Lee', 'Nguyen']
# ['Anthony', 'Knockaert']
# ['IÃ±igo', 'CÃ³rdoba', 'Kerejeta']
# ['JoÃ«l', 'Veltman']
# ['Nicola', 'Sansone']
# ['Arda', 'Turan']
# ['Haris', 'SeferoviÄ‡']
# ['Rafael', 'Jorgino', 'Cachoira', 'Rebelo']
# ['Amadou', 'Haidara']
# ['Francesco', 'Caputo']
# ['Manuel', 'Locatelli']
# ['Jordan', 'Ayew']
# ['Tin', 'Jedvaj']
# ['Sofiane', 'Hanni']
# ['AndrÃ©s', 'Eduardo', 'FernÃ¡ndez', 'Moreno']
# ['Thomas', 'Monconduit']
# ['Nordi', 'Mukiele']
# ['Dominique', 'Heintz']
# ['UÃ\xadlson', 'de', 'Souza', 'Paula', 'JÃºnior']
# ['Aaron', '', 'Lennon']
# ['Jetro', 'Willems']
# ['MiloÅ¡', 'VeljkoviÄ‡']
# ['Ishak', 'Belfodil']
# ['Hugo', 'Miguel', 'Almeida', 'Costa', 'Lopes']
# ['Dale', 'Stephens']
# ['Brais', 'MÃ©ndez', 'Portela']
# ['Adam', 'Smith']
# ['JosÃ©', 'Luis', 'GarcÃ\xada', 'del', 'Pozo']
# ['Francisco', 'FemenÃ\xada', 'Far']
# ['Mijat', 'GaÄ‡inoviÄ‡']
# ['Per', 'Ciljan', 'Skjelbred']
# ['Da', 'ConceiÃ§Ã£o', 'Fernando', 'Henrique']
# ['Scott', 'Brown']
# ['Marko', 'GrujiÄ‡']
# ['Adama', 'Soumaoro']
# ['RaÃºl', 'RodrÃ\xadguez', 'Navas']
# ['Ã\x81dÃ¡m', 'Szalai']
# ['Amadou', 'Diawara']
# ['Å\x81ukasz', 'Skorupski']
# ['Romain', 'Hamouma']
# ['Kevin', 'StÃ¶ger']
# ['Karol', 'Linetty']
# ['Stefan', 'Bell']
# ['Alfred', 'John', 'Momar', "N'Diaye"]
# ['Yusuf', 'YazÄ±cÄ±']
# ['Bastian', 'Oczipka']
# ['Federico', 'Valverde']
# ['MartÃ\xadn', 'BenÃ\xadtez']
# ['Michel', 'Vorm']
# ['Nampalys', 'Mendy']
# ['JosÃ©', 'Juan', 'VÃ¡zquez', 'GÃ³mez']
# ['Unai', 'NÃºÃ±ez', 'Gestoso']
# ['Nemanja', 'Radoja']
# ['Kieran', '', 'Gibbs']
# ['Abderrazak', 'Hamdallah']
# ['Pablo', 'Renan', 'dos', 'Santos']
# ['Seko', 'Fofana']
# ['Felipe', 'Dias', 'da', 'Silva', 'dal', 'Belo']
# ['Carlos', 'AndrÃ©s', 'Villanueva', 'Roland']
# ['JosÃ©', 'MÃ¡rcio', 'da', 'Costa']
# ['Diego', 'Rico', 'Salguero']
# ['Alberto', 'Moreno', 'PÃ©rez']
# ['Jordy', 'Clasie']
# ['Rogelio', 'Gabriel', 'Funes', 'Mori']
# ['Osvaldo', 'Alonso', 'Moreno']
# ['Alexander', 'Djiku']
# ['Jonathan', 'Hogg']
# ['Dominic', 'Calvert-Lewin']
# ['Marvin', 'Zeegelaar']
# ['Guido', 'Carrillo']
# ['Jozabed', 'SÃ¡nchez', 'Ruiz']
# ['Alan', 'Javier', 'Franco']
# ['David', 'Brooks']
# ['Jeffrey', 'Bruma']
# ['Luigi', 'Sepe']
# ['Sam', 'Vokes']
# ['Javier', 'LÃ³pez', 'RodrÃ\xadguez']
# ['Jordan', 'Amavi']
# ['Idrissa', 'Mandiang']
# ['Alper', 'Potuk']
# ['Oliver', 'Norwood']
# ['Rani', 'Khedira']
# ['Darwin', 'MachÃ\xads']
# ['Robin', 'Quaison']
# ['Paul', 'Dummett']
# ['Landry', 'Dimata']
# ['Allan', 'Norberto', 'Bardini', 'Paneira']
# ['Ludovic', 'Butelle']
# ['SebastiÃ¡n', 'CristÃ³foro']
# ['David', 'Jason', 'Remeseiro', 'Salgueiro']
# ['Mikel', 'Agu']
# ['Emmanuel', 'Badu']
# ['Nathan', 'Redmond']
# ['Sandro', 'Ranieri', 'GuimarÃ£es', 'Cordeiro']
# ['Anthony', 'Mounier']
# ['Matheus', 'Fellipe', 'Costa', 'Pereira']
# ['Christophe', 'Jallet']
# ['Diego', 'Castro', 'GimÃ©nez']
# ['å²¡å´Ž', 'æ…Žå\x8f¸']
# ['Ola', '', 'Williams', 'Kamara']
# ['Miguel', 'Ã‚ngelo', 'da', 'Silva', 'Rocha']
# ['Rick', 'Karsdorp']
# ['JosÃ©', 'Carlos', 'CoentrÃ£o', 'Marafona']
# ['Diego', 'ValdÃ©s']
# ['Maxime', 'Gonalons']
# ['Jorge', 'Franco', 'Alviz']
# ['Fredy', 'Alejandro', 'GuarÃ\xadn', 'VÃ¡squez']
# ['Mathias', 'Jensen']
# ['Ryan', 'Thomas']
# ['Bogdan', 'Butko']
# ['Luca', 'Cigarini']
# ['Ahmed', 'Musa']
# ['Mykola', 'Morozyuk']
# ['Georgiy', 'Schennikov']
# ['AndrÃ©', 'Ramalho', 'Silva']
# ['Thomas', 'Foket']
# ['Philip', 'Foden']
# ['Walace', 'Souza', 'Silva']
# ['Ä°rfan', 'Can', 'Kahveci']
# ['Jimmy', 'Briand']
# ['Diego', 'RolÃ¡n']
# ['Cyril', 'ThÃ©rÃ©au']
# ['Bruno', 'Valdez']
# ['Pape', 'Moussa', 'KonatÃ©']
# ['Hugo', 'Ayala', 'Castro']
# ['Justin', 'Kluivert']
# ['Percy', 'Tau']
# ['Javier', 'Eraso', 'GoÃ±i']
# ['Artur', 'Boruc']
# ['Sam', 'Larsson']
# ['Paulo', 'Henrique', 'Soares', 'dos', 'Santos']
# ['Jonathan', 'MatÃ\xadas', 'Urretaviscaya', 'da', 'Luz']
# ['Youssef', 'AÃ¯t', 'Bennasser']
# ['Paul', 'Bernardoni']
# ['Joshua', 'Brenet']
# ['Carles', 'AleÃ±Ã¡', 'Castillo']
# ['Thiago', 'Maia', 'Alencar']
# ['Robert', 'Skov']
# ['Mauricio', 'AnÃ\xadbal', 'Isla', 'Isla']
# ['Weston', 'McKennie']
# ['James', 'Tavernier']
# ['Samuel', 'Kalu', 'Ojim']
# ['Marlon', 'da', 'Silva', 'Barbosa']
# ['Joseph', 'Alfred', 'Duncan']
# ['Stefano', 'Sturaro']
# ['Harry', 'Arter']
# ['Vitaliy', 'Buyalskyi']
# ['Malang', 'Sarr']
# ['Ignacio', 'FernÃ¡ndez']
# ['Hans', 'Hateboer']
# ['Florian', 'Niederlechner']
# ['Pirmin', 'Schwegler']
# ['Ben', 'Pearson']
# ['Tammy', 'Abraham']
# ['Jefferson', 'Moreira', 'Nascimento']
# ['Joakim', 'MÃ¦hle']
# ['Unai', 'LÃ³pez', 'Cabrera']
# ['Ibrahim', 'Amadou']
# ['Christian', 'GÃ¼nter']
# ['Ogenyi', 'Eddy', 'Onazi']
# ['Jefferson', 'Antonio', 'Montero', 'Vite']
# ['Oscar', 'FabiÃ¡n', 'Murillo', 'Murillo']
# ['Borja', 'GonzÃ¡lez', 'TomÃ¡s']
# ['Lucas', 'ZelarayÃ¡n']
# ['Martin', 'Kelly']
# ['Aminu', 'Umar']
# ['Joseba', 'ZaldÃºa', 'Bengoetxea']
# ['Mbaye', 'Diagne']
# ['Jovane', 'Eduardo', 'Borges', 'Cabral']
# ['Scott', 'Dann']
# ['Mateo', 'PavloviÄ‡']
# ['Andrew', 'Surman']
# ['Florian', 'Kainz']
# ['Francisco', 'JosÃ©', 'BeltrÃ¡n', 'Peinado']
# ['Kenneth', 'Vermeer']
# ['Andreu', 'FontÃ\xa0s', 'Prat']
# ['Luis', 'Enrique', 'QuiÃ±Ã³nes']
# ['Mathew', 'Leckie']
# ['Danilo', 'das', 'Neves', 'Pinheiro']
# ['Solly', 'March']
# ['Bryan', 'Dabo']
# ['Fredrik', 'MidtsjÃ¸']
# ['Alejandro', 'Arribas', 'Garrido']
# ['Duirval', 'HÃ©lton', 'Diniz', 'Cabral']
# ['Ollie', 'Watkins']
# ['Renato', 'Tapia']
# ['Enzo', 'Pablo', 'Roco', 'Roco']
# ['Jonas', 'Svensson']
# ['Lucas', 'Alfonso', 'OrbÃ¡n', 'Alegre']
# ['Godfred', 'Donsah']
# ['Ladislav', 'KrejÄ\x8dÃ\xad']
# ['Scott', 'Sinclair']
# ['Bojan', 'JokiÄ\x8d']
# ['Marcus', 'Thuram']
# ['Silvio', 'Ezequiel', 'Romero']
# ['Christian', 'Atsu']
# ['Christian', 'TrÃ¤sch']
# ['Florentin', 'Pogba']
# ['Sergio', 'ReguilÃ³n', 'RodrÃ\xadguez']
# ['Caio', 'Bruno', 'MilaÃ§ar', 'Kenedy']
# ['Marc-Oliver', 'Kempf']
# ['Daniel', 'SÃ¡nchez', 'Ayala']
# ['Patrick', 'Roberts']
# ['Guillermo', 'OrtÃ\xadz']
# ['RafaÅ‚', 'Gikiewicz']
# ['Rodrigo', 'Rey']
# ['Yasin', 'Ã–ztekin']
# ['Daniel', 'JoÃ£o', 'Santos', 'Candeias']
# ['Claudio', 'Beauvue']
# ['Marcelo', 'dos', 'Santos', 'Ferreira']
# ['Steve', 'von', 'Bergen']
# ['Joel', 'Obi']
# ['Rafael', 'da', 'ConceiÃ§Ã£o', 'LeÃ£o']
# ['Pedro', 'K.', 'Medina', 'da', 'Silva']
# ['RaÃºl', 'FernÃ¡ndez-Cavada', 'Mateos']
# ['é•·å\x8f‹', 'ä½‘éƒ½']
# ['Patrik', 'HroÅ¡ovskÃ½']
# ['Robert', 'BeriÄ‡']
# ['NicolÃ¡s', 'Federico', 'Spolli']
# ['Liam', 'Moore']
# ['Diego', 'Falcinelli']
# ['Jean-Sylvain', 'Claude', 'Babin']
# ['Jan', 'Kopic']
# ['Matt', 'Besler']
# ['Pablo', 'Martinez']
# ['Renan', 'Bardini', 'Bressan']
# ['Olcay', 'Åžahan']
# ['Michael', 'Rensing']
# ['Kalvin', 'Phillips']
# ['Willem', 'Janssen']
# ['Eugenio', 'Mena']
# ['Amato', 'Ciciretti']
# ['Davidson', 'da', 'Luz', 'Pereira']
# ['Diogo', 'Filipe', 'Monteiro', 'Pinto', 'Leite']
# ['Andrea', 'Raggi']
# ['Samuel', 'Grandsir']
# ['Damir', 'Kreilach']
# ['Alan', 'Ruiz']
# ['IÃ±igo', 'PÃ©rez', 'Soto']
# ['Ludovic', 'Lamine', 'SanÃ©']
# ['OlÃ\xadvio', 'da', 'Rosa']
# ['Gil', 'BastiÃ£o', 'Dias']
# ['Ã\x81ngel', 'Mena']
# ['Jhon', 'CÃ³rdoba']
# ['Bruno', 'Ã‰cuÃ©lÃ©', 'Manga']
# ['Nicola', 'Murru']
# ['Graeme', 'Shinnie']
# ['Jens', 'Stryger', 'Larsen']
# ['Aleksandr', 'Erokhin']
# ['Luis', 'Robles']
# ['Andreas', 'Ulmer']
# ['FabiÃ¡n', 'Castillo']
# ['Ilija', 'Nestorovski']
# ['Mason', 'Mount']
# ['Olarenwaju', 'Ayoba', 'Kayode']
# ['Matheus', 'Jadson', 'Vidigal', 'Morais']
# ['Paul', 'Verhaegh']
# ['Lucas', 'Cavallini']
# ['Johannes', 'Geis']
# ['Ricky', 'van', 'Wolfswinkel']
# ['Kasim', 'Adams', 'Nuhu']
# ['KÃ©vin', 'Manuel', 'Rodrigues']
# ['JonÃ¡s', '', 'Ramalho', 'Chimeno']
# ['Andrey', 'Semenov']
# ['GaÃ«tan', 'Charbonnier']
# ['Luis', 'Carlos', 'Correia', 'Pinto']
# ['Erik', 'Pieters']
# ['Hannes', 'Wolf']
# ['Joseph', 'Aidoo']
# ['NicolÃ¡s', 'JÃºlio', 'Formido', 'Paiva']
# ['Dimitrios', 'Kourmpelis']
# ['JagoÅ¡', 'VukoviÄ‡']
# ['Jean', 'AndrÃ©', 'Emanuel', 'Beausejour', 'Coliqueo']
# ['Matthias', 'Ostrzolek']
# ['Jakub', 'BÅ‚aszczykowski']
# ['Denis', 'Bouanga']
# ['RubÃ©n', 'Botta']
# ['Darko', 'LazoviÄ‡']
# ['Lazar', '', 'MarkoviÄ‡']
# ['FÃ¡bio', 'Ricardo', 'Gomes', 'Fonseca']
# ['Ruben', 'Alexandre', 'Rocha', 'Lima']
# ['å®‡ä½\x90ç¾Ž', 'è²´å\x8f²']
# ['Eloy', 'Room']
# ['Koffi', 'Cheikh', 'KonatÃ©']
# ['RubÃ©n', 'Alcaraz', 'JimÃ©nez']
# ['Allan', 'Nyom']
# ['Yuri', 'Oliveira', 'Ribeiro']
# ['Mehmet', 'Ekici']
# ['VÃ\xadctor', 'Ismael', 'Sosa']
# ['Lorenzo', 'AntÃ³nio', 'Melgarejo', 'Sanabria']
# ['William', 'Alves', 'de', 'Oliveira']
# ['MatÄ›j', 'Vydra']
# ['Tiago', 'Manuel', 'Dias', 'Correia']
# ['AdriÃ¡n', '', 'GonzÃ¡lez', 'Morales']
# ['Ã‡aÄŸlar', 'SÃ¶yÃ¼ncÃ¼']
# ['Kelechi', 'Iheanacho']
# ['Marcel', 'Tisserand']
# ['Anthony', 'RubÃ©n', 'Lozano', 'ColÃ³n']
# ['Luca', 'Waldschmidt']
# ['Adriano', 'Leandro', 'Soares', 'Taffarel']
# ['Sten', 'Michael', 'Grytebust']
# ['Ivan', 'StriniÄ‡']
# ['Pedro', 'Miguel', 'Braga', 'Rebocho']
# ['Jerry', 'Mbakogu']
# ['Matheus', 'DÃ³ria', 'Macedo']
# ['Musa', 'Ã‡aÄŸÄ±ran']
# ['Kaiansu', 'Kei', 'Kamara']
# ['StÃ©phane', 'Bahoken']
# ['Ben', 'Gibson']
# ['JosÃ©', 'Ignacio', 'MartÃ\xadnez', 'GarcÃ\xada']
# ['Andreas', 'Evald', 'Cornelius']
# ['Maxime', 'Le', 'Marchand']
# ['Pape', 'Cheikh', 'Diop', 'Gueye']
# ['Åžener', 'Ã–zbayraklÄ±']
# ['Steven', 'Davis']
# ['Abdul', 'Rahman', 'Baba']
# ['Ervin', 'ZukanoviÄ‡']
# ['El-Hadji', 'Baye', 'Oumar', 'Niasse']
# ['Paul-JosÃ©', "M'Poku", 'Ebunge']
# ['Kevin', 'McDonald']
# ['Jesus', 'FabrÃ\xadcio', 'Andrade', 'SimÃµes']
# ['Soslan', 'Dzhanaev']
# ['MiloÅ¡', 'Degenek']
# ['Adrien', 'Tameze']
# ['Tiago', 'Rafael', 'Maia', 'Silva']
# ['Ã‰ric', 'BauthÃ©ac']
# ['Yoric', 'Ravet']
# ['DuÅ¡ko', 'ToÅ¡iÄ‡']
# ['Daniele', 'Padelli']
# ['Bernard', 'Mensah']
# ['Jonathan', 'Ludovic', 'Biabiany']
# ['Ivo', 'IliÄ\x8deviÄ‡']
# ['Harvey', 'Lewis', 'Barnes']
# ['Chidozie', 'Collins', 'Awaziem']
# ['Antonio', 'Manuel', 'Luna', 'RodrÃ\xadguez']
# ['AurÃ©lien', 'Chedjou']
# ['Djavan', 'da', 'Silva', 'Ferreira']
# ['Artem', 'Rebrov']
# ['Georg', 'Margreitter']
# ['Salvador', 'SÃ¡nchez', 'Ponce']
# ['Pietro', 'MaurÃ\xadcio', 'Mendes', 'Abranches']
# ['Marco', 'Russ']
# ['Hendrik', 'Van', 'Crombrugge']
# ['Abdelaziz', 'Barrada']
# ['ä¸\xadæ\x9d‘', 'å®ªå‰›']
# ['Adam', 'Clayton']
# ['Tim', 'Leibold']
# ['Vyacheslav', 'Karavaev']
# ['Iver', 'Fossum']
# ['Daniel', 'Bessa']
# ['Nelson', 'Acevedo']
# ['Sergiy', 'Rybalka']
# ['Giovanni', 'Di', 'Lorenzo']
# ['Habib', 'Diallo']
# ['Brian', 'FernÃ¡ndez']
# ['JosÃ©', 'MarÃ\xada', 'Basanta']
# ['Sada', 'Thioub']
# ['Che', 'Adams']
# ['JosÃ©', 'Ignacio', 'Peleteiro', 'Ramallo']
# ['Enzo', 'Crivelli']
# ['Xabier', 'Etxeita', 'Gorritxategi']
# ['Daniel', 'Ciofani']
# ['Maximiliano', 'Urruti']
# ['Gerso', 'Fernandes']
# ['Josef', 'Å\xa0ural']
# ['Bersant', 'Celina']
# ['Salman', 'Mohammed', 'Al', 'Faraj']
# ['Lovro', 'Majer']
# ['Jeremiah', 'St.', 'Juste']
# ['Miler', 'Alejandro', 'BolaÃ±os', 'Reascos']
# ['Roy', 'Krishna']
# ['Edoardo', 'Goldaniga']
# ['ì„\x9dí˜„ì¤€', 'çŽ„é“‰ä¿Š']
# ['Miguel', 'Alfonso', 'Herrero', 'Javaloyas']
# ['Ã\x81lejandro', 'Gallar', 'Falguero']
# ['Pablo', 'Insua', 'Blanco']
# ['Ignasi', 'Miquel', 'i', 'Pons']
# ['Luis', 'Gonzalo', 'Bustamante']
# ['Ezequiel', 'Schelotto']
# ['Paulo', 'SÃ©rgio', 'Mota']
# ['Florian', 'HÃ¼bner']
# ['AndrÃ©', 'de', 'Castro', 'Pereira']
# ['Rodrigo', 'Aliendro']
# ['é‡‘å´Ž', 'å¤¢ç”Ÿ']
# ['Stoppila', 'Sunzu']
# ['Yaya', 'Sanogo']
# ['å\x8d—é‡Ž', 'æ‹“å®Ÿ']
# ['Sokratis', 'Dioudis']
# ['Jehad', 'Fadel', 'Al', 'Hussain']
# ['RaÃºl', 'GarcÃ\xada', 'Carnero']
# ['SebastiÃ¡n', 'HernÃ¡n', 'Bertoli']
# ['JÃ©rÃ©my', 'GÃ©lin']
# ['Josip', 'MiÅ¡iÄ‡']
# ['Fabiano', 'Ribeiro', 'de', 'Freitas']
# ['Orel', 'Mangala']
# ['Jeremy', 'Toljan']
# ['Javier', 'Marcelo', 'Gandolfi']
# ['Joe', 'Lewis']
# ['Jan', 'BoÅ™il']
# ['Sam', 'Clucas']
# ['Alexander', 'GrÃ¼nwald']
# ['Jakob', 'Bendix', 'Uhd', 'Poulsen']
# ['CÃ©sar', 'Jasib', 'Montes', 'Castro']
# ['Riccardo', 'Meggiorini']
# ['Niko', 'Bungert']
# ['Christian', 'KouamÃ©']
# ['Francisco', 'Javier', 'Meza', 'Palma']
# ['Ã\x81ngelo', 'HenrÃ\xadquez']
# ['NÃ©lson', 'Miguel', 'Castro', 'Oliveira']
# ['Emanuele', 'Terranova']
# ['Renaud', 'Emond']
# ['Gary', 'Hooper']
# ['Luke', 'Anthony', 'Freeman']
# ['LuÃ\xads', 'Miguel', 'Vieira', 'da', 'Silva']
# ['Andrea', 'Rispoli']
# ['NicolÃ¡s', 'GastÃ³n', 'Navarro']
# ['Alexander', 'Nahuel', 'Barboza', 'UllÃºa']
# ['Alexandru', 'Iulian', 'Maxim']
# ['Ola', 'John']
# ['Alex', 'Smithies']
# ['Pablo', 'CÃ©sar', 'Barrientos']
# ['FabiÃ¡n', 'AndrÃ©s', 'Rinaudo']
# ['Luca', 'Mazzitelli']
# ['Eduardo', 'AntÃ´nio', 'Machado', 'Teixeira']
# ['Giampaolo', 'Pazzini']
# ['Abdoulaye', 'Bamba']
# ['Arturo', 'Mina']
# ['Ibrahima', 'Mbaye']
# ['Mahmut', 'Tekdemir']
# ['Leonardo', 'FabiÃ¡n', 'BuriÃ¡n', 'Castro']
# ['Michel', 'David', 'Cruceiro', 'Muscato']
# ['Ricardo', 'Jorge', 'Vaz', 'TÃ©']
# ['Yeison', 'Stiven', 'Gordillo', 'Vargas']
# ['Gino', 'Peruzzi']
# ['æ±‰è¶…äºŽ']
# ['Keiren', 'Westwood']
# ['Evandro', 'SÃ©rgio', 'Rochedo', 'Paulino']
# ['Daniel', 'Pacheco', 'Lobato']
# ['Antonio', 'RÃ\xados', 'MartÃ\xadnez']
# ['Deniz', 'Kadah']
# ['Adama', 'Diakhaby']
# ['Juan', 'Carlos', 'MartÃ\xadn', 'Corral']
# ['Isaac', 'Success']
# ['Salem', 'Al', 'Dawsari']
# ['Aras', 'Ã–zbiliz']
# ['Geovanni', 'Banguera']
# ['Karl-Johan', 'Johnsson']
# ['UÄŸur', 'Demirok']
# ['Nana', 'Kwesi', 'Asare']
# ['Manuel', 'Pucciarelli']
# ['Diego', 'Santiago', 'FagÃºndez', 'Pepe']
# ['William', 'Troost-Ekong']
# ['Paulo', 'JosÃ©', 'de', 'Oliveira']
# ['Juan', 'Marcos', 'Foyth']
# ['Martin', 'Linnes']
# ['SÃ©rgio', 'AntÃ´nio', 'Soler', 'Oliveira', 'Jr']
# ['HÃ©lder', 'Filipe', 'Oliveira', 'Lopes']
# ['Erik', 'Berg']
# ['Rasmus', 'Bengtsson']
# ['Fernando', 'MartÃ\xadn', 'Forestieri']
# ['Kamil', 'Wilczek']
# ['Gojko', 'Cimirot']
# ['IsmaÃ«l', 'Bennacer']
# ['Luca', 'Marrone']
# ['Rafik', 'Halliche']
# ['ValentÃ\xadn', 'Vada']
# ['Yves', 'Bissouma']
# ['Rodrigo', 'Salinas', 'Dorantes']
# ['å\xa0‚å®‰', 'å¾‹']
# ['Ã‰dgar', 'Felipe', 'Pardo', 'Castro']
# ['Jhon', 'Duque']
# ['David', 'Jensen']
# ['JuliÃ¡n', 'Omar', 'Ramos', 'SuÃ¡rez']
# ['Darren', 'Randolph']
# ['Stefano', 'Sensi']
# ['AndrÃ©s', 'Ricaurte', 'VÃ©lez']
# ['MatÃ\xadas', 'Aguirregaray', 'Guruceaga']
# ['JoÃ£o', 'AntÃ³nio', 'Antunes', 'Carvalho']
# ['ArbÃ«r', 'Zeneli']
# ['Dario', 'Dainelli']
# ['Kian', 'Hansen']
# ['Ryan', 'Bennett']
# ['ì\x9d´ì²\xadìš©', 'æ\x9dŽé\x9d’é¾™']
# ['Valerio', 'Verre']
# ['ê¶Œìˆœíƒœ', 'æ\x9dƒçº¯æ³°']
# ['Mauro', 'Pierre', 'Cildinho', 'Conradi']
# ['Arnaldo', 'Edi', 'Lopes', 'da', 'Silva']
# ['Leonardo', 'NicolÃ¡s', 'Pisculichi']
# ['Yohan', 'Benalouane']
# ['Antonino', 'Ragusa']
# ['Fabien', 'Lemoine']
# ['Cristian', 'Roldan']
# ['Didier', '', 'Ndong', 'Ibrahim']
# ['VladimÃ\xadr', 'Coufal']
# ['Mislav', 'OrÅ¡iÄ‡']
# ['Ã‰der', 'Marvin', 'Oliveira', 'SimÃ£o']
# ['Barry', 'Bannan']
# ['Robin', 'Koch']
# ['NicolÃ¡s', 'Pasquini']
# ['Alessandro', 'Rosina']
# ['Tim', 'Parker']
# ['Marcos', 'G.', 'Santos', 'Matos']
# ['Derrick', 'Luckassen']
# ['Shaun', 'Hutchinson']
# ['Bruno', 'JosÃ©', 'Pavani', 'Lamas']
# ['Alexandru', 'BÄƒlutÄƒ']
# ['Miguel', 'Ã\x81ngel', 'De', 'las', 'Cuevas', 'BarberÃ¡']
# ['Leonardo', 'B.', 'Lohner', 'Maia']
# ['Daniel', 'KolÃ¡Å™']
# ['é\x9d’å±±', 'æ•\x8få¼˜']
# ['Santiago', 'Montoya']
# ['Victor', 'Emanuel', 'Aguilera']
# ['å±±å\x8f£', 'è›\x8d']
# ['Ilombe', 'Mboyo']
# ['Bruno', 'VinÃ\xadcius', 'Souza', 'Ramos']
# ['Borna', 'BariÅ¡iÄ‡']
# ['Wilson', 'MiguÃ©is', 'ManafÃ¡', 'JancÃ³']
# ['Christian', 'NÃ¸rgaard']
# ['George', 'Friend']
# ['Davit', 'Khotcholava']
# ['Bassem', '', 'Srarfi']
# ['RomÃ¡rio', 'Ricardo', 'da', 'Silva']
# ['Mateus', 'Galiano', 'da', 'Costa']
# ['Wes', 'Hoolahan']
# ['Ramon', 'Olamilekan', 'Azeez']
# ['Michael', 'Frey']
# ['Jean-Daniel', 'Akpa', 'Akpro']
# ['Joan', 'Isaac', 'Cuenca', 'LÃ³pez']
# ['FÃ¡bio', 'JosÃ©', 'Ferreira', 'Pacheco']
# ['Gustavo', 'Lucas', 'Domingues', 'Piazon']
# ['Timoteo', 'Samuel', 'Triano', 'Branco']
# ['Alexander', 'Scholz']
# ['Yussif', 'Raman', 'Chibsah']
# ['Mark', 'Duffy']
# ['Gareth', 'McAuley']
# ['Nawaf', 'Shaker', 'Al', 'Abid']
# ['Alessandro', 'Nuno', 'Vaz', 'Laranjeiras']
# ['Daniele', 'Verde']
# ['Pierre-Michel', 'Lasogga']
# ['Marlon', 'Pack']
# ['Zinedine', 'Ferhat']
# ['Chad', 'Marshall']
# ['Jean-Christophe', 'Bahebeck']
# ['RÃ³ger', 'Espinoza', 'RamÃ\xadrez']
# ['NicolÃ¡s', 'IvÃ¡n', 'GonzÃ¡lez']
# ['Nuno', 'Miguel', 'Gomes', 'dos', 'Santos']
# ['Kasper', 'Kusk', 'Vangsgaard']
# ['Eugenio', 'Lamanna']
# ['Gilles', 'Sunu']
# ['Emil', 'Berggreen']
# ['Jonathan', 'Guillermo', 'NuÃ±ez', 'Espinoza']
# ['Luciano', 'Aued']
# ['è’¿ä¿Šé—µ']
# ['Marius', 'ValericÄƒ', 'GÄƒman']
# ['Jorge', 'Pulido', 'Mayoral']
# ['Abbubaker', 'Mobara']
# ['Joe', 'Ledley']
# ['Ahmet', 'Ã‡alÄ±k']
# ['Alberto', 'Cerri']
# ['í‚´ì§„ìˆ˜', 'é‡‘ç\x8f\x8dæ´™']
# ['Christian', 'GytkjÃ¦r']
# ['ì\x9d´ê°•ì\x9d¸', 'Kangin', 'Lee']
# ['Edigar', 'Junio', 'Teixeira', 'Lima']
# ['John', 'Bostock']
# ['Sergio', 'Pellissier']
# ['Marcus', 'Antonsson']
# ['Moise', 'Kean']
# ['James', '', 'Collins']
# ['Nyasha', 'Liberty', 'Mushekwi']
# ['Leiton', 'JimÃ©nez']
# ['Delvin', 'Nâ€™Dinga']
# ['Felix', 'Kroos']
# ['Mimoun', 'Mahi']
# ['Joris', 'van', 'Overeem']
# ['Alexander', 'Esswein']
# ['Jorge', 'Moreira']
# ['Jorge', 'Pietro', 'Carvalho', 'PorfÃ\xadrio']
# ['Jair', 'Pereira', 'RodrÃ\xadguez']
# ['Nino', 'GaloviÄ‡']
# ['HÃ¡rold', 'Santiago', '', 'Mosquera', 'Caicedo']
# ['Juan', 'Pablo', 'Nieto', 'Salazar']
# ['Claudio', 'Ariel', 'Yacob']
# ['Ludovic', 'Ajorque']
# ['HernÃ¡n', 'Barcos']
# ['ä¸\xadæ\x9d‘', 'ä¿Šè¼”']
# ['Moussa', 'Doumbia']
# ['Gennaro', 'Tutino']
# ['AgustÃ\xadn', 'Allione']
# ['GermÃ¡n', 'Lanaro']
# ['Walker', 'Zimmerman']
# ['Luca', 'Rizzo']
# ['Roberto', 'Carlos', 'GutiÃ©rrez', 'Gamboa']
# ['Mario', 'GavranoviÄ‡']
# ['Ã–zer', 'HurmacÄ±']
# ['Andres', 'Tello']
# ['Simon', 'Gustafson']
# ['Fabio', 'Giovanni', 'Ceravolo']
# ['Fabricio', 'Coloccini']
# ['Gianluca', 'Curci']
# ['Daniel', 'Martins', 'GuimarÃ£es']
# ['Emil', 'HallfreÃ°sson']
# ['Miiko', 'MartÃ\xadn', 'Albornoz', 'Inola']
# ['Juan', 'Ignacio', 'Mercier']
# ['Mitchell', 'Glenn', 'Donald']
# ['MickaÃ«l', 'Cuisance']
# ['Amr', 'Warda']
# ['Adama', 'TraorÃ©']
# ['Oliver', 'McBurnie']
# ['Dankler', 'LuÃ\xads', 'de', 'Jesus', 'Pedreira']
# ['Mauro', 'Daniel', 'Goicoechea', 'Furia']
# ['Lucas', '', 'Andersen']
# ['Chinedu', 'Obasi', 'Ogbuke']
# ['Tim', 'Howard']
# ['Henok', 'Goitom']
# ['SaÃ®f-Eddine', 'Khaoui']
# ['Rajiv', 'van', 'La', 'Parra']
# ['AdriÃ¡n', 'MarÃ\xadn', 'GÃ³mez']
# ['Lucas', 'Menossi']
# ['JosuÃ©', 'Humberto', 'GonÃ§alves', 'Leal', 'SÃ¡']
# ['Anastasios', 'Chatzigiovanis']
# ['Cristian', 'Enzo', 'Lodeira', 'Araujo']
# ['Aleksandar', 'PantiÄ‡']
# ['Jorge', 'Luis', 'Rojas', 'Meza']
# ['Fabian', 'Klos']
# ['Cristian', 'Leonel', 'RamÃ\xadrez', 'Zambrano']
# ['John', 'Boye']
# ['Maksym', 'Malyshev']
# ['Douglas', 'Pereira', 'dos', 'Santos']
# ['Kris', 'Boyd']
# ['Diego', 'RodrÃ\xadguez']
# ['Mats', '', 'MÃ¸ller', 'DÃ¦hli']
# ['Sebastian', 'Polter']
# ['Ricardo', 'van', 'Rhijn']
# ['Nikola', 'MaraÅ¡']
# ['AndrÃ©s', 'Leandro', 'Castellanos', 'Serrano']
# ['AndrÃ©', 'Biyogo', 'Poko']
# ['Juan', 'Ferney', 'Otero', 'Tovar']
# ['Nicolai', 'MÃ¸ller', 'Boilesen']
# ['Diego', 'Lainez', 'Leyva']
# ['Yasser', 'Al', 'Shahrani']
# ['IsmaÃ«l', 'TiÃ©moko', 'DiomandÃ©']
# ['DÃ©nes', 'Dibusz']
# ['Damian', 'KÄ…dzior']
# ['Jonathan', 'Pablo', 'Bottinelli']
# ['Gareth', 'Barry']
# ['Robbie', 'Kruse']
# ['Cristian', 'Oscar', 'Bernardi']
# ['Ezequiel', 'Ã\x81vila']
# ['Nemanja', 'RadonjiÄ‡']
# ['Jeff', 'Nazario', 'Meire', 'Costinho']
# ['Javier', 'GÃ¼emez', 'LÃ³pez']
# ['Jordan', 'Jones']
# ['David', 'Guzman']
# ['Ã\x81ngel', 'ZaldÃ\xadvar', 'Caviedes']
# ['Simon', 'Tibbling']
# ['Joshua', 'Eduardo', 'SÃ¡', 'Madeira']
# ['Alexis', 'De', 'Sart']
# ['William', 'Owusu']
# ['Mohamed', 'Aberhoune']
# ['Jason', 'Puncheon']
# ['Marco', 'Stiepermann']
# ['Muhammet', 'Demir']
# ['Salvador', 'Sevilla', 'LÃ³pez']
# ['Benjamin', 'Kololli']
# ['Julian', 'BÃ¶rner']
# ['Ricardo', 'Ryller', 'Ribeiro', 'Lino', 'Silva']
# ['Bartosz', 'BiaÅ‚kowski']
# ['MartÃ\xadn', 'Maximiliano', 'Mantovani']
# ['Stefan', 'Ortega', 'Moreno']
# ['Serdar', 'GÃ¼rler']
# ['Joe', 'Bennett']
# ['Rui', 'Pedro', 'da', 'Rocha', 'Fonte']
# ['Ali', 'Adnan']
# ['Luis', 'Miguel', 'SÃ¡nchez', 'BenÃ\xadtez']
# ['Luca', 'Garritano']
# ['AdriÃ¡n', 'AndrÃ©s', 'Cubas']
# ['Jubal', 'Rocha', 'Mendes', 'Junior']
# ['Lebogang', 'Phiri']
# ['Thomas', 'Delaine']
# ['Jamie', 'Murphy']
# ['Alex', 'Martin', 'Frandeira', 'Ã\x81lvares']
# ['Rolando', 'GarcÃ\xada', 'GuerreÃ±o']
# ['Ken', 'Sema']
# ['JosÃ©', 'Antonio', 'Reyes', 'CalderÃ³n']
# ['Izet', 'HajroviÄ‡']
# ['Fernando', 'Henrique', 'Boldrin']
# ['Diego', 'Arturo', 'Peralta', 'GonzÃ¡lez']
# ['SebastiÃ£o', 'de', 'Freitas', 'Couto', 'JÃºnior']
# ['UroÅ¡', 'Ä†osiÄ‡']
# ['Fabio', 'Pisacane']
# ['Diego', 'Rossi']
# ['Roberto', 'Alvarado']
# ['Josh', 'Brownhill']
# ['Marlon', 'Javier', 'Piedrahita', 'LondoÃ±o']
# ['Maikel', 'van', 'der', 'Werff']
# ['Dom', 'Dwyer']
# ['Gonzalo', 'Bettini']
# ['Petar', 'Brlek']
# ['M.', 'Vanderlei', 'Paulino', 'Kenedy']
# ['Tobias', 'Pereira', 'Figueiredo']
# ['Erik', 'MorÃ¡n', 'Arribas']
# ['David', 'Batanero', 'PuigbÃ³']
# ['Gerrit', 'Holtmann']
# ['Antonio', 'Aldo', 'Caracciolo']
# ['Astrit', 'AjdareviÄ‡']
# ['ì\xa0•ì„±ë£¡', 'éƒ‘ä¿ŠçŽ„']
# ['Aboubakar', 'Kamara']
# ['Ayrton', 'Preciado']
# ['Milton', 'Nahuel', 'Valenzuela']
# ['Edimilson', 'Fernandes']
# ['Ledian', 'Memushaj']
# ['å·\x9då³¶', 'æ°¸å—£']
# ['Jakov', 'FilipoviÄ‡']
# ['Akaki', 'Gogia']
# ['Dominik', 'Schmidt']
# ['Rodrigo', 'Nascimento', 'FranÃ§a']
# ['Marvin', 'Friedrich']
# ['Tom', 'SchÃ¼tz']
# ['Stanislav', 'Tecl']
# ['Danijel', 'MiliÄ‡eviÄ‡']
# ['Oliver', 'Fink']
# ['Amro', 'Tarek', 'Abdel', 'Aziz']
# ['Matej', 'JonjiÄ‡']
# ['Bryan', 'Heynen']
# ['JoÃ£o', 'Pedro', 'Maturano', 'dos', 'Santos']
# ['Daniel', 'Rosero', 'Valencia']
# ['Rafael', 'Antonio', 'Caroca', 'Cordero']
# ['Elierce', 'Barbosa', 'de', 'Souza']
# ['Kevin', 'Bonifazi']
# ['Daniel', 'Williams']
# ['Ã“scar', 'Cabezas']
# ['Calvin', 'Stengs']
# ['Borja', 'Lasso', 'De', 'La', 'Vega']
# ['RÃ©mi', 'Oudin']
# ['Ribair', 'RodrÃ\xadguez', 'PÃ©rez']
# ['Jhasmani', 'Campos']
# ['Jordan', 'Rhodes']
# ['Ivan', 'Å\xa0unjiÄ‡']
# ['Rasmus', 'Thelander']
# ['Nikola', 'Moro']
# ['Mikael', 'Lustig']
# ['è¥¿å·\x9d', 'å‘¨ä½œ']
# ['Marco', 'Natanel', 'Torsiglieri']
# ['Petar', 'Å\xa0kuletiÄ‡']
# ['Maximiliano', 'Caire']
# ['Cristian', 'David', 'Lucchetti']
# ['Benik', 'Afobe']
# ['Carlos', 'Alberto', 'Alves', 'Garcia']
# ['JÃ©rÃ©mie', 'Bela']
# ['Maximiliano', 'Ã\x81ngel', 'Coronel']
# ['Ricardo', 'Jorge', 'Oliveira', 'Valente']
# ['JÃ©rÃ©my', 'Perbet']
# ['Alexander', 'MartÃ\xadn', 'Marquinho', 'Callens', 'AsÃ\xadn']
# ['Adriano', 'Facchini']
# ['Rui', 'Filipe', 'Caetano', 'Moura']
# ['Ariel', 'Mauricio', 'Rojas']
# ['Darragh', 'Lenihan']
# ['Barrie', 'McKay']
# ['Nabil', 'Ghilas']
# ['æŸ\x8få¥½', 'æ–‡']
# ['Dejan', 'DamjanoviÄ‡']
# ['FrÃ©dÃ©ric', 'Sammaritano']
# ['Vincenzo', 'Fiorillo']
# ['Richard', 'Keogh']
# ['Matheus', 'Simoneti', 'Bressaneli']
# ['Emrah', 'BaÅŸsan']
# ['JuliÃ¡n', 'AndrÃ©s', 'QuiÃ±ones', 'QuiÃ±ones']
# ['Alexis', 'Soto']
# ['Harry', 'Novillo']
# ['Chris', 'Brunt']
# ['David', 'McGoldrick']
# ['Karlo', 'Letica']
# ['Luis', 'Ricardo', 'Reyes', 'Moreno']
# ['Leopold', 'Zingerle']
# ['Florian', 'MÃ¼ller']
# ['Robert', 'Tesche']
# ['Urby', 'Emanuelson']
# ['JosÃ©', 'Javier', 'Abella', 'Fanjul']
# ['Tim', 'Kleindienst']
# ['Mustafa', 'Yumlu']
# ['Marvin', 'Matip']
# ['JosÃ©', 'Gabriel', 'Sambenito']
# ['Smail', 'Prevljak']
# ['David', 'von', 'Ballmoos']
# ['Anthony', 'Nwakaeme']
# ['David', 'Mackalister', 'Silva', 'Mosquera']
# ['Ivan', 'Oblyakov']
# ['Miguel', 'Ã\x81ngel', 'Fraga', 'Licona']
# ['Bilal', 'BaÅŸaÃ§Ä±koÄŸlu']
# ['Craig', 'Bryson']
# ['Darwin', 'Zamir', 'Andrade', 'Marmolejo']
# ['Eirik', '', 'Ulland', 'Andersen']
# ['Harlee', 'Dean']
# ['Eduardo', 'JosÃ©', 'Borges', 'Machado']
# ['Erick', 'Germain', 'Aguirre', 'Tafolla']
# ['MatÃ\xadas', 'Nahuel', 'Leiva', 'Esquivel']
# ['Tiago', 'Alves', 'Sales']
# ['Knowledge', 'Musona']
# ['Anthony', 'GonÃ§alves']
# ['Marc', 'TorrejÃ³n', 'Moya']
# ['CÃ©sar', 'Ignacio', 'Pinares', 'Tamayo']
# ['Raffaele', 'Pucino']
# ['Pablo', 'Edson', 'Barrera', 'Acosta']
# ['Jonas', 'Welson', 'Orsi', 'de', 'Meneses']
# ['Heltinho', 'Melo', 'Chaves']
# ['Bengali-FodÃ©', 'Koita']
# ['Roberto', 'Canella', 'SuÃ¡rez']
# ['Kieran', 'Lee']
# ['Ramahlwe', 'Mphahlele']
# ['Kevin', 'MÃ¼ller']
# ['Jefferson', 'Cuero', 'Castro']
# ['Jed', 'Wallace']
# ['JesÃºs', 'Enrique', 'SÃ¡nchez', 'GarcÃ\xada']
# ['Serhou', 'Guirassy']
# ['Lumor', 'Agbenyenu']
# ['Jack', 'Harrison']
# ['Stefan', 'Schwab']
# ['Dan', 'Burn']
# ['Marcel', 'Correia']
# ['Marlion', 'RÃ´mulo', 'Rolim', 'Nascimento']
# ['Sven', 'Michel']
# ['PaweÅ‚', 'Olkowski']
# ['Giorgi', 'Loria']
# ['Javier', 'Castellano', 'Betancor']
# ['Mohamed', 'Fouzair']
# ['CÃ©dric', 'YambÃ©rÃ©']
# ['Bubacarr', 'Sanneh']
# ['Harrison', 'Reed']
# ['Fernando', 'Dos', 'Santos', 'Pedro']
# ['Srdjan', 'PlavÅ¡iÄ‡']
# ['James', '', 'Morrison']
# ['Deiver', 'Machado']
# ['Paulo', 'CÃ©sar', 'DÃ\xadaz', 'Huincales']
# ['Abdul', 'Rahman', 'Khalili']
# ['Konstantin', 'Kerschbaumer']
# ['Slobodan', 'MedojeviÄ‡']
# ['Gaetano', 'Berardi']
# ['Thiago', 'Santos', 'Santana']
# ['Mario', 'MaloÄ\x8da']
# ['Guilherme', 'Ferreira', 'Pinto']
# ['Scott', 'Malone']
# ['Jake', 'Cooper']
# ['é˜¿éƒ¨', 'æµ©ä¹‹']
# ['RaÃºl', 'LizoÃ¡in', 'Cruz']
# ['Kyle', 'Lafferty']
# ['Wiliam', 'Carlos', 'Santoso', 'Sampaio']
# ['Tom', 'Beugelsdijk']
# ['Fredrik', 'Gulbrandsen']
# ['Luigi', 'Bruins']
# ['å¤§å³¶', 'åƒšå¤ª']
# ['Ã\x81lvaro', 'VÃ¡zquez', 'GarcÃ\xada']
# ['Mohammed', 'Al', 'Buraik']
# ['Raphael', 'Rossi', 'Branco']
# ['Gianluca', 'Litteri']
# ['MatÃ\xadas', 'NicolÃ¡s', 'RodrÃ\xadguez']
# ['Ceyhun', 'GÃ¼lselam']
# ['MickaÃ«l', 'Le', 'Bihan']
# ['Rijad', 'BajiÄ‡']
# ['Fernando', 'Navarro', 'MorÃ¡n']
# ['BartÅ‚omiej', 'DrÄ…gowski']
# ['Daniel', 'Bentley']
# ['Vitor', 'Gomes', 'Pereira', 'JÃºnior']
# ['Ricardo', 'Martins', 'de', 'AraÃºjo']
# ['Rafael', 'Mir', 'Vicente']
# ['Mathias', 'Autret']
# ['Adama', 'Valentin', 'Diomande']
# ['Benjamin', 'Jeannot']
# ['Zdravko', 'KuzmanoviÄ‡']
# ['DamiÃ¡n', 'Oscar', 'Lemos']
# ['David', 'MatÃ\xadas', 'Barbona']
# ['Facundo', 'AdriÃ¡n', 'Erpen']
# ['Sebastian', 'Andersson']
# ['Michael', 'Hector']
# ['Guillermo', 'Federico', 'Molins', 'Palmeiro']
# ['Lukas', 'Jutkiewicz']
# ['Thomas', 'Nicolas', 'Silva', 'Rangel']
# ['Kevin', 'Balanta']
# ['Vedat', 'Muriqi']
# ['Fernando', 'MÃ¡rquez']
# ['Hannes', 'Van', 'Der', 'Bruggen']
# ['Lasse', 'Nielsen']
# ['Alexis', 'Mac', 'Allister']
# ['Jonas', 'Gomes', 'de', 'Sousa']
# ['Rodrigo', 'Defendi']
# ['Luis', 'Quintana']
# ['Albert', 'Dorca', 'MasÃ³']
# ['Edgar', 'Prib']
# ['ì—¼ê¸°í›ˆ', 'å»‰åŸºå‹‹']
# ['Gleison', 'Bremer', 'Silva', 'Nascimento']
# ['Rodrigo', 'Alves', 'Soares']
# ['Joseph', 'Attamah']
# ['Ã\x81lvaro', 'Lemos', 'Collazo']
# ['Justin', 'Meram']
# ['Renato', 'Neto', 'Cardoso', 'Porto']
# ['Alexandre', 'Garcia', 'Guedes']
# ['Emmanuel', 'GarcÃ\xada']
# ['Abdullah', 'Ateef']
# ['Nir', 'Bitton']
# ['Simon', 'Thern']
# ['Nikola', 'KatiÄ‡']
# ['Oussama', 'Haddadi']
# ['Hamza', 'Choudhury']
# ['Mile', 'JedinÃ¡k']
# ['Djamel', 'Eddine', 'Benlamri']
# ['SebastiÃ¡n', 'Palacios']
# ['Mohammed', 'Khalil', 'Al', 'Owais']
# ['Osama', 'Rashid']
# ['George', 'Thorne']
# ['Aleksandar', 'PeÅ¡iÄ‡']
# ['Saido', 'Berahino']
# ['Raffaele', 'Bianco']
# ['Noah', 'Joel', 'Sarenren', 'Bazee']
# ['JÃ³n', 'DaÃ°i', 'BÃ¶Ã°varsson']
# ['Casper', 'De', 'Norre']
# ['Sean', 'Maguire']
# ['Lorenzo', 'Lollo']
# ['Luis', 'Eduardo', 'Delgado', 'Pacheco']
# ['Aleksandr', 'Kolomeytsev']
# ['JÃ¶rg', 'Siebenhandl']
# ['Stewart', 'Downing']
# ['Ã“scar', 'PÃ©rez', 'Rojas']
# ['Philipp', 'Klingmann']
# ['Leonardo', 'Mancuso']
# ['IÃ±igo', 'Eguaras', 'Ã\x81lvarez']
# ['Giorgi', 'Makaridze']
# ['Sidney', 'Sam']
# ['Lucas', 'Possignolo']
# ['Edson', 'Rodrigues', 'Farias']
# ['GastÃ³n', 'Campi']
# ['Alan', 'Hutton']
# ['Bruno', 'Manuel', 'AraÃºjo', 'Braga']
# ['Cristian', 'Ganea']
# ['Esteban', 'Rodrigo', 'Burgos']
# ['Saidy', 'Janko']
# ['Lorenzo', 'Pasciuti']
# ['Johan', 'Cavalli']
# ['Besart', 'Berisha']
# ['TomÃ¡s', 'MartÃ\xadnez']
# ['Hamza', 'Mendyl']
# ['Alberto', 'Benito', 'Correo']
# ['Guillermo', 'Varela']
# ['Simon', 'Lundevall']
# ['Jorge', 'RodrÃ\xadguez']
# ['Micheal', 'Azira']
# ['Alfredo', 'OrtuÃ±o', 'MartÃ\xadnez']
# ['Toma', 'BaÅ¡iÄ‡']
# ['Francis', 'Amuzu']
# ['Bismark', 'de', 'AraÃºjo', 'Ferreira']
# ['Jordan', 'AdÃ©oti']
# ['William', 'Fernando', 'da', 'Silva']
# ['Joe', 'Garner']
# ['Mauro', 'Matos']
# ['Cenk', 'Åžahin']
# ['ErtaÃ§', 'Ã–zbir']
# ['Javier', 'Ros', 'AÃ±Ã³n']
# ['Kelvin', 'Leerdam']
# ['Marco', 'Silvestri']
# ['Samir', 'Ujkani']
# ['Martin', 'Victor', 'Ã\x81lvares', 'Fachini']
# ['NÃºrio', 'Domingos', 'Matias', 'Fortuna']
# ['Stergos', 'Marinos']
# ['Grant', 'Leadbitter']
# ['SÃ©bastien', 'Pocognoli']
# ['Kasper', 'HÃ¤mÃ¤lÃ¤inen']
# ['Yairo', 'Yesid', 'Moreno', 'BerrÃ\xado']
# ['PÃ¥l', 'AndrÃ©', 'Helland']
# ['Marcus', 'Pedersen']
# ['VÃ\xadctor', 'Manuel', 'CasadesÃºs', 'CastaÃ±o']
# ['Jordan', '', 'Archer']
# ['Pierre', 'Emmanuel', 'Sagna']
# ['Jonathan', 'Diego', 'MenÃ©ndez']
# ['æŸ\x8fæœ¨', 'é™½ä»‹']
# ['Lucas', 'Henrique', 'da', 'Silva']
# ['Nemanja', 'MihajloviÄ‡']
# ['Steve', 'Breitkreuz']
# ['Didier', 'Delgado']
# ['Sean', '', 'Johnson']
# ['Francisco', 'Reis', 'Ferreira']
# ['Claudio', 'Daniel', 'Bieler']
# ['Michael', 'Hefele']
# ['Danny', 'Blum']
# ['UÄŸur', 'UÃ§ar']
# ['NehuÃ©n', 'Mario', 'Paz']
# ['Bernardo', 'VÃ\xadctor', 'Cruz', 'Torres']
# ['Mirko', 'Gori']
# ['Rafael', 'Robayo']
# ['Andriy', 'Totovytskyi']
# ['Oliver', 'HÃ¼sing']
# ['Andrea', 'Seculin']
# ['Marco', 'Sangalli', 'Fuentes']
# ['Marcus', 'Danielsson']
# ['ê¹€ì˜\x81ê¶Œ', 'é‡‘è‹±æ\x9dƒ']
# ['Miguel', 'Barbieri']
# ['GaÃ«tan', 'Belaud']
# ['Ricardo', 'Abel', 'Barbosa', 'Ferreira']
# ['Kosta', 'Barbarouses']
# ['JosÃ©', 'IvÃ¡n', 'RodrÃ\xadguez']
# ['Cristian', 'Battocchio']
# ['Will', 'Grigg']
# ['Mathieu', 'Coutadeur']
# ['Raoul', 'Petretta']
# ['Steve', 'De', 'Ridder']
# ['Macario', 'AndrÃ©', 'Louro', 'Padilha']
# ['Birger', 'Solberg', 'Meling']
# ['Nwankwo', 'Emeka', 'Obiora']
# ['Antonio', 'JosÃ©', 'RodrÃ\xadguez', 'DÃ\xadaz']
# ['Alfredo', 'SaldÃ\xadvar', 'Medina']
# ['Yoane', 'Wissa']
# ['Roberto', 'AndrÃ©s', 'Ovelar', 'Maldonado']
# ['Daniele', 'Dessena']
# ['Nasser', 'Ali', 'Al', 'Shamrani']
# ['SÃ\xadlvio', 'Manuel', 'Azevedo', 'Ferreira', 'SÃ¡', 'Pereira']
# ['Marcos', 'Bolados', 'Hidalgo']
# ['Diogo', 'Nathan', 'Peixe', 'Barreto']
# ['Sebastian', 'Griesbeck']
# ['Luis', 'Manuel', 'GarcÃ\xada', 'Palomera']
# ['Jakub', 'Brabec']
# ['Ã‚nderson', 'Miguel', 'da', 'Silva']
# ['ä¼Šè—¤', 'é\x81”å“‰']
# ['Lukas', 'Spalvis']
# ['Aitor', 'GarcÃ\xada', 'Flores']
# ['Juan', 'Carlos', 'Paredes']
# ['Marco', 'Varnier']
# ['Sam', 'Morsy']
# ['Floyd', 'AyitÃ©']
# ['Franco', 'Zuculini']
# ['Bruno', 'Daniel', 'Castro', 'Moreira']
# ['Carlos', 'Eduardo', 'Fierro', 'Guerrero']
# ['Michael', 'Morrison']
# ['Paul', 'Gallagher']
# ['Dany', 'Nounkeu']
# ['Taleb', 'Tawatha']
# ['Daniel', 'Toribio', 'GutiÃ©rrez']
# ['Trevor', 'Carson']
# ['Hosam', 'Aiesh']
# ['Ruud', 'Boffin']
# ['UroÅ¡', 'MatiÄ‡']
# ['Lautaro', 'Giannetti']
# ['Dejan', 'SorgiÄ‡']
# ['JosÃ©', 'Manuel', 'ArnÃ¡iz', 'DÃ\xadaz']
# ['Dominik', 'Kaiser']
# ['Alessandro', 'Crescenzi']
# ['Darwin', 'Adelso', 'CerÃ©n', 'Delgado']
# ['Yahia', 'Sulaiman', 'Al', 'Shehri']
# ['Renato', 'de', 'AraÃºjo', 'Chaves', 'JÃºnior']
# ['Abdulwahid', 'Sissoko']
# ['Te', 'Se', 'Chong']
# ['Domilson', 'Cordeiro', 'dos', 'Santos']
# ['Ruben', 'YttergÃ¥rd', 'Jenssen']
# ['Josh', 'Onomah']
# ['Pedro', 'Camilo', 'Franco', 'Ulloa']
# ['Jeremy', 'Dudziak']
# ['Wilfried', 'Zahibo']
# ['Javier', 'FabiÃ¡n', 'Toledo']
# ['Christophe', 'Diandy']
# ['Artur', 'JÄ™drzejczyk']
# ['Wagner', 'da', 'Silva', 'Souza']
# ['Mauro', 'Manotas']
# ['Aderllan', 'de', 'Jesus', 'Santos']
# ['Juan', 'Daniel', 'Roa', 'Reyes']
# ['Daniel', 'HernÃ¡ndez', 'Santos']
# ['Aziz', 'Bouhaddouz']
# ['Niklas', 'Hauptmann']
# ['Leart', 'Paqarada']
# ['David', 'Kinsombi']
# ['Riccardo', 'Improta']
# ['Erick', 'EstÃ©fano', 'Torres', 'Padilla']
# ['Fousseni', 'DiabatÃ©']
# ['Steeven', 'Willems']
# ['Salih', 'Ã–zcan']
# ['Marco', 'Caligiuri']
# ['David', 'Moberg', 'Karlsson']
# ['Ousmane', 'DramÃ©']
# ['Javier', 'Puado', 'DÃ\xadaz']
# ['Carlos', 'Alberto', 'Henao', 'SÃ¡nchez']
# ['Jeisson', 'AndrÃ©s', 'Palacios', 'Palacios']
# ['Maximilian', 'Wittek']
# ['Marcel', 'Hartel']
# ['Martin', 'FrÃ½dek']
# ['Ã\x81lvaro', 'David', 'Montero', 'Perales']
# ['Eirik', 'Hestad']
# ['Mirko', 'Drudi']
# ['Sebastian', 'Schonlau']
# ['Patricio', 'Daniel', 'Toranzo']
# ['Daniel', 'Lopes', 'Amora']
# ['MatÄ›j', 'Hanousek']
# ['Timothy', 'Derijck']
# ['Edwar', 'LÃ³pez']
# ['Anuar', 'Mohamed', 'Tuhami']
# ['Koray', 'GÃ¼nter']
# ['Anders', 'Ã…gnes', '', 'Konradsen']
# ['Gabriel', 'Arturo', 'Torres', 'Tejada']
# ['æµ…é‡Ž', 'ä½\x90è—¤']
# ['IonuÅ£', 'Nedelcearu']
# ['Leonardo', 'Fabio', 'Castro', 'Loaiza']
# ['Scott', 'McKenna']
# ['Danny', 'Fox']
# ['Steven', 'Birnbaum']
# ['Christopher', 'Maxwell']
# ['Denis', 'Stracqualursi']
# ['Waldemar', 'Sobota']
# ['åœŸå±…', 'è\x81–çœŸ']
# ['JosÃ©', 'MarÃ\xada', 'MartÃ\xadn', 'Bejarano']
# ['Tom', 'Weilandt']
# ['Andre', 'Wisdom']
# ['Korey', 'Smith']
# ['Mathieu', 'Bodmer']
# ['FodÃ©', 'Ballo-TourÃ©']
# ['ì\xa0•ìš´', 'Woon', 'Jeong']
# ['Luis', 'Ã\x81ngel', 'Mendoza', 'Escamilla']
# ['Marco', 'Davide', 'Faraoni']
# ['Donis', 'Avdijaj']
# ['Juan', 'DomÃ\xadnguez', 'Lamas']
# ['Mamadou', 'Sylla', 'Diallo']
# ['MatÃ\xadas', 'IbÃ¡Ã±ez']
# ['Fabian', 'Giefer']
# ['Dylan', 'Batubinsika']
# ['é‡‘å\xad\x90', 'ç¿”å¤ª']
# ['Edson', 'GÃ©rson', 'Torres', 'Guerra']
# ['Aleandro', 'Rosi']
# ['Eduardo', 'LÃ³pez']
# ['Stephan', 'Hain']
# ['Juan', 'Caicedo']
# ['Pape', '', "N'Diaye", 'SouarÃ©']
# ['Graham', 'Carey']
# ['Niall', 'McGinn']
# ['LÃ©o', 'Lacroix']
# ['Iliass', 'Bel', 'Hassani']
# ['Luciano', 'Lollo']
# ['Florian', 'Jungwirth']
# ['Jose', 'Miguel', 'Silbeira']
# ['Evan', 'Bush']
# ['Antonio', 'Campillo', 'Medina']
# ['Fabrice', 'Ondoa']
# ['Federico', 'Mancinelli']
# ['Killian', 'Overmeire']
# ['Hugo', 'Armando', 'Campagnaro']
# ['Nikola', 'Ä\x90urÄ‘iÄ‡']
# ['Hugo', 'Filipe', 'da', 'Costa', 'Oliveira']
# ['RaÃºl', 'Alberto', 'Loaiza', 'Morelos']
# ['Brilliant', 'Khuzwayo']
# ['Alessandro', 'Salvi']
# ['Jorge', 'Alejandro', 'ZÃ¡rate', 'Careaga']
# ['Sebastiaan', 'Bornauw']
# ['Ã“scar', 'RodrÃ\xadguez', 'Arnaiz']
# ['Michael', 'Parkhurst']
# ['Marek', 'RodÃ¡k']
# ['Rodrigo', 'RÃ\xados', 'Lozano']
# ['LukÃ¡Å¡', 'MareÄ\x8dek']
# ['Arnaud', 'Nordin']
# ['Theoson', 'Jordan', 'Siebatcheu']
# ['Joel', 'Castro', 'Pereira']
# ['Sulley', 'Ali', 'Muntari']
# ['AurÃ©lien', 'TchouamÃ©ni']
# ['Jhonatan', 'Luiz', 'da', 'Siqueira']
# ['Rodrigo', 'Eduardo', 'EcheverrÃ\xada', 'SÃ¡ez']
# ['Alessandro', 'Bernardini']
# ['Benno', 'Schmitz']
# ['Dimitri', 'Bisoli']
# ['Idrissa', 'Sylla']
# ['Michael', '', 'Dawson']
# ['Ahmed', 'Fathy', 'Abdel', 'Meneim', 'Ibrahim']
# ['Eduard', 'LÃ¶wen']
# ['Robert', 'Green']
# ['LÃ©andre', 'Tawamba']
# ['Pablo', 'Ignacio', 'Galdames', 'MillÃ¡n']
# ['Marius', 'MÃ¼ller']
# ['Unai', 'Medina', 'PÃ©rez']
# ['Sami', 'Allagui']
# ['AdriÃ¡n', 'JesÃºs', 'BastÃ\xada', 'Beruzzi']
# ['Tobias', 'Kempe']
# ['Zargo', 'TourÃ©']
# ['Fidel', 'Chaves', 'de', 'la', 'Torre']
# ['OndÅ™ej', 'KolÃ¡Å™']
# ['James', 'Alexander', 'Lawrence']
# ['Jamie', 'Maclaren']
# ['Artur', 'Sobiech']
# ['Anco', 'Jansen']
# ['Francesco', 'Zampano']
# ['Kevin', 'Stuhr-Ellegaard']
# ['Mark', 'Bunn']
# ['Juan', 'JosÃ©', 'CiÃ©rcoles', 'Sagra']
# ['Denis', 'Odoi']
# ['Joel', 'Ngandu', 'Kayamba']
# ['Michel', 'Morganella']
# ['Volkan', 'FÄ±ndÄ±klÄ±']
# ['Denilson', 'Pereira', 'Junior']
# ['Juan', 'SebastiÃ¡n', 'Villota', 'Vargas']
# ['Ismael', 'LÃ³pez', 'Blanco']
# ['Blas', 'Riveros']
# ['Issam', 'Chebake']
# ['Franz', 'Hermann', 'Schultz', 'RamÃ\xadrez']
# ['Filip', 'Kurto']
# ['Sergio', 'AndrÃ©s', 'Mosquera', 'Zapata']
# ['Felipe', 'Ignacio', 'Seymour', 'Dobud']
# ['Reza', 'Ghoochannejhad', 'Nournia']
# ['Riccardo', 'Maniero']
# ['Norman', 'Theuerkauf']
# ['Frank', 'Fielding']
# ['Carlos', 'Lampe']
# ['Ayaz', 'Guliev']
# ['Luciano', 'Renato', 'Cacheira', 'SÃ¡']
# ['Alberto', 'JimÃ©nez', 'BenÃ\xadtez']
# ['Joseph-Claude', 'Gyau']
# ['Benedikt', 'Gimber']
# ['Camilo', 'Bryan', 'RodrÃ\xadguez', 'Pedraza']
# ['KÃ©vin', 'FortunÃ©']
# ['é©¹äº•', 'å–„æˆ\x90']
# ['Niclas', 'Eliasson']
# ['Levent', 'GÃ¼len']
# ['Gleidionor', 'Figueiredo', 'Pinto', 'JÃºnior']
# ['Selim', 'Ay']
# ['Yesus', 'Segundo', 'Cabrera', 'RamÃ\xadrez']
# ['Ahmed', 'El', 'Messaoudi']
# ['Marcos', 'Mauro', 'LÃ³pez']
# ['Amir', 'Rrahmani']
# ['Calogero', 'Rizzuto']
# ['RoldÃ£o', 'Tony', 'Riso', 'Cardenas']
# ['Kelyn', 'Rowe']
# ['Yonathan', 'Emanuel', 'Cabral']
# ['Badra', 'Ali', 'SangarÃ©']
# ['Dustin', 'Bomheuer']
# ['Lee', 'Gregory']
# ['Alexandre', 'Geijo', 'Pazos']
# ['Nathan', 'Byrne']
# ['Anderson', 'JosÃ©', 'Lopes', 'de', 'Souza']
# ['Antonio', 'Rosati']
# ['ìž¥í˜„ìˆ˜', 'å¼\xa0è´¤ç§€']
# ['Isaac', 'Sackey']
# ['Jannik', 'Huth']
# ['Terence', 'Mpho', 'Makola']
# ['Janis', 'Blaswich']
# ['Rafael', 'LÃ³pez', 'GÃ³mez']
# ['Lefteris', 'Choutesiotis']
# ['Evangelos', 'Oikonomou']
# ['Fabio', 'Depaoli']
# ['Steven', '', 'Taylor']
# ['Bruno', 'Martella']
# ['Maciej', 'DÄ…browski']
# ['Pedro', 'Filipe', 'Figueiredo', 'Rodrigues']
# ['Elias', 'Cobbaut']
# ['Cameron', 'Carter-Vickers']
# ['Nicola', 'Dalmonte']
# ['Luiz', 'Fernando', 'da', 'Silva', 'Monte']
# ['Robin', 'PrÃ¶pper']
# ['Mohamed', '', 'Hamdy', 'Sharaf']
# ['Walter', 'Alberto', 'LÃ³pez', 'Gasco']
# ['Pierre-Yves', 'Hamel']
# ['Facundo', 'PÃ\xadriz']
# ['Per', 'Kristian', 'Worre', 'BrÃ¥tveit']
# ['Javier', 'Guerra', 'RodrÃ\xadguez']
# ['Maximilian', 'Sax']
# ['Daniel', 'Keita-Ruel']
# ['Maksym', 'Koval']
# ['Ali', 'Gholizadeh']
# ['é“ƒæœ¨', 'å¤§è¼”']
# ['Fernando', 'Pellegrino']
# ['Oussama', 'Darfalou']
# ['Ezri', 'Konsa']
# ['Ventura', 'Alvarado']
# ['Patricio', 'RodrÃ\xadguez']
# ['Daniel', 'Gordon']
# ['Felipe', 'Castaldo', 'Curcio']
# ['ThÃ©o', 'Valls']
# ['Nicolas', 'Haas']
# ['Justen', 'Glad']
# ['Will', 'Bruin']
# ['Joe', 'Benny', 'Corona', 'CrespÃ\xadn']
# ['Gianmarco', 'Zigoni']
# ['Miroslav', 'RadoviÄ‡']
# ['Louis', 'Elliott', 'Moult']
# ['JoaquÃ\xadn', 'MatÃ\xadas', 'Ardaiz', 'de', 'los', 'Santos']
# ['Ortwin', 'De', 'Wolf']
# ['Jonathan', 'Martins', 'Pereira']
# ['Alan', 'Jonathan', 'PatrÃ\xadcio', 'Botelho']
# ['Javier', 'MuÃ±oz', 'JimÃ©nez']
# ['Lucas', 'Ceballos']
# ['Jack', 'Hunt']
# ['Laurens', 'De', 'Bock']
# ['AdriÃ¡n', 'Alexei', 'Aldrete', 'RodrÃ\xadguez']
# ['Bruno', 'Batista', 'Pires']
# ['Jean-Charles', 'Castelletto']
# ['Waleed', 'Bakhashwain']
# ['Ayman', 'Ashraf']
# ...
# ['Daniel', 'Castelo', 'Podence']
# ['Rodrigo', 'Bentancur', 'ColmÃ¡n']
# ['Christian', 'Pulisic']
# ['Yeray', 'Ã\x81lvarez', 'LÃ³pez']
# ['Davide', 'Calabria']
# ['Ben', 'Chilwell']
# ['Pierre', 'Lees-Melou']
# ['Ronaldo', 'Diego', 'Esler', 'Domingues']
# ['Claudio', 'Nuno', 'CoÃ\xadntra', 'Calegari']
# ['Everton', 'Jorge', 'SimÃ£o', 'Resende']
# ['Sidney', 'AdriÃ¡n', 'Pessoa', 'Vidigal']
# ['Alban', 'Lafont']
# ['Ruslan', 'Malinovskyi']
# ['Amine', 'Harit']
# ['Wesley', 'Moraes', 'Ferreira', 'da', 'Silva']
# ['Achraf', 'Hakimi', 'Mouh']
# ['Manuel', 'Lazzari']
# ['Diadie', 'SamassÃ©kou']
# ['Cengiz', 'Ãœnder']
# ['David', 'Neres', 'Campos']
# ['Theo', '', 'Walcott']
# ['Samir', 'Nasri']
# ['Luis', 'Antonio', 'Valencia', 'Mosquera']
# ['Andrea', 'Masiello']
# ['Steven', 'Defour']
# ['JosÃ©', 'Miguel', 'da', 'Rocha', 'Fonte']
# ['Daniel', 'Andre', 'Sturridge']
# ['Daniel', 'Wass']
# ['David', 'Ospina', 'RamÃ\xadrez']
# ['Pontus', 'Wernbloom']
# ['Ã\x81ngel', 'LuÃ\xads', 'RodrÃ\xadguez', 'DÃ\xadaz']
# ['Francisco', 'Casilla', 'CortÃ©s']
# ['Etienne', 'Capoue']
# ['Javier', 'HernÃ¡ndez', 'BalcÃ¡zar']
# ['Eder', 'Citadin', 'Martins']
# ['SÃ©amus', 'Coleman']
# ['Marcelo', 'AntÃ´nio', 'Guedes', 'Filho']
# ['Adam', 'David', 'Lallana']
# ['é•·è°·', 'éƒ¨èª\xa0']
# ['Stevan', 'JovetiÄ‡']
# ['Mamadou', 'Sakho']
# ['Fabian', 'Delph']
# ['Gabriel', 'IvÃ¡n', 'Mercado']
# ['Bruno', '', 'Soriano', 'Llido']
# ['Fernando', 'Francisco', 'Reges']
# ['Lucas', 'David', 'Pratto']
# ['Sofiane', 'Feghouli']
# ['Mariano', 'Ferreira', 'Filho']
# ['Nikola', 'KaliniÄ‡']
# ['Ron-Robert', 'Zieler']
# ['Kwadwo', 'Asamoah']
# ['Igor', 'Smolnikov']
# ['Alex', 'Teixeira', 'dos', 'Santos']
# ['Ryad', 'Boudebouz']
# ['Victor', 'Wanyama']
# ['Sebastian', 'Rudy']
# ['Francis', 'Coquelin']
# ['Markel', 'Susaeta', 'Laskurain']
# ['Josef', 'de', 'Souza', 'Dias']
# ['Benjamin', 'HÃ¼bner']
# ['Jack', 'Wilshere']
# ['Vicente', 'Iborra', 'de', 'la', 'Fuente']
# ['Rafael', 'Pereira', 'da', 'Silva']
# ['Callum', 'Wilson']
# ['Daniel', 'Caligiuri']
# ['Benjamin', 'Stambouli']
# ['Ross', 'Barkley']
# ['Danilo', 'Luiz', 'da', 'Silva']
# ['Michael', 'Gregoritsch']
# ['Manuel', 'Agudo', 'DurÃ¡n']
# ['JosÃ©', 'Ã\x81ngel', 'GÃ³mez', 'CampaÃ±a']
# ['Hans', 'Vanaken']
# ['Steven', 'Berghuis']
# ['Mark', 'Uth']
# ['Djibril', 'SidibÃ©']
# ['Milan', 'Badelj']
# ['David', 'LÃ³pez', 'Silva']
# ['GastÃ³n', 'Exequiel', 'RamÃ\xadrez', 'Pereyra']
# ['Jordan', 'Veretout']
# ['Faustino', 'Marcos', 'Alberto', 'Rojo']
# ['Jeffrey', 'Gouweleeuw']
# ['Diego', 'Demme']
# ['Gerard', 'Deulofeu', 'LÃ¡zaro']
# ['Sergi', 'Darder', 'Moll']
# ['James', 'Tarkowski']
# ['Jannik', 'Vestergaard']
# ['Davy', 'Klaassen']
# ['JosÃ©', 'LuÃ\xads', 'Mendes', 'Andrade']
# ['Loris', 'Karius']
# ['Nick', 'Pope']
# ['Alejandro', 'Pozuelo', 'Melero']
# ['John', 'Anthony', 'Brooks']
# ['Santiago', 'Arias', 'Naranjo']
# ['Roque', 'Mesa', 'Quevedo']
# ['Kurt', 'Happy', 'Zouma']
# ['MÃ¡rio', 'Rui', 'Silva', 'Duarte']
# ['Willi', 'Orban']
# ['Denis', 'SuÃ¡rez', 'FernÃ¡ndez']
# ['Karim', 'Rekik']
# ['Daniele', 'Baselli']
# ['Zouhair', 'Feddal']
# ['Luka', 'MilivojeviÄ‡']
# ['Sergio', 'Rico', 'GonzÃ¡lez']
# ['Michael', 'Keane']
# ['Roger', 'MartÃ\xad', 'Salvador']
# ['Guido', 'Pizarro']
# ['Sead', 'KolaÅ¡inac']
# ['JoaquÃ\xadn', 'Correa']
# ['DuvÃ¡n', 'Zapata']
# ['Lucas', 'Alario']
# ['Davide', 'Zappacosta']
# ['Allan', 'Saint-Maximin']
# ['Diego', 'Carlos', 'Santos', 'Silva']
# ['Martin', 'DÃºbravka']
# ['Harry', 'Winks']
# ['Franco', 'Cervi']
# ['Valentin', 'Rongier']
# ['David', 'Soria', 'SolÃ\xads']
# ['Karl', 'Brillant', 'Toko', 'Ekambi']
# ['Dyego', 'Wilverson', 'Ferreira', 'Sousa']
# ['Cristian', 'David', 'PavÃ³n']
# ['MartÃ\xadn', 'CampaÃ±a']
# ['Abdou', 'Diallo']
# ['Marcos', 'Llorente', 'Moreno']
# ['Benjamin', 'VerbiÄ\x8d']
# ['Maximilian', 'Eggestein']
# ['Thilo', 'Kehrer']
# ['Gonzalo', 'NicolÃ¡s', 'MartÃ\xadnez']
# ['Benjamin', 'Pavard']
# ['Lucas', 'Tousart']
# ['Marko', 'DmitroviÄ‡']
# ['Francisco', 'das', 'Chagas', 'Soares', 'dos', 'Santos']
# ['Lorenzo', 'Pellegrini']
# ['Ferland', 'Mendy']
# ['Andrey', 'Lunev']
# ['Maikel', 'Renan', 'Catarino', 'Fagundes']
# ['A.', 'Benjamin', 'Chiamuloira', 'Paes']
# ['Melvin', 'Luan', 'Parrela', 'PorfÃ\xadrio']
# ['Bernard', 'Gabriel', 'PrestÃ£o', 'Chaves']
# ['Luan', 'VÃ¡gner', 'Boas', 'Macedo']
# ['Franck', 'Yannick', 'KessiÃ©']
# ['Trent', 'Alexander-Arnold']
# ['Lautaro', 'MartÃ\xadnez']
# ['Jadon', 'Sancho']
# ['Raphael', 'Dias', 'Belloli']
# ['Lucas', 'Tolentino', 'Coelho', 'de', 'Lima']
# ['Federico', 'Chiesa']
# ['RÃºben', 'Alves', 'Dias']
# ['Ã‰der', 'Gabriel', 'MilitÃ£o']
# ['Viktor', 'Tsygankov']
# ['Lorenzo', 'MorÃ³n', 'GarcÃ\xada']
# ['Åžtefan', 'Daniel', 'Radu']
# ['Martin', 'Å\xa0krtel']
# ['RaÃºl', 'GarcÃ\xada', 'Escudero']
# ['Diego', 'HernÃ¡n', 'VÃ¡leri']
# ['Domenico', 'Criscito']
# ['Antonio', 'Candreva']
# ['Sergio', 'GermÃ¡n', 'Romero']
# ['IvÃ¡n', 'Marcano', 'Sierra']
# ['Pedro', 'LeÃ³n', 'SÃ¡nchez', 'Gil']
# ['Valter', 'Birsa']
# ['Ignacio', 'Piatti']
# ['KÃ©vin', 'Gameiro']
# ['Augusto', 'MatÃ\xadas', 'FernÃ¡ndez']
# ['Mathieu', 'Valbuena']
# ['BeÃ±at', 'Etxebarria', 'Urkiaga']
# ['Ignacio', 'Monreal', 'Eraso']
# ['Vitorino', 'Gabriel', '', 'Pacheco', 'Antunes']
# ['Alexandre', 'Rodrigues', 'da', 'Silva']
# ['Sidnei', 'Rechel', 'da', 'Silva', 'JÃºnior']
# ['Anthony', 'Modeste']
# ['Adil', 'Rami']
# ['Diego', 'Perotti']
# ['Ã–mer', 'Toprak']
# ['Mateo', 'Pablo', 'Musacchio']
# ['Sven', 'Ulreich']
# ['Yann', 'GÃ©rard', "M'Vila"]
# ['Ignacio', 'Camacho', 'Barnola']
# ['Nicolas', "N'Koulou"]
# ['Manuel', 'Lanzini']
# ['é¦™å·\x9d', 'çœŸå\x8f¸']
# ['Vicente', 'Guaita', 'Panadero']
# ['Luuk', 'de', 'Jong']
# ['Chris', 'Smalling']
# ['Iago', 'FalquÃ©', 'Silva']
# ['Jeroen', 'Zoet']
# ['Daley', 'Blind']
# ['Maicon', 'Pereira', 'Roque']
# ['Roberto', 'Pereyra']
# ['Ricardo', 'RodrÃ\xadguez']
# ['GermÃ¡n', 'Alejandro', 'Pezzella']
# ['Daniel', 'Didavi']
# ['AndrÃ©', 'Gomes', 'Magalhaes', 'de', 'Almeida']
# ['Andriy', 'Yarmolenko']
# ['Sergio', 'Enrich', 'Ametller']
# ['Pavel', 'KadeÅ™Ã¡bek']
# ['HÃ©ctor', 'BellerÃ\xadn', 'Moruno']
# ['TomÃ¡Å¡', 'VaclÃ\xadk']
# ['Eran', 'Zahavi']
# ['Ã\x8dÃ±igo', 'MartÃ\xadnez', 'Berridi']
# ['Michy', 'Batshuayi', 'Tunga']
# ['Cristian', 'PortuguÃ©s', 'Manzanera']
# ['ä¹¾', 'è²´å£«']
# ['Bernard', '', 'AnÃ\xadcio', 'Caldeira', 'Duarte']
# ['Ben', 'Davies']
# ['Luke', 'Shaw']
# ['Taras', 'Stepanenko']
# ['Manuel', 'Trigueros', 'MuÃ±oz']
# ['Leandro', 'Paredes']
# ['Carlos', 'Arturo', 'Bacca', 'Ahumada']
# ['Yussuf', 'Yurary', 'Poulsen']
# ['Hakan', 'Ã‡alhanoÄŸlu']
# ['Emre', 'Can']
# ['Nathan', 'AkÃ©']
# ['Frederico', 'R.', 'de', 'Paula', 'Santos']
# ['Fernando', 'Pacheco', 'Flores']
# ['Juan', 'Fernando', 'Quintero']
# ['Elseid', 'Hysaj']
# ['Morgan', 'Sanson']
# ['NicolÃ¡s', 'Alejandro', 'Tagliafico']
# ['AndrÃ©', 'Filipe', 'Tavares', 'Gomes']
# ['JosÃ©', 'LuÃ\xads', 'GayÃ\xa0', 'PeÃ±a']
# ['Santiago', 'Mina', 'Lorenzo']
# ['Marcos', 'Paulo', 'Mesquita', 'Lopes']
# ['Andreas', 'Christensen']
# ['Franco', 'Armani']
# ['GerÃ³nimo', 'Rulli']
# ['Keita', 'BaldÃ©']
# ['IÃ±aki', 'Williams', 'Arthuer']
# ['Jean', 'MichaÃ«l', 'Seri']
# ['Rafael', 'Alexandre', 'Fernandes', 'Ferreira', 'da', 'Silva']
# ['Mahmoud', 'Dahoud']
# ['Matias', 'Vecino']
# ['Ante', 'RebiÄ‡']
# ['Mattia', 'Caldara']
# ['RaÃºl', 'Michel', 'Melo', 'da', 'Silva']
# ['Mariano', 'DÃ\xadaz', 'MejÃ\xada']
# ['Julian', 'Weigl']
# ['Marcos', 'Javier', 'AcuÃ±a']
# ['David', 'Villa', 'SÃ¡nchez']
# ['James', 'Philip', 'Milner']
# ['LuÃ\xads', 'Carlos', 'Almeida', 'da', 'Cunha']
# ['JesÃºs', 'Navas', 'GonzÃ¡lez']
# ['Santiago', 'Cazorla', 'GonzÃ¡lez']
# ['BafÃ©timbi', 'Gomis']
# ['Å\x81ukasz', 'FabiaÅ„ski']
# ['Renato', '', 'Soares', 'de', 'Oliveira', 'Augusto']
# ['Carlos', 'Alberto', 'Vela', 'Garrido']
# ['Danny', 'Rose']
# ['Erik', 'Lamela']
# ['Å\x81ukasz', 'Piszczek']
# ['Kevin-Prince', 'Boateng']
# ['Sven', 'Bender']
# ['Simon', 'Thorup', 'KjÃ¦r']
# ['Benedikt', 'HÃ¶wedes']
# ['Fernando', 'Muslera']
# ['Ljubomir', 'Fejsa']
# ['Cristhian', 'Ricardo', 'Stuani', 'Curbelo']
# ['Lars', 'Stindl']
# ['Fyodor', 'Smolov']
# ['Steven', "N'Kemboanza", 'Mike', 'Christopher', 'Nzonzi']
# ['Kevin', 'Trapp']
# ['Givanildo', 'Vieira', 'de', 'Souza']
# ['Iker', 'Muniain', 'GoÃ±i']
# ['Stephan', 'El', 'Shaarawy']
# ['Eduardo', 'Antonio', 'Salvio']
# ['Javier', 'MatÃ\xadas', 'Pastore']
# ['Ander', 'Herrera', 'AgÃ¼era']
# ['Mario', 'GÃ¶tze']
# ['Kevin', 'Vogt']
# ['Alphonse', 'Areola']
# ['JesÃºs', 'Corona']
# ['Dejan', 'Lovren']
# ['Simone', 'Verdi']
# ['DuÅ¡an', 'TadiÄ‡']
# ['Charles', 'Mariano', 'ArÃ¡nguiz', 'Sandoval']
# ['Granit', 'Xhaka']
# ['VÃ\xadctor', 'MachÃ\xadn', 'PÃ©rez']
# ['Lucas', 'Digne']
# ['Nico', 'Schulz']
# ['Kevin', 'Volland']
# ['Josip', 'IliÄ\x8diÄ‡']
# ['Faouzi', 'Ghoulam']
# ['JoÃ£o', 'MÃ¡rio', 'Naval', 'Costa', 'Eduardo']
# ['Ã\x81ngel', 'Correa']
# ['Daniel', 'GarcÃ\xada', 'Carrillo']
# ['Marcelo', 'BrozoviÄ‡']
# ['JosÃ©', 'Luis', 'Morales', 'Nogales']
# ['TiÃ©mouÃ©', 'Bakayoko']
# ['Victor', 'Nilsson', 'LindelÃ¶f']
# ['Daniel', 'Ceballos', 'FernÃ¡ndez']
# ['RÃºben', 'Diogo', 'da', 'Silva', 'Neves']
# ['Eric', 'Bailly']
# ['Pablo', 'Fornals', 'Malla']
# ['Gelson', 'Dany', 'Batalha', 'Martins']
# ['Onyinye', 'Wilfred', 'Ndidi']
# ['Moussa', 'Marega']
# ['NÃ©lson', 'Cabral', 'Semedo']
# ['Manuel', 'Obafemi', 'Akanji']
# ['Leon', 'Bailey', 'Butler']
# ['Laureano', 'Thomas', 'Santeiro', 'Marre']
# ['Miguel', 'AlmirÃ³n']
# ['Luka', 'JoviÄ‡']
# ['Kai', 'Havertz']
# ['JosÃ©', 'Manuel', '', 'Reina', 'PÃ¡ez']
# ['Petr', 'ÄŒech']
# ['Aritz', 'Aduriz', 'Zubeldia']
# ['Daniel', 'Alves', 'da', 'Silva']
# ['HÃ©ctor', 'Miguel', 'Herrera', 'LÃ³pez']
# ['Lucas', 'Rodrigo', 'Biglia']
# ['Fabio', 'Quagliarella']
# ['Moussa', 'Sidi', 'Yaya', 'DembÃ©lÃ©']
# ['JoÃ£o', 'Filipe', 'Iria', 'Santos', 'Moutinho']
# ['Francesc', 'FÃ\xa0bregas', 'i', 'Soler']
# ['Andrea', 'Consigli']
# ['Steve', 'Mandanda']
# ['Laurent', 'Koscielny']
# ['Emiliano', 'Viviano']
# ['Jardel', 'Nivaldo', 'Vieira']
# ['Ezequiel', 'Marcelo', 'Garay']
# ['JosÃ©', 'AndrÃ©s', 'Guardado', 'HernÃ¡ndez']
# ['Antonio', 'AdÃ¡n', 'Garrido']
# ['Juan', 'Manuel', 'Mata', 'GarcÃ\xada']
# ['Olivier', 'Giroud']
# ['Ralf', 'FÃ¤hrmann']
# ['Federico', 'JuliÃ¡n', 'Fazio']
# ['Vedran', 'Ä†orluka']
# ['Pedro', 'Eliezer', 'RodrÃ\xadguez', 'Ledesma']
# ['Kevin', 'Strootman']
# ['Kamil', 'Glik']
# ['Shkodran', 'Mustafi']
# ['Danijel', 'SubaÅ¡iÄ‡']
# ['Henrikh', 'Mkhitaryan']
# ['Thomas', 'Delaney']
# ['Xherdan', 'Shaqiri']
# ['MÃ¡rio', 'Figueira', 'Fernandes']
# ['Willian', 'JosÃ©', 'da', 'Silva']
# ['SebastiÃ¡n', 'Coates', 'NiÃ³n']
# ['Marc', 'Bartra', 'Aregall']
# ['Jonathan', 'Viera', 'Ramos']
# ['Luis', 'Alberto', 'Romero', 'Alconchel']
# ['Wilfried', 'Zaha']
# ['CÃ©dric', 'Bakambu']
# ['Wissam', 'Ben', 'Yedder']
# ['Jasper', 'Cillessen']
# ['Francisco', 'AlcÃ¡cer', 'GarcÃ\xada']
# ['Benjamin', 'Lecomte']
# ['Ã\x81lvaro', 'Borja', 'Morata', 'MartÃ\xadn']
# ['Gabriel', 'Armando', 'de', 'Abreu']
# ['Rafael', 'AlcÃ¢ntara', 'do', 'Nascimento']
# ['Salif', 'SanÃ©']
# ['Thomas', 'Meunier']
# ['Karim', 'Bellarabi']
# ['Harry', 'Maguire']
# ['Alessandro', '', 'Florenzi']
# ['Arkadiusz', 'Milik']
# ['Antonio', 'RÃ¼diger']
# ['SÃ©bastien', 'Haller']
# ['Franco', 'VÃ¡zquez']
# ['Jesse', 'Lingard']
# ['Josef', 'Alexander', 'MartÃ\xadnez']
# ['Emil', 'Forsberg']
# ['Andrea', 'Belotti']
# ['Jamie', 'Vardy']
# ['Thomas', 'Partey']
# ['Alejandro', 'Grimaldo', 'GarcÃ\xada']
# ['Piotr', 'ZieliÅ„ski']
# ['Daniele', 'Rugani']
# ['Kerem', 'Demirbay']
# ['Thomas', 'Strakosha']
# ['Federico', 'Bernardeschi']
# ['JiÅ™Ã\xad', 'Pavlenka']
# ['Iker', 'Casillas', 'FernÃ¡ndez']
# ['Daniele', 'De', 'Rossi']
# ['Rune', '', 'Almenning', 'Jarstein']
# ['Andrea', 'Barzagli']
# ['Franck', 'Bilal', 'RibÃ©ry']
# ['Kasper', 'Schmeichel']
# ['Salvatore', 'Sirigu']
# ['Sokratis', 'Papastathopoulos']
# ['Lucas', '', 'Pezzini', 'Leiva']
# ['Jonas', 'GonÃ§alves', 'Oliveira']
# ['Dimitri', '', 'Payet']
# ['Lars', 'Bender']
# ['Javier', 'MartÃ\xadnez', 'Aginaga']
# ['Rui', 'Pedro', 'dos', 'Santos', 'PatrÃ\xadcio']
# ['Sergio', '', 'Asenjo', 'AndrÃ©s']
# ['David', 'Luiz', 'Moreira', 'Marinho']
# ['Georginio', 'Wijnaldum']
# ['Aleksandar', 'Kolarov']
# ['Oscar', 'dos', 'Santos', 'Emboaba', 'JÃºnior']
# ['Bas', 'Dost']
# ['Sergio', 'Canales', 'Madrazo']
# ['Bernd', 'Leno']
# ['Marcos', 'Alonso', 'Mendoza']
# ['Koen', 'Casteels']
# ['Idrissa', 'Gana', 'Gueye']
# ['Oliver', 'Baumann']
# ['Norberto', 'Murara', 'Neto']
# ['Kevin', 'Kampl']
# ['LuÃ\xads', 'Miguel', 'Afonso', 'Fernandes']
# ['Rodrigo', 'Moreno', 'Machado']
# ['Pablo', 'Sarabia', 'GarcÃ\xada']
# ['Sergio', 'Roberto', 'Carnicer']
# ['Francesco', 'Acerbi']
# ['Timo', 'Horn']
# ['JosÃ©', 'Ignacio', 'FernÃ¡ndez', 'Iglesias']
# ['Danilo', 'LuÃ\xads', 'HÃ©lio', 'Pereira']
# ['Lucas', 'Rodrigues', 'M.', 'Silva']
# ['Julian', 'Draxler']
# ['JesÃºs', 'JoaquÃ\xadn', 'FernÃ¡ndez', 'SÃ¡ez']
# ['Thorgan', 'Hazard']
# ['John', 'Stones']
# ['Stefan', 'SaviÄ‡']
# ['Jordan', 'Pickford']
# ['Andrew', 'Robertson']
# ['Andrej', 'KramariÄ‡']
# ['Corentin', 'Tolisso']
# ['Lucas', 'HernÃ¡ndez']
# ['Naby', 'KeÃ¯ta']
# ['Presnel', 'Kimpembe']
# ['Lourival', 'Adnan', 'Beretta', 'Barbosa']
# ['JosuÃ©', 'Durval', 'Chiamulera', 'Vaz']
# ['Ronaldo', 'Jailson', 'Cabrais', 'Petri']
# ['Gabriel', 'Fernando', 'de', 'Jesus']
# ['Gianluigi', 'Donnarumma']
# ['Marcus', 'Rashford']
# ['Matthijs', 'de', 'Ligt']
# ['Arjen', 'Robben']
# ['Ricardo', 'Andrade', 'Quaresma', 'Bernardo']
# ['Alejandro', 'DarÃ\xado', 'GÃ³mez']
# ['RaÃºl', 'Albiol', 'Tortajada']
# ['Radamel', 'Falcao', 'GarcÃ\xada', 'ZÃ¡rate']
# ['StÃ©phane', 'Ruffier']
# ['JoÃ£o', 'Miranda', 'de', 'Souza', 'Filho']
# ['Ronaldo', '', 'Aparecido', 'Rodrigues']
# ['Yann', 'Sommer']
# ['Ã‰ver', 'Maximiliano', 'David', 'Banega']
# ['Diego', 'da', 'Silva', 'Costa']
# ['Sami', 'Khedira']
# ['Willian', 'Borges', 'da', 'Silva']
# ['Alexis', 'Alejandro', 'SÃ¡nchez', 'SÃ¡nchez']
# ['JosÃ©', 'MarÃ\xada', 'CallejÃ³n', 'Bueno']
# ['Ä°lkay', 'GÃ¼ndoÄŸan']
# ['Kyle', 'Walker']
# ['Roman', 'BÃ¼rki']
# ['Asier', 'Illarramendi', 'Andonegi']
# ['LukÃ¡Å¡', 'HrÃ¡deckÃ½']
# ['Nemanja', 'MatiÄ‡']
# ['NicolÃ¡s', 'HernÃ¡n', 'Otamendi']
# ['Iago', 'Aspas', 'Juncal']
# ['Juan', 'Cuadrado']
# ['David', 'Olatukunbo', 'Alaba']
# ['Mattia', 'Perin']
# ['Stefan', 'de', 'Vrij']
# ['Allan', 'Marques', 'Loureiro']
# ['Felipe', '', 'Anderson', 'Pereira', 'Gomes']
# ['Memphis', 'Depay']
# ['Florian', 'Thauvin']
# ['KÃ©pler', 'Laveran', 'Lima', 'Ferreira']
# ['Vincent', 'Kompany']
# ['Filipe', 'LuÃ\xads', 'Kasmirski']
# ['Blaise', 'Matuidi']
# ['Mesut', 'Ã–zil']
# ['Axel', '', 'Witsel']
# ['Radja', 'Nainggolan']
# ['Edin', 'DÅ¾eko']
# ['Ivan', 'PeriÅ¡iÄ‡']
# ['Mario', 'MandÅ¾ukiÄ‡']
# ['Arturo', 'Vidal']
# ['Ã\x81ngel', 'FabiÃ¡n', 'Di', 'MarÃ\xada', 'HernÃ¡ndez']
# ['JÃ©rÃ´me', 'Boateng']
# ['Yacine', 'Brahimi']
# ['JosÃ©', 'Paulo', 'Bezzera', 'Maciel', 'JÃºnior']
# ['Daniel', 'Parejo', 'MuÃ±oz']
# ['Douglas', 'Costa', 'de', 'Souza']
# ['Kostas', 'Manolas']
# ['Alexandre', 'Lacazette']
# ['Jorge', 'ResurrecciÃ³n', 'Merodio']
# ['Anthony', 'Lopes']
# ['ì†\x90í\x9d¥ë¯¼', 'å\xad™å…´æ…œ']
# ['Riyad', 'Mahrez']
# ['Daniel', 'Carvajal', 'Ramos']
# ['Marcos', '', 'AoÃ¡s', 'CorrÃªa']
# ['SaÃºl', 'Ã‘Ã\xadguez', 'EsclÃ¡pez']
# ['Bamidele', 'Alli']
# ['Aymeric', '', 'Laporte']
# ['Sergej', 'MilinkoviÄ‡-SaviÄ‡']
# ['Karim', 'Benzema']
# ['Miralem', 'PjaniÄ‡']
# ['Leonardo', 'Bonucci']
# ['CÃ©sar', 'Azpilicueta', 'Tanco']
# ['Wojciech', '', 'SzczÄ™sny']
# ['Thomas', 'MÃ¼ller']
# ['Alex', 'Sandro', 'Lobo', 'Silva']
# ['Romelu', 'Lukaku']
# ['Marco', 'Verratti']
# ['RaphaÃ«l', 'Varane']
# ['Roberto', 'Firmino', 'Barbosa', 'de', 'Oliveira']
# ['Sadio', 'ManÃ©']
# ['Ederson', 'Santana', 'de', 'Moraes']
# ['Joshua', 'Kimmich']
# ['Bernardo', 'Mota', 'Veiga', 'de', 'Carvalho', 'e', 'Silva']
# ['Leroy', 'SanÃ©']
# ['Raheem', 'Sterling']
# ['Samuel', 'Umtiti']
# ['Alisson', 'Ramses', 'Becker']
# ['Gianluigi', 'Buffon']
# ['Gerard', 'PiquÃ©', 'BernabÃ©u']
# ['Samir', 'HandanoviÄ\x8d']
# ['Thiago', 'Emiliano', 'da', 'Silva']
# ['Hugo', 'Lloris']
# ['Gareth', 'Frank', 'Bale']
# ['Mats', '', 'Hummels']
# ['Marco', 'Reus']
# ['Pierre-Emerick', 'Aubameyang']
# ['Philippe', 'Coutinho', 'Correia']
# ["N'Golo", 'KantÃ©']
# ['Giorgio', 'Chiellini']
# ['Sergio', 'Ramos', 'GarcÃ\xada']
# ['David', 'JosuÃ©', 'JimÃ©nez', 'Silva']
# ['Diego', 'GodÃ\xadn']
# ['Toni', 'Kroos']
# ['Robert', 'Lewandowski']
# ['Jan', 'Oblak']
# ['Harry', 'Kane']
# ['Luis', 'Alberto', 'SuÃ¡rez', 'DÃ\xadaz']
# ['Luka', 'ModriÄ‡']
# ['Eden', 'Hazard']
# ['Kevin', 'De', 'Bruyne']
# ['David', 'De', 'Gea', 'Quintana']
# ['Neymar', 'da', 'Silva', 'Santos', 'Junior']
# ['Cristiano', 'Ronaldo', 'dos', 'Santos', 'Aveiro']
# ['Janni-Luca', 'Serra']
# ['Angel', 'Rodriguez']
# ['AndrÃ©', 'Calisir']
# ['RÃ³ger', 'Mauricio', 'Torres', 'Hoya']
# ['Rory', '', 'McKenzie']
# ['Michal', 'SipÄ¾ak']
# ['Jan', 'Bekkema']
# ['Abdulrahman', 'Al', 'Yami']
# ['JosÃ©', 'Francisco', 'dos', 'Santos', 'JÃºnior']

# %%
# Ok--new problems discoverd!
# 1) Lots of players have >2 names
# 2) It's not obvious how to interpret multiple fields
#   e.g. Is it a hyphenated last name?
#        Is it latin-style and including mother's & father's surnames
#        Is "del Castillo" part of the formal name?
# 3) Some players have "Junior", etc. suffixes
# 4) We imported the header row as "full_name"
#
#

# %%
# Can we use the name column to infer which block is the surname?
lines[0:17]

# Maybe?   Let's print just the name and full_name
# Out:
# ['\ufeffname,full_name,birth_date,age,height_cm,weight_kgs,positions,nationality,overall_rating,potential,value_euro,wage_euro,preferred_foot,international_reputation(1-5),weak_foot(1-5),skill_moves(1-5),body_type,release_clause_euro,national_team,national_rating,national_team_position,national_jersey_number,crossing,finishing,heading_accuracy,short_passing,volleys,dribbling,curve,freekick_accuracy,long_passing,ball_control,acceleration,sprint_speed,agility,reactions,balance,shot_power,jumping,stamina,strength,long_shots,aggression,interceptions,positioning,vision,penalties,composure,marking,standing_tackle,sliding_tackle\n',
#  'L. Messi,Lionel AndrÃ©s Messi Cuccittini,6/24/1987,31,170.18,72.1,"CF,RW,ST",Argentina,94,94,110500000,565000,Left,5,4,4,Messi,226500000,Argentina,82,RF,10,86,95,70,92,86,97,93,94,89,96,91,86,93,95,95,85,68,72,66,94,48,22,94,94,75,96,33,28,26\n',
#  'C. Eriksen,Christian  Dannemann Eriksen,2/14/1992,27,154.94,76.2,"CAM,RM,CM",Denmark,88,89,69500000,205000,Right,3,5,4,Lean,133800000,Denmark,78,CAM,10,88,81,52,91,80,84,86,87,89,91,76,73,80,88,81,84,50,92,58,89,46,56,84,91,67,88,59,57,22\n',
#  'P. Pogba,Paul Pogba,3/15/1993,25,190.5,83.9,"CM,CAM",France,88,91,73000000,255000,Right,4,4,5,Normal,144200000,France,84,RDM,6,80,75,75,86,85,87,85,82,90,90,71,79,76,82,66,90,83,88,87,82,78,64,82,88,82,87,63,67,67\n',
#  'L. Insigne,Lorenzo Insigne,6/4/1991,27,162.56,59,"LW,ST",Italy,88,88,62000000,165000,Right,3,4,4,Normal,105400000,Italy,83,LW,10,86,77,56,85,74,90,87,77,78,93,94,86,94,83,93,75,53,75,44,84,34,26,83,87,61,83,51,24,22\n',
#  'K. Koulibaly,Kalidou Koulibaly,6/20/1991,27,187.96,88.9,CB,Senegal,88,91,60000000,135000,Right,3,3,2,Normal,106500000,,,,,30,22,83,68,14,69,28,28,60,63,70,75,50,82,40,55,81,75,94,15,87,88,24,49,33,80,91,88,87\n',
#  'V. van Dijk,Virgil van Dijk,7/8/1991,27,193.04,92.1,CB,Netherlands,88,90,59500000,215000,Right,3,3,2,Normal,114500000,Netherlands,81,LCB,4,53,52,83,79,45,70,60,70,81,76,74,77,61,87,49,81,88,75,92,64,82,88,41,60,62,87,90,89,84\n',
#  'K. MbappÃ©,Kylian MbappÃ©,12/20/1998,20,152.4,73,"RW,ST,RM",France,88,95,81000000,100000,Right,3,4,5,Lean,166100000,France,84,RM,10,77,88,77,82,78,90,77,63,73,91,96,96,92,87,83,79,75,83,71,78,62,38,88,82,70,86,34,34,32\n',
#  'S. AgÃ¼ero,Sergio Leonel AgÃ¼ero del Castillo,6/2/1988,30,172.72,69.9,ST,Argentina,89,89,64500000,300000,Right,4,4,4,Stocky,119300000,Argentina,82,SUB,11,70,93,77,81,85,89,82,73,64,89,88,80,86,90,91,88,81,76,73,83,65,24,92,83,83,90,30,20,12\n',
#  'M. Neuer,Manuel Neuer,3/27/1986,32,193.04,92.1,GK,Germany,89,89,38000000,130000,Right,5,4,1,Normal,62700000,Germany,85,GK,1,15,13,25,55,11,30,14,11,59,46,54,60,51,84,35,25,77,43,80,16,29,30,12,70,47,70,17,10,11\n',
#  'E. Cavani,Edinson Roberto Cavani GÃ³mez,2/14/1987,32,185.42,77.1,ST,Uruguay,89,89,60000000,200000,Right,4,4,3,Lean,111000000,Uruguay,81,LS,21,70,89,89,78,90,80,77,76,52,82,75,76,77,91,59,87,88,92,78,79,84,48,93,77,85,82,52,45,39\n',
#  'Sergio Busquets,Sergio Busquets i Burgos,7/16/1988,30,187.96,76.2,"CDM,CM",Spain,89,89,51500000,315000,Right,4,3,3,Lean,105600000,Spain,85,CDM,5,62,67,68,89,44,80,66,68,82,88,50,52,66,87,52,61,66,86,77,54,85,87,77,87,60,93,90,86,80\n',
#  'T. Courtois,Thibaut Courtois,5/11/1992,26,198.12,96.2,GK,Belgium,89,90,53500000,240000,Left,4,2,1,Courtois,113700000,Belgium,85,GK,1,14,14,13,33,12,13,19,20,35,23,46,52,61,84,45,36,68,38,70,17,23,15,13,44,27,66,20,18,16\n',
#  'M. ter Stegen,Marc-AndrÃ© ter Stegen,4/30/1992,26,187.96,84.8,GK,Germany,89,92,58000000,240000,Right,3,4,1,Normal,123300000,Germany,85,SUB,22,18,14,11,42,14,17,18,12,47,18,38,50,37,86,43,22,79,35,78,10,43,22,11,70,25,70,25,13,10\n',
#  'A. Griezmann,Antoine Griezmann,3/21/1991,27,175.26,73,"CF,ST",France,89,90,78000000,145000,Left,4,3,4,Lean,165800000,France,84,CAM,7,82,89,84,84,87,87,86,84,78,90,88,85,90,90,82,82,90,86,62,82,73,49,91,85,83,89,59,54,48\n',
#  'M. Salah,Mohamed  Salah Ghaly,6/15/1992,26,175.26,71.2,"RW,ST",Egypt,89,90,78500000,265000,Left,3,3,4,PLAYER_BODY_TYPE_25,151100000,Egypt,73,RM,10,78,90,59,83,76,89,83,60,74,88,94,91,91,92,88,80,68,84,70,83,63,55,92,84,75,91,38,43,41\n',
#  'P. Dybala,Paulo Bruno Exequiel Dybala,11/15/1993,25,152.4,74.8,"CAM,RW",Argentina,89,94,89000000,205000,Left,3,3,4,Normal,153500000,Argentina,82,LF,21,82,84,68,87,88,92,88,88,75,92,87,83,91,86,85,82,75,80,65,88,48,32,84,87,86,84,23,20,20\n']

# %%
for thisplayer in lines:
    print(thisplayer.split(',')[0:2])
# Out:
# ['\ufeffname', 'full_name']
# ['L. Messi', 'Lionel AndrÃ©s Messi Cuccittini']
# ['C. Eriksen', 'Christian  Dannemann Eriksen']
# ['P. Pogba', 'Paul Pogba']
# ['L. Insigne', 'Lorenzo Insigne']
# ['K. Koulibaly', 'Kalidou Koulibaly']
# ['V. van Dijk', 'Virgil van Dijk']
# ['K. MbappÃ©', 'Kylian MbappÃ©']
# ['S. AgÃ¼ero', 'Sergio Leonel AgÃ¼ero del Castillo']
# ['M. Neuer', 'Manuel Neuer']
# ['E. Cavani', 'Edinson Roberto Cavani GÃ³mez']
# ['Sergio Busquets', 'Sergio Busquets i Burgos']
# ['T. Courtois', 'Thibaut Courtois']
# ['M. ter Stegen', 'Marc-AndrÃ© ter Stegen']
# ['A. Griezmann', 'Antoine Griezmann']
# ['M. Salah', 'Mohamed  Salah Ghaly']
# ['P. Dybala', 'Paulo Bruno Exequiel Dybala']
# ['M. Å\xa0kriniar', 'Milan Å\xa0kriniar']
# ['Fernandinho', 'Fernando Luiz Rosa']
# ['G. HiguaÃ\xadn', 'Gonzalo Gerardo HiguaÃ\xadn']
# ['I. RakitiÄ‡', 'Ivan RakitiÄ‡']
# ['J. Vertonghen', 'Jan Vertonghen']
# ['D. Mertens', 'Dries Mertens']
# ['Marcelo', 'Marcelo Vieira da Silva JÃºnior']
# ['T. Alderweireld', 'Toby Alderweireld']
# ['Jordi Alba', 'Jordi Alba Ramos']
# ['Thiago', 'Thiago AlcÃ¢ntara do Nascimento']
# ['C. Immobile', 'Ciro Immobile']
# ['K. Navas', 'Keylor Navas']
# ['Isco', 'Francisco RomÃ¡n AlarcÃ³n SuÃ¡rez']
# ['J. RodrÃ\xadguez', 'James David RodrÃ\xadguez Rubio']
# ['Casemiro', 'Carlos Henrique Venancio Casimiro']
# ['M. Icardi', 'Mauro Emanuel Icardi Rivero']
# ['Kepa', 'Kepa Arrizabalaga']
# ['H. Ziyech', 'Hakim Ziyech']
# ['Fabinho', 'FÃ¡bio Henrique Tavares']
# ['A. Martial', 'Anthony Martial']
# ['T. Werner', 'Timo Werner']
# ['N. SÃ¼le', 'Niklas SÃ¼le']
# ['Bruno Fernandes', 'Bruno Miguel Borges Fernandes']
# ['Alex Telles', 'Alex Nicolao Telles']
# ['J. GimÃ©nez', 'JosÃ© MarÃ\xada GimÃ©nez de Vargas']
# ['N. Fekir', 'Nabil Fekir']
# ['D. SÃ¡nchez', 'Davinson SÃ¡nchez']
# ['Marco Asensio', 'Marco Asensio Willemsen']
# ['O. DembÃ©lÃ©', 'Ousmane DembÃ©lÃ©']
# ['Iniesta', 'AndrÃ©s Iniesta LujÃ¡n']
# ['Z. IbrahimoviÄ‡', 'Zlatan IbrahimoviÄ‡']
# ['Jorginho', 'Luiz Frello Filho Jorge']
# ['E. ViÅ¡Ä‡a', 'Edin ViÅ¡Ä‡a']
# ['S. Gnabry', 'Serge Gnabry']
# ['M. KovaÄ\x8diÄ‡', 'Mateo KovaÄ\x8diÄ‡']
# ['William Carvalho', 'William Silva de Carvalho']
# ['Felipe', 'Felipe Augusto de Almeida Monteiro']
# ['Y. Carrasco', 'Yannick Ferreira Carrasco']
# ['Lucas VÃ¡zquez', 'Lucas VÃ¡zquez Iglesias']
# ['Q. Promes', 'Quincy Anton Promes']
# ['L. Goretzka', 'Leon Goretzka']
# ['A. Rabiot', 'Adrien Rabiot']
# ['A. Romagnoli', 'Alessio Romagnoli']
# ['JoÃ£o Cancelo', 'JoÃ£o Pedro Cavaco Cancelo']
# ['Anderson Talisca', 'Anderson Souza ConceiÃ§Ã£o']
# ['K. Coman', 'Kingsley Coman']
# ['T. Lemar', 'Thomas Lemar']
# ['J. Tah', 'Jonathan Tah']
# ['M. Politano', 'Matteo Politano']
# ['C. Lenglet', 'ClÃ©ment Lenglet']
# ['Pau LÃ³pez', 'Pau LÃ³pez Sabata']
# ['H. Lozano', 'Hirving Rodrigo Lozano Bahena']
# ['Malcom', 'Malcom Filipe Silva de Oliveira']
# ['L. Torreira', 'Lucas Torreira Di Pascua']
# ['GonÃ§alo Guedes', 'GonÃ§alo Manuel Ganchinho Guedes']
# ['G. Lo Celso', 'Giovani Lo Celso']
# ['FabiÃ¡n', 'FabiÃ¡n Ruiz PeÃ±a']
# ['F. de Jong', 'Frenkie de Jong']
# ['Raphaelito Anjos', 'Raphael William Anjos Rochedo']
# ['Juiano Mestres', 'Juan Everton Mestres de Mesquita']
# ['Rosberto Dourado', 'Rosberto J. Dourado Santos']
# ['Arthur', 'Arthur Henrique Ramos Oliveira Melo']
# ['Rodri', 'Rodrigo HernÃ¡ndez Cascante']
# ['M. Parolo', 'Marco Parolo']
# ['M. Kruse', 'Max Kruse']
# ['J. Henderson', 'Jordan Brian Henderson']
# ['N. GaitÃ¡n', 'Osvaldo NicolÃ¡s FabiÃ¡n GaitÃ¡n']
# ['M. ArnautoviÄ‡', 'Marko ArnautoviÄ‡']
# ['S. Giovinco', 'Sebastian Giovinco']
# ['G. SigurÃ°sson', 'Gylfi ÃžÃ³r SigurÃ°sson']
# ['Giuliano', 'Giuliano Victor de Paula']
# ['P. GulÃ¡csi', 'PÃ©ter GulÃ¡csi']
# ['Luiz Gustavo', 'Luiz Gustavo Dias']
# ['K. Trippier', 'Kieran Trippier']
# ['A. Ramsey', 'Aaron Ramsey']
# ['M. Balotelli', 'Mario  Barwuah Balotelli']
# ['Marlos', 'Marlos Romero Bonfim']
# ['Taison', 'Taison Barcellos Freda']
# ['G. Bonaventura', 'Giacomo Bonaventura']
# ['G. Kondogbia', 'Geoffrey Kondogbia']
# ['J. Roussillon', 'JÃ©rÃ´me Roussillon']
# ['S. Zaza', 'Simone Zaza']
# ['S. Vrsaljko', 'Å\xa0ime Vrsaljko']
# ['C. Kramer', 'Christoph Kramer']
# ['B. Mendy', 'Benjamin Mendy']
# ['M. Sabitzer', 'Marcel Sabitzer']
# ['M. NastasiÄ‡', 'Matija NastasiÄ‡']
# ['A. Plea', 'Alassane Plea']
# ['M. Ginter', 'Matthias Ginter']
# ['Gerard Moreno', 'Gerard Moreno BalaguerÃ³']
# ['A. DoucourÃ©', 'Abdoulaye DoucourÃ©']
# ['R. Guerreiro', 'RaphaÃ«l Guerreiro']
# ['Ricardo Pereira', 'Ricardo Barbosa Pereira']
# ['Samu Castillejo', 'Samuel Castillejo Azuaga']
# ['J. Brandt', 'Julian Brandt']
# ['N. PÃ©pÃ©', 'Nicolas PÃ©pÃ©']
# ['S. Bergwijn', 'Steven Bergwijn']
# ['A. Onana', 'AndrÃ© Onana']
# ['F. Balbuena', 'FabiÃ¡n Balbuena']
# ['AndrÃ© Silva', 'AndrÃ© Miguel Valente da Silva']
# ['Oyarzabal', 'Mikel Oyarzabal Ugarte']
# ['Everton AndrÃ£o', 'Everton Jorge Andrade Zanon']
# ['Welington Dano', 'Welington KauÃª Dano Nascimento']
# ['Richarlison', 'Richarlison de Andrade']
# ['Odriozola', 'Ã\x81lvaro Odriozola Arzalluz']
# ['Carlos Soler', 'Carlos Soler BarragÃ¡n']
# ['H. Aouar', 'Houssem Aouar']
# ['T. Ndombele', 'Tanguy NDombÃ¨lÃ© Alvaro']
# ['M. GÃ³mez', 'Maximiliano GÃ³mez']
# ['JoaquÃ\xadn', 'JoaquÃ\xadn SÃ¡nchez RodrÃ\xadguez']
# ['J. Mathieu', 'JÃ©rÃ©my Mathieu']
# ['J. Matip', 'JoÃ«l Andre Job Matip']
# ['S. Aurier', 'Serge Aurier']
# ['J. Guilavogui', 'Josuha Guilavogui']
# ['A. Oxlade-Chamberlain', 'Alex Oxlade-Chamberlain']
# ['M. Ryan', 'Mathew Ryan']
# ['V. Aboubakar', 'Vincent PatÃ© Aboubakar']
# ['L. Muriel', 'Luis Fernando Muriel Fruto']
# ['D. Vida', 'Domagoj Vida']
# ['Ibai GÃ³mez', 'Ibai GÃ³mez PÃ©rez']
# ['Cristian Tello', 'Cristian Tello Herrera']
# ['Ismaily', 'Ismaily GonÃ§alves dos S.']
# ['A. Mandi', 'AÃ¯ssa Mandi']
# ['C. TÄƒtÄƒruÅŸanu', 'Anton Ciprian TÄƒtÄƒruÈ™anu']
# ['J. Murillo', 'Jeison FabiÃ¡n Murillo CerÃ³n']
# ['E. Dier', 'Eric Dier']
# ['J. Butland', 'Jack Butland']
# ['S. Sorrentino', 'Stefano Sorrentino']
# ['W. Rooney', 'Wayne Mark Rooney']
# ['MoyÃ¡', 'Miguel Ã\x81ngel MoyÃ¡ Rumbo']
# ['L. LÃ³pez', 'Lisandro LÃ³pez']
# ['J. Mascherano', 'Javier Alejandro Mascherano']
# ['Raffael', 'Raffael Caetano de AraÃºjo']
# ['Diego LÃ³pez', 'Diego LÃ³pez RodrÃ\xadguez']
# ['Juanfran', 'Juan Francisco Torres BelÃ©n']
# ['I. Denisov', 'Igor Denisov']
# ['I. Akinfeev', 'Igor Akinfeev']
# ['A. Gignac', 'AndrÃ©-Pierre Gignac']
# ['A. Granqvist', 'Andreas Granqvist']
# ['Manuel Fernandes', 'Manuel Henrique Tavares Fernandes']
# ['Dante', 'Dante Bonfim da Costa Santos']
# ['L. Perrin', 'LoÃ¯c Perrin']
# ['Borja Valero', 'Borja Valero Iglesias']
# ['A. Januzaj', 'Adnan Januzaj']
# ['J. Hector', 'Jonas Hector']
# ['M. Dabbur', 'Moanes Dabour']
# ['Ã“liver Torres', 'Ã“liver Torres MuÃ±oz']
# ['Y. Bounou', 'Yassine Bounou']
# ['J. Hofmann', 'Jonas Hofmann']
# ['OtÃ¡vio', 'OtÃ¡vio Edmilson da Silva Monteiro']
# ['Jonny', 'Jonathan Castro Otto']
# ['L. Dendoncker', 'Leander Dendoncker']
# ['R. Zobnin', 'Roman Zobnin']
# ['Ricardo Horta', 'Ricardo Jorge da Luz Horta']
# ['Thiago Mendes', 'Thiago Henrique Mendes Ribeiro']
# ['J. Lerma', 'Jefferson AndrÃ©s Lerma SolÃ\xads']
# ['J. Gbamin', 'Jean-Philippe Gbamin']
# ['I. Marcone', 'IvÃ¡n Marcone']
# ['D. Benedetto', 'DarÃ\xado Benedetto']
# ['M. Hitz', 'Marwin Hitz']
# ['N. Clyne', 'Nathaniel Edwin Clyne']
# ['A. LjajiÄ‡', 'Adem LjajiÄ‡']
# ['J. GuÃ°mundsson', 'Johann  Berg GuÃ°mundsÂ\xadson']
# ['Elkeson', 'Elkeson de Oliveira Cardoso']
# ['Kike GarcÃ\xada', 'Enrique GarcÃ\xada MartÃ\xadnez']
# ['Escudero', 'Sergio Escudero Palomo']
# ['HerrerÃ\xadn', 'Iago HerrerÃ\xadn BuisÃ¡n']
# ['VÃ\xadctor Ruiz', 'VÃ\xadctor RuÃ\xadz Torre']
# ['G. Medel', 'Gary Alexis Medel Soto']
# ['Y. Belhanda', 'YounÃ¨s Belhanda']
# ['Hugo Mallo', 'Hugo Mallo Novegil']
# ['Borja GarcÃ\xada', 'Borja GarcÃ\xada Freire']
# ['W. Khazri', 'Wahbi Khazri']
# ['P. Jones', 'Phil Jones']
# ['A. Finnbogason', 'AlfreÃ° Finnbogason']
# ['VinÃ\xadcius JÃºnior', 'VinÃ\xadcius JosÃ© de Oliveira JÃºnior']
# ['Junior Firpo', 'HÃ©ctor Junior Firpo AdamÃ©s']
# ['E. BelÃ¶zoÄŸlu', 'Emre BelÃ¶zoÄŸlu']
# ['Fernando Torres', 'Fernando JosÃ© Torres Sanz']
# ['B. Schweinsteiger', 'Bastian Schweinsteiger']
# ['B. YÄ±lmaz', 'Burak YÄ±lmaz']
# ['M. GÃ³mez', 'Mario GÃ³mez GarcÃ\xada']
# ['A. Young', 'Ashley Young']
# ['R. Babel', 'Ryan Guno Babel']
# ['B. Costil', 'BenoÃ®t Costil']
# ['S. Kalou', 'Salomon Armand Magloire Kalou']
# ['E. Lavezzi', 'Ezequiel IvÃ¡n Lavezzi']
# ['H. Ben Arfa', 'Hatem Ben Arfa']
# ['B. Foster', 'Ben Foster']
# ['T. Heaton', 'Tom Heaton']
# ['Charles', 'Charles Dias De Oliveira']
# ['G. Cahill', 'Gary Cahill']
# ['A. Iwobi', 'Alex Iwobi']
# ['R. Loftus-Cheek', 'Ruben Loftus-Cheek']
# ['A. Selikhov', 'Alexandr Selikhov']
# ['J. Mojica', 'Johan AndrÃ©s Mojica Palacio']
# ['W. Barrios', 'WÃ\xadlmar Enrique Barrios TerÃ¡n']
# ['C. Izquierdoz', 'Carlos Roberto Izquierdoz']
# ['W. BenÃ\xadtez', 'Walter BenÃ\xadtez']
# ['N. MaksimoviÄ‡', 'Nikola MaksimoviÄ‡']
# ['A. MitroviÄ‡', 'Aleksandar MitroviÄ‡']
# ['M. Sportiello', 'Marco Sportiello']
# ['Capa', 'Ander Capa RodrÃ\xadguez']
# ['Marcelo Goiano', 'Marcelo Augusto Ferreira Teixeira']
# ['Y. Tielemans', 'Youri Tielemans']
# ['S. Lobotka', 'Stanislav Lobotka']
# ['M. Philipp', 'Maximilian Philipp']
# ['L. Dubois', 'LÃ©o Dubois']
# ['L. Dunk', 'Lewis Dunk']
# ['C. Schindler', 'Christopher Schindler']
# ['Y. Konoplyanka', 'Yevhen Konoplyanka']
# ['Pedro Mendes', 'Pedro Filipe TeodÃ³sio Mendes']
# ['R. Saponara', 'Riccardo Saponara']
# ['L. Kurzawa', 'Layvin Kurzawa']
# ['M. Hinteregger', 'Martin Hinteregger']
# ['D. da Costa', 'Danny  Vieira da Costa']
# ['Fernando', 'Fernando Lucas Martins']
# ['W. Boly', 'Willy Boly']
# ['A. Schwolow', 'Alexander Schwolow']
# ['G. Defrel', 'Gregoire Defrel']
# ['Ã\x81lvaro', 'Ã\x81lvaro GonzÃ¡lez SoberÃ³n']
# ['L. Bittencourt', 'Leonardo Bittencourt']
# ['A. Carrillo', 'AndrÃ© MartÃ\xadn Carrillo DÃ\xadaz']
# ['M. Elyounoussi', 'Mohamed Elyounoussi']
# ['O. Karnezis', 'Orestis Karnezis']
# ['De Marcos', 'Ã“scar de Marcos Arana']
# ['R. Cabella', 'RÃ©my Cabella']
# ['J. Hart', 'Joe Hart']
# ['Jurado', 'JosÃ© Manuel Jurado MarÃ\xadn']
# ['E. HernÃ¡ndez', 'ElÃ\xadas HernÃ¡n HernÃ¡ndez Jacuinde']
# ['D. Ginczek', 'Daniel Ginczek']
# ['Lucas PÃ©rez', 'Lucas PÃ©rez MartÃ\xadnez']
# ['J. FarfÃ¡n', 'Jefferson AgustÃ\xadn FarfÃ¡n Guadalupe']
# ['A. BegoviÄ‡', 'Asmir BegoviÄ‡']
# ['Hilton', 'Vitorino Hilton da Silva']
# ['J. Baumgartlinger', 'Julian Baumgartlinger']
# ['Granero', 'Esteban FÃ©lix Granero Molina']
# ['Z. JunuzoviÄ‡', 'Zlatko JunuzoviÄ‡']
# ['V. Moses', 'Victor Moses']
# ['M. Debuchy', 'Mathieu Debuchy']
# ['G. MaripÃ¡n', 'Guillermo Alfonso MaripÃ¡n Loaysa']
# ['IvÃ¡n CuÃ©llar', 'IvÃ¡n CuÃ©llar SacristÃ¡n']
# ['F. Johnson', 'Fabian Johnson']
# ['AarÃ³n MartÃ\xadn', 'AarÃ³n MartÃ\xadn Caricol']
# ['G. Pereiro', 'GastÃ³n Rodrigo Pereiro LÃ³pez']
# ['B. Moukandjo', 'Benjamin Moukandjo BilÃ©']
# ['M. Harnik', 'Martin Harnik']
# ['J. Ward-Prowse', 'James  Ward-Prowse']
# ['R. Alessandrini', 'Romain Alessandrini']
# ['Manu GarcÃ\xada', 'Manuel Alejandro GarcÃ\xada SÃ¡nchez']
# ['M. Antonio', 'Michail Antonio']
# ['Adrien Silva', 'Adrien Sebastian Perruchet Silva']
# ['S. Cook', 'Steve Cook']
# ['B. Mee', 'Ben Mee']
# ['Adriano', 'Adriano Correia Claro']
# ['J. Lens', 'Jeremain Lens']
# ['S. RondÃ³n', 'JosÃ© SalomÃ³n RondÃ³n GimÃ©nez']
# ['Andreas Pereira', 'Andreas Hugo Hoelgebaum Pereira']
# ['V. IbiÅ¡eviÄ‡', 'Vedad IbiÅ¡eviÄ‡']
# ['L. Ocampos', 'Lucas Ocampos']
# ['N. MÃ¼ller', 'Nicolai MÃ¼ller']
# ['SimÃ£o Acunha', 'SimÃ£o Alvin Acunha Bardini']
# ['J. Calleri', 'Jonathan Calleri']
# ['A. Jahanbakhsh', 'Alireza Jahanbakhsh']
# ['A. PrijoviÄ‡', 'Aleksandar PrijoviÄ‡']
# ['Fabricio', 'Fabricio MartÃ\xadn Agosto RamÃ\xadrez']
# ['M. Elneny', 'Mohamed Elneny']
# ['Jorge MerÃ©', 'Jorge MerÃ© PÃ©rez']
# ['Wilson Eduardo', 'Wilson Bruno Naval Costa Eduardo']
# ['Ã\x81lex Remiro', 'Alejandro Remiro Gargallo']
# ['T. GutiÃ©rrez', 'TeÃ³filo GutiÃ©rrez']
# ['A. Pyatov', 'Andriy Pyatov']
# ['Diego Llorente', 'Diego Javier Llorente RÃ\xados']
# ['I. Abate', 'Ignazio Abate']
# ['T. Vermaelen', 'Thomas Vermaelen']
# ['N. FÃ¼llkrug', 'Niclas FÃ¼llkrug']
# ['Pedro Obiang', 'Pedro  Mba Obiang Avomo']
# ['Wallace', 'Wallace Fortuna dos Santos']
# ['Djaniny', 'Jorge Djaniny  Tavares Semedo']
# ['Roberto', 'Roberto JimÃ©nez Gago']
# ['S. Tasci', 'Serdar TaÅŸÃ§Ä±']
# ['L. SchÃ¸ne', 'Lasse SchÃ¸ne']
# ['J. Defoe', 'Jermain  Defoe']
# ['V. Babacan', 'Volkan Babacan']
# ['O. Ighalo', 'Odion Jude Ighalo']
# ['A. SchÃ¼rrle', 'AndrÃ© SchÃ¼rrle']
# ['E. Skhiri', 'Ellyes Skhiri']
# ['W. Anton', 'Waldemar Anton']
# ['R. Palacio', 'Rodrigo SebastiÃ¡n Palacio']
# ['K. Lasagna', 'Kevin Lasagna']
# ['D. Cvitanich', 'DarÃ\xado Cvitanich']
# ['S. De Maio', 'Sebastian De Maio']
# ['S. Terodde', 'Simon Terodde']
# ['J. De GuzmÃ¡n', 'Jonathan  de GuzmÃ¡n']
# ['R. Civelli', 'Renato Civelli']
# ['Pablo Maffeo', 'Pablo Maffeo Becerra']
# ['CÃ©dric', 'CÃ©dric Ricardo Alves Soares']
# ['K. Papadopoulos', 'Kyriakos Papadopoulos']
# ['A. Szymanowski', 'Alexander Szymanowski']
# ['J. Kucka', 'Juraj Kucka']
# ['P. Jagielka', 'Phil Jagielka']
# ['M. Benassi', 'Marco Benassi']
# ['P. Jansson', 'Pontus Jansson']
# ['B. Espinosa', 'Bernardo JosÃ© Espinosa ZÃºÃ±iga']
# ['JosÃ© SÃ¡', 'JosÃ© Pedro Malheiro de SÃ¡']
# ['M. Sels', 'Matz Sels']
# ['Yuri Berchiche', 'Yuri Berchiche Izeta']
# ['R. BorrÃ©', 'Rafael Santos BorrÃ©']
# ['Paulinho', 'JoÃ£o Paulo Dias Fernandes']
# ['C. Piccini', 'Cristiano Piccini']
# ['B. AndrÃ©', 'Benjamin AndrÃ©']
# ['BarragÃ¡n', 'Antonio BarragÃ¡n FernÃ¡ndez']
# ['M. Samatta', 'Mbwana Ally Samatta']
# ['I. Diop', 'Issa Diop']
# ['M. Lowton', 'Matthew Lowton']
# ['T. HernÃ¡ndez', 'Theo Bernard FranÃ§ois HernÃ¡ndez']
# ['Juanpe', 'Juan Pedro RamÃ\xadrez LÃ³pez']
# ['K. Tete', 'Kenny Tete']
# ['B. DÅ¾emaili', 'Blerim DÅ¾emaili']
# ['AndrÃ© AndrÃ©', 'AndrÃ© Filipe BrÃ¡s AndrÃ©']
# ['Balenziaga', 'Mikel Balenziaga Oruesagasti']
# ['V. Behrami', 'Valon Behrami']
# ['D. Reyes', 'Diego Antonio Reyes Rosales']
# ['Caiuby', 'Caiuby Francisco da Silva']
# ['S. Doumbia', 'Seydou Doumbia']
# ['JoÃ£o FÃ©lix', 'JoÃ£o FÃ©lix Sequeira']
# ['L. LÃ³pez', 'Lisandro LÃ³pez']
# ['Mario SuÃ¡rez', 'Mario SuÃ¡rez Mata']
# ['J. LÃ¶ssl', 'Jonas LÃ¶ssl']
# ['G. Castro', 'Gonzalo Castro Randon']
# ['M. Phillips', 'Matt Phillips']
# ['Gabriel Boschilia', 'Gabriel Boschilia']
# ['Wu Lei', 'æ\xad¦ç£Š']
# ['N. Blandi', 'NicolÃ¡s Blandi']
# ['L. KaliniÄ‡', 'Lovre KaliniÄ‡']
# ['F. FernÃ¡ndez', 'Federico FernÃ¡ndez']
# ['J. MartÃ\xadnez', 'Jackson MartÃ\xadnez']
# ['Emerson', 'Emerson Palmieri dos Santos']
# ['RÃ´mulo', 'RÃ´mulo  Souza Orestes Caldeira']
# ['C. Benteke', 'Christian Benteke Liolo']
# ['M. Rashica', 'Milot Rashica']
# ['L. Baines', 'Leighton Baines']
# ['M. Noble', 'Mark Noble']
# ['F. BenkoviÄ‡', 'Filip BenkoviÄ‡']
# ['C. Riveros', 'Cristian Miguel Riveros NÃºÃ±ez']
# ['M. Niang', "M'Baye Babacar Niang"]
# ['D. Santon', 'Davide Santon']
# ['I. Ordets', 'Ivan Ordets']
# ['Francisco Geraldes', 'Francisco Geraldes']
# ['R. Snodgrass', 'Robert Snodgrass']
# ['Vitor Hugo', 'Vitor Hugo Franchescoli de Souza']
# ['M. PaÅ¡aliÄ‡', 'Mario PaÅ¡aliÄ‡']
# ['F. Borini', 'Fabio Borini']
# ['N. VukÄ\x8deviÄ‡', 'Nikola VukÄ\x8deviÄ‡']
# ['A. Hutchinson', 'Atiba Hutchinson']
# ['M. Moralez', 'Maximiliano Nicol Moralez']
# ['C. Austin', 'Charlie Austin']
# ['Kenedy', 'Robert Kenedy Nunes do Nascimento']
# ['Eltildo Correia', 'Eltildo Lucas Correia Pitta']
# ['JoÃ£o Pedro', 'JoÃ£o Pedro Geraldino dos Santos GalvÃ£o']
# ['A. Diamanti', 'Alessandro Diamanti']
# ['Guilherme', 'Guilherme dos Santos Torres']
# ['J. Morel', 'JÃ©rÃ©my Morel']
# ['Llorente', 'Fernando Javier Llorente Torres']
# ['G. GÃ¶nÃ¼l', 'GÃ¶khan GÃ¶nÃ¼l']
# ['A. Paloschi', 'Alberto Paloschi']
# ['Juli Freitinho', 'Julio Leonardo Dourado de Freitas']
# ['Markel Bergara', 'Markel Bergara LarraÃ±aga']
# ['L. Nguyen', 'Lee Nguyen']
# ['A. Knockaert', 'Anthony Knockaert']
# ['CÃ³rdoba', 'IÃ±igo CÃ³rdoba Kerejeta']
# ['J. Veltman', 'JoÃ«l Veltman']
# ['N. Sansone', 'Nicola Sansone']
# ['A. Turan', 'Arda Turan']
# ['H. SeferoviÄ‡', 'Haris SeferoviÄ‡']
# ['Rafael Cachoira', 'Rafael Jorgino Cachoira Rebelo']
# ['A. Haidara', 'Amadou Haidara']
# ['F. Caputo', 'Francesco Caputo']
# ['M. Locatelli', 'Manuel Locatelli']
# ['J. Ayew', 'Jordan Ayew']
# ['T. Jedvaj', 'Tin Jedvaj']
# ['S. Hanni', 'Sofiane Hanni']
# ['AndrÃ©s FernÃ¡ndez', 'AndrÃ©s Eduardo FernÃ¡ndez Moreno']
# ['T. Monconduit', 'Thomas Monconduit']
# ['N. Mukiele', 'Nordi Mukiele']
# ['D. Heintz', 'Dominique Heintz']
# ['JÃºnior CaiÃ§ara', 'UÃ\xadlson de Souza Paula JÃºnior']
# ['A. Lennon', 'Aaron  Lennon']
# ['J. Willems', 'Jetro Willems']
# ['M. VeljkoviÄ‡', 'MiloÅ¡ VeljkoviÄ‡']
# ['I. Belfodil', 'Ishak Belfodil']
# ['Miguel Lopes', 'Hugo Miguel Almeida Costa Lopes']
# ['D. Stephens', 'Dale Stephens']
# ['Brais MÃ©ndez', 'Brais MÃ©ndez Portela']
# ['A. Smith', 'Adam Smith']
# ['Recio', 'JosÃ© Luis GarcÃ\xada del Pozo']
# ['Kiko FemenÃ\xada', 'Francisco FemenÃ\xada Far']
# ['M. GaÄ‡inoviÄ‡', 'Mijat GaÄ‡inoviÄ‡']
# ['P. Skjelbred', 'Per Ciljan Skjelbred']
# ['Fernandinho', 'Da ConceiÃ§Ã£o Fernando Henrique']
# ['S. Brown', 'Scott Brown']
# ['M. GrujiÄ‡', 'Marko GrujiÄ‡']
# ['A. Soumaoro', 'Adama Soumaoro']
# ['RaÃºl Navas', 'RaÃºl RodrÃ\xadguez Navas']
# ['A. Szalai', 'Ã\x81dÃ¡m Szalai']
# ['A. Diawara', 'Amadou Diawara']
# ['L. Skorupski', 'Å\x81ukasz Skorupski']
# ['R. Hamouma', 'Romain Hamouma']
# ['K. StÃ¶ger', 'Kevin StÃ¶ger']
# ['K. Linetty', 'Karol Linetty']
# ['S. Bell', 'Stefan Bell']
# ["A. N'Diaye", "Alfred John Momar N'Diaye"]
# ['Y. YazÄ±cÄ±', 'Yusuf YazÄ±cÄ±']
# ['B. Oczipka', 'Bastian Oczipka']
# ['F. Valverde', 'Federico Valverde']
# ['M. BenÃ\xadtez', 'MartÃ\xadn BenÃ\xadtez']
# ['M. Vorm', 'Michel Vorm']
# ['N. Mendy', 'Nampalys Mendy']
# ['J. VÃ¡zquez', 'JosÃ© Juan VÃ¡zquez GÃ³mez']
# ['Unai NÃºÃ±ez', 'Unai NÃºÃ±ez Gestoso']
# ['N. Radoja', 'Nemanja Radoja']
# ['K. Gibbs', 'Kieran  Gibbs']
# ['A. Hamdallah', 'Abderrazak Hamdallah']
# ['Pablo Santos', 'Pablo Renan dos Santos']
# ['S. Fofana', 'Seko Fofana']
# ['Felipe', 'Felipe Dias da Silva dal Belo']
# ['C. Villanueva', 'Carlos AndrÃ©s Villanueva Roland']
# ['MossorÃ³', 'JosÃ© MÃ¡rcio da Costa']
# ['Diego Rico', 'Diego Rico Salguero']
# ['Alberto Moreno', 'Alberto Moreno PÃ©rez']
# ['J. Clasie', 'Jordy Clasie']
# ['R. Funes Mori', 'Rogelio Gabriel Funes Mori']
# ['O. Alonso', 'Osvaldo Alonso Moreno']
# ['A. Djiku', 'Alexander Djiku']
# ['J. Hogg', 'Jonathan Hogg']
# ['D. Calvert-Lewin', 'Dominic Calvert-Lewin']
# ['M. Zeegelaar', 'Marvin Zeegelaar']
# ['G. Carrillo', 'Guido Carrillo']
# ['Jozabed', 'Jozabed SÃ¡nchez Ruiz']
# ['A. Franco', 'Alan Javier Franco']
# ['D. Brooks', 'David Brooks']
# ['J. Bruma', 'Jeffrey Bruma']
# ['L. Sepe', 'Luigi Sepe']
# ['S. Vokes', 'Sam Vokes']
# ['Javi LÃ³pez', 'Javier LÃ³pez RodrÃ\xadguez']
# ['J. Amavi', 'Jordan Amavi']
# ['Idris', 'Idrissa Mandiang']
# ['A. Potuk', 'Alper Potuk']
# ['O. Norwood', 'Oliver Norwood']
# ['R. Khedira', 'Rani Khedira']
# ['D. MachÃ\xads', 'Darwin MachÃ\xads']
# ['R. Quaison', 'Robin Quaison']
# ['P. Dummett', 'Paul Dummett']
# ['L. Dimata', 'Landry Dimata']
# ['Allan Bardinho', 'Allan Norberto Bardini Paneira']
# ['L. Butelle', 'Ludovic Butelle']
# ['S. CristÃ³foro', 'SebastiÃ¡n CristÃ³foro']
# ['Jason', 'David Jason Remeseiro Salgueiro']
# ['M. Agu', 'Mikel Agu']
# ['E. Badu', 'Emmanuel Badu']
# ['N. Redmond', 'Nathan Redmond']
# ['Sandro', 'Sandro Ranieri GuimarÃ£es Cordeiro']
# ['A. Mounier', 'Anthony Mounier']
# ['Matheus Pereira', 'Matheus Fellipe Costa Pereira']
# ['C. Jallet', 'Christophe Jallet']
# ['Diego Castro', 'Diego Castro GimÃ©nez']
# ['S. Okazaki', 'å²¡å´Ž æ…Žå\x8f¸']
# ['O. Kamara', 'Ola  Williams Kamara']
# ['Xeka', 'Miguel Ã‚ngelo da Silva Rocha']
# ['R. Karsdorp', 'Rick Karsdorp']
# ['Marafona', 'JosÃ© Carlos CoentrÃ£o Marafona']
# ['D. ValdÃ©s', 'Diego ValdÃ©s']
# ['M. Gonalons', 'Maxime Gonalons']
# ['Burgui', 'Jorge Franco Alviz']
# ['F. GuarÃ\xadn', 'Fredy Alejandro GuarÃ\xadn VÃ¡squez']
# ['M. Jensen', 'Mathias Jensen']
# ['R. Thomas', 'Ryan Thomas']
# ['B. Butko', 'Bogdan Butko']
# ['L. Cigarini', 'Luca Cigarini']
# ['A. Musa', 'Ahmed Musa']
# ['M. Morozyuk', 'Mykola Morozyuk']
# ['G. Schennikov', 'Georgiy Schennikov']
# ['AndrÃ© Ramalho', 'AndrÃ© Ramalho Silva']
# ['T. Foket', 'Thomas Foket']
# ['P. Foden', 'Philip Foden']
# ['Walace', 'Walace Souza Silva']
# ['I. Kahveci', 'Ä°rfan Can Kahveci']
# ['J. Briand', 'Jimmy Briand']
# ['D. RolÃ¡n', 'Diego RolÃ¡n']
# ['C. ThÃ©rÃ©au', 'Cyril ThÃ©rÃ©au']
# ['B. Valdez', 'Bruno Valdez']
# ['M. KonatÃ©', 'Pape Moussa KonatÃ©']
# ['H. Ayala', 'Hugo Ayala Castro']
# ['J. Kluivert', 'Justin Kluivert']
# ['P. Tau', 'Percy Tau']
# ['Eraso', 'Javier Eraso GoÃ±i']
# ['A. Boruc', 'Artur Boruc']
# ['S. Larsson', 'Sam Larsson']
# ['Paulinho', 'Paulo Henrique Soares dos Santos']
# ['J. Urretaviscaya', 'Jonathan MatÃ\xadas Urretaviscaya da Luz']
# ['Y. AÃ¯t Bennasser', 'Youssef AÃ¯t Bennasser']
# ['P. Bernardoni', 'Paul Bernardoni']
# ['J. Brenet', 'Joshua Brenet']
# ['AleÃ±Ã¡', 'Carles AleÃ±Ã¡ Castillo']
# ['Thiago Maia', 'Thiago Maia Alencar']
# ['R. Skov', 'Robert Skov']
# ['M. Isla', 'Mauricio AnÃ\xadbal Isla Isla']
# ['W. McKennie', 'Weston McKennie']
# ['J. Tavernier', 'James Tavernier']
# ['S. Kalu', 'Samuel Kalu Ojim']
# ['Marlon', 'Marlon da Silva Barbosa']
# ['A. Duncan', 'Joseph Alfred Duncan']
# ['S. Sturaro', 'Stefano Sturaro']
# ['H. Arter', 'Harry Arter']
# ['V. Buyalskyi', 'Vitaliy Buyalskyi']
# ['M. Sarr', 'Malang Sarr']
# ['I. FernÃ¡ndez', 'Ignacio FernÃ¡ndez']
# ['H. Hateboer', 'Hans Hateboer']
# ['F. Niederlechner', 'Florian Niederlechner']
# ['P. Schwegler', 'Pirmin Schwegler']
# ['B. Pearson', 'Ben Pearson']
# ['T. Abraham', 'Tammy Abraham']
# ['Jefferson', 'Jefferson Moreira Nascimento']
# ['J. MÃ¦hle', 'Joakim MÃ¦hle']
# ['Unai LÃ³pez', 'Unai LÃ³pez Cabrera']
# ['I. Amadou', 'Ibrahim Amadou']
# ['C. GÃ¼nter', 'Christian GÃ¼nter']
# ['O. Onazi', 'Ogenyi Eddy Onazi']
# ['J. Montero', 'Jefferson Antonio Montero Vite']
# ['O. Murillo', 'Oscar FabiÃ¡n Murillo Murillo']
# ['Borja BastÃ³n', 'Borja GonzÃ¡lez TomÃ¡s']
# ['L. ZelarayÃ¡n', 'Lucas ZelarayÃ¡n']
# ['M. Kelly', 'Martin Kelly']
# ['A. Umar', 'Aminu Umar']
# ['ZaldÃºa', 'Joseba ZaldÃºa Bengoetxea']
# ['M. Diagne', 'Mbaye Diagne']
# ['Jovane Cabral', 'Jovane Eduardo Borges Cabral']
# ['S. Dann', 'Scott Dann']
# ['M. PavloviÄ‡', 'Mateo PavloviÄ‡']
# ['A. Surman', 'Andrew Surman']
# ['F. Kainz', 'Florian Kainz']
# ['Fran BeltrÃ¡n', 'Francisco JosÃ© BeltrÃ¡n Peinado']
# ['K. Vermeer', 'Kenneth Vermeer']
# ['FontÃ\xa0s', 'Andreu FontÃ\xa0s Prat']
# ['L. QuiÃ±ones', 'Luis Enrique QuiÃ±Ã³nes']
# ['M. Leckie', 'Mathew Leckie']
# ['TchÃª TchÃª', 'Danilo das Neves Pinheiro']
# ['S. March', 'Solly March']
# ['B. Dabo', 'Bryan Dabo']
# ['F. MidtsjÃ¸', 'Fredrik MidtsjÃ¸']
# ['Arribas', 'Alejandro Arribas Garrido']
# ['Duirval Diniz', 'Duirval HÃ©lton Diniz Cabral']
# ['O. Watkins', 'Ollie Watkins']
# ['R. Tapia', 'Renato Tapia']
# ['E. Roco', 'Enzo Pablo Roco Roco']
# ['J. Svensson', 'Jonas Svensson']
# ['L. OrbÃ¡n', 'Lucas Alfonso OrbÃ¡n Alegre']
# ['G. Donsah', 'Godfred Donsah']
# ['L. KrejÄ\x8dÃ\xad', 'Ladislav KrejÄ\x8dÃ\xad']
# ['S. Sinclair', 'Scott Sinclair']
# ['B. JokiÄ\x8d', 'Bojan JokiÄ\x8d']
# ['M. Thuram', 'Marcus Thuram']
# ['S. Romero', 'Silvio Ezequiel Romero']
# ['C. Atsu', 'Christian Atsu']
# ['C. TrÃ¤sch', 'Christian TrÃ¤sch']
# ['F. Pogba', 'Florentin Pogba']
# ['ReguilÃ³n', 'Sergio ReguilÃ³n RodrÃ\xadguez']
# ['Caio MilaÃ§ar', 'Caio Bruno MilaÃ§ar Kenedy']
# ['M. Kempf', 'Marc-Oliver Kempf']
# ['Daniel Ayala', 'Daniel SÃ¡nchez Ayala']
# ['P. Roberts', 'Patrick Roberts']
# ['G. OrtÃ\xadz', 'Guillermo OrtÃ\xadz']
# ['R. Gikiewicz', 'RafaÅ‚ Gikiewicz']
# ['R. Rey', 'Rodrigo Rey']
# ['Y. Ã–ztekin', 'Yasin Ã–ztekin']
# ['Daniel Candeias', 'Daniel JoÃ£o Santos Candeias']
# ['C. Beauvue', 'Claudio Beauvue']
# ['Marcelo', 'Marcelo dos Santos Ferreira']
# ['S. von Bergen', 'Steve von Bergen']
# ['J. Obi', 'Joel Obi']
# ['Rafael LeÃ£o', 'Rafael da ConceiÃ§Ã£o LeÃ£o']
# ['Pedro Henrique', 'Pedro K. Medina da Silva']
# ['RaÃºl FernÃ¡ndez', 'RaÃºl FernÃ¡ndez-Cavada Mateos']
# ['Y. Nagatomo', 'é•·å\x8f‹ ä½‘éƒ½']
# ['P. HroÅ¡ovskÃ½', 'Patrik HroÅ¡ovskÃ½']
# ['R. BeriÄ‡', 'Robert BeriÄ‡']
# ['N. Spolli', 'NicolÃ¡s Federico Spolli']
# ['L. Moore', 'Liam Moore']
# ['D. Falcinelli', 'Diego Falcinelli']
# ['J. Babin', 'Jean-Sylvain Claude Babin']
# ['J. Kopic', 'Jan Kopic']
# ['M. Besler', 'Matt Besler']
# ['P. Martinez', 'Pablo Martinez']
# ['Renan Bressan', 'Renan Bardini Bressan']
# ['O. Åžahan', 'Olcay Åžahan']
# ['M. Rensing', 'Michael Rensing']
# ['K. Phillips', 'Kalvin Phillips']
# ['W. Janssen', 'Willem Janssen']
# ['E. Mena', 'Eugenio Mena']
# ['A. Ciciretti', 'Amato Ciciretti']
# ['Davidson', 'Davidson da Luz Pereira']
# ['Diogo Leite', 'Diogo Filipe Monteiro Pinto Leite']
# ['A. Raggi', 'Andrea Raggi']
# ['S. Grandsir', 'Samuel Grandsir']
# ['D. Kreilach', 'Damir Kreilach']
# ['A. Ruiz', 'Alan Ruiz']
# ['IÃ±igo PÃ©rez', 'IÃ±igo PÃ©rez Soto']
# ['L. SanÃ©', 'Ludovic Lamine SanÃ©']
# ['Ivo', 'OlÃ\xadvio da Rosa']
# ['Gil Dias', 'Gil BastiÃ£o Dias']
# ['A. Mena', 'Ã\x81ngel Mena']
# ['J. CÃ³rdoba', 'Jhon CÃ³rdoba']
# ['B. EcuÃ©lÃ© Manga', 'Bruno Ã‰cuÃ©lÃ© Manga']
# ['N. Murru', 'Nicola Murru']
# ['G. Shinnie', 'Graeme Shinnie']
# ['J. Stryger Larsen', 'Jens Stryger Larsen']
# ['A. Erokhin', 'Aleksandr Erokhin']
# ['L. Robles', 'Luis Robles']
# ['A. Ulmer', 'Andreas Ulmer']
# ['F. Castillo', 'FabiÃ¡n Castillo']
# ['I. Nestorovski', 'Ilija Nestorovski']
# ['M. Mount', 'Mason Mount']
# ['O. Kayode', 'Olarenwaju Ayoba Kayode']
# ['Jadson Vidigal', 'Matheus Jadson Vidigal Morais']
# ['P. Verhaegh', 'Paul Verhaegh']
# ['L. Cavallini', 'Lucas Cavallini']
# ['J. Geis', 'Johannes Geis']
# ['R. van Wolfswinkel', 'Ricky van Wolfswinkel']
# ['K. Adams Nuhu', 'Kasim Adams Nuhu']
# ['KÃ©vin Rodrigues', 'KÃ©vin Manuel Rodrigues']
# ['Ramalho', 'JonÃ¡s  Ramalho Chimeno']
# ['A. Semenov', 'Andrey Semenov']
# ['G. Charbonnier', 'GaÃ«tan Charbonnier']
# ['Luisinho', 'Luis Carlos Correia Pinto']
# ['E. Pieters', 'Erik Pieters']
# ['H. Wolf', 'Hannes Wolf']
# ['J. Aidoo', 'Joseph Aidoo']
# ['NicolÃ¡s Formido', 'NicolÃ¡s JÃºlio Formido Paiva']
# ['D. Kourmpelis', 'Dimitrios Kourmpelis']
# ['J. VukoviÄ‡', 'JagoÅ¡ VukoviÄ‡']
# ['J. Beausejour', 'Jean AndrÃ© Emanuel Beausejour Coliqueo']
# ['M. Ostrzolek', 'Matthias Ostrzolek']
# ['J. BÅ‚aszczykowski', 'Jakub BÅ‚aszczykowski']
# ['D. Bouanga', 'Denis Bouanga']
# ['R. Botta', 'RubÃ©n Botta']
# ['D. LazoviÄ‡', 'Darko LazoviÄ‡']
# ['L. MarkoviÄ‡', 'Lazar  MarkoviÄ‡']
# ['FÃ¡bio Espinho', 'FÃ¡bio Ricardo Gomes Fonseca']
# ['Ruben Lima', 'Ruben Alexandre Rocha Lima']
# ['T. Usami', 'å®‡ä½\x90ç¾Ž è²´å\x8f²']
# ['E. Room', 'Eloy Room']
# ['K. KonatÃ©', 'Koffi Cheikh KonatÃ©']
# ['RubÃ©n Alcaraz', 'RubÃ©n Alcaraz JimÃ©nez']
# ['A. Nyom', 'Allan Nyom']
# ['Yuri Ribeiro', 'Yuri Oliveira Ribeiro']
# ['M. Ekici', 'Mehmet Ekici']
# ['I. Sosa', 'VÃ\xadctor Ismael Sosa']
# ['L. Melgarejo', 'Lorenzo AntÃ³nio Melgarejo Sanabria']
# ['William', 'William Alves de Oliveira']
# ['M. Vydra', 'MatÄ›j Vydra']
# ['BebÃ©', 'Tiago Manuel Dias Correia']
# ['AdriÃ¡n GonzÃ¡lez', 'AdriÃ¡n  GonzÃ¡lez Morales']
# ['C. SÃ¶yÃ¼ncÃ¼', 'Ã‡aÄŸlar SÃ¶yÃ¼ncÃ¼']
# ['K. Iheanacho', 'Kelechi Iheanacho']
# ['M. Tisserand', 'Marcel Tisserand']
# ['A. Lozano', 'Anthony RubÃ©n Lozano ColÃ³n']
# ['L. Waldschmidt', 'Luca Waldschmidt']
# ['Adrianiscito', 'Adriano Leandro Soares Taffarel']
# ['S. Grytebust', 'Sten Michael Grytebust']
# ['I. StriniÄ‡', 'Ivan StriniÄ‡']
# ['Pedro Rebocho', 'Pedro Miguel Braga Rebocho']
# ['J. Mbakogu', 'Jerry Mbakogu']
# ['DÃ³ria', 'Matheus DÃ³ria Macedo']
# ['M. Ã‡aÄŸÄ±ran', 'Musa Ã‡aÄŸÄ±ran']
# ['K. Kamara', 'Kaiansu Kei Kamara']
# ['S. Bahoken', 'StÃ©phane Bahoken']
# ['B. Gibson', 'Ben Gibson']
# ['Nacho', 'JosÃ© Ignacio MartÃ\xadnez GarcÃ\xada']
# ['A. Cornelius', 'Andreas Evald Cornelius']
# ['M. Le Marchand', 'Maxime Le Marchand']
# ['P. Diop', 'Pape Cheikh Diop Gueye']
# ['S. Ã–zbayraklÄ±', 'Åžener Ã–zbayraklÄ±']
# ['S. Davis', 'Steven Davis']
# ['A. Baba', 'Abdul Rahman Baba']
# ['E. ZukanoviÄ‡', 'Ervin ZukanoviÄ‡']
# ['O. Niasse', 'El-Hadji Baye Oumar Niasse']
# ['P. Mpoku', "Paul-JosÃ© M'Poku Ebunge"]
# ['K. McDonald', 'Kevin McDonald']
# ['Jesus Andradaldo', 'Jesus FabrÃ\xadcio Andrade SimÃµes']
# ['S. Dzhanaev', 'Soslan Dzhanaev']
# ['M. Degenek', 'MiloÅ¡ Degenek']
# ['A. Tameze', 'Adrien Tameze']
# ['Tiago Silva', 'Tiago Rafael Maia Silva']
# ['E. BauthÃ©ac', 'Ã‰ric BauthÃ©ac']
# ['Y. Ravet', 'Yoric Ravet']
# ['D. ToÅ¡iÄ‡', 'DuÅ¡ko ToÅ¡iÄ‡']
# ['D. Padelli', 'Daniele Padelli']
# ['B. Mensah', 'Bernard Mensah']
# ['J. Biabiany', 'Jonathan Ludovic Biabiany']
# ['I. IliÄ\x8deviÄ‡', 'Ivo IliÄ\x8deviÄ‡']
# ['H. Barnes', 'Harvey Lewis Barnes']
# ['C. Awaziem', 'Chidozie Collins Awaziem']
# ['Luna', 'Antonio Manuel Luna RodrÃ\xadguez']
# ['A. Chedjou', 'AurÃ©lien Chedjou']
# ['Djavan', 'Djavan da Silva Ferreira']
# ['A. Rebrov', 'Artem Rebrov']
# ['G. Margreitter', 'Georg Margreitter']
# ['Salvi SÃ¡nchez', 'Salvador SÃ¡nchez Ponce']
# ['Pietrson Mendes', 'Pietro MaurÃ\xadcio Mendes Abranches']
# ['M. Russ', 'Marco Russ']
# ['H. Van Crombrugge', 'Hendrik Van Crombrugge']
# ['A. Barrada', 'Abdelaziz Barrada']
# ['K. Nakamura', 'ä¸\xadæ\x9d‘ å®ªå‰›']
# ['A. Clayton', 'Adam Clayton']
# ['T. Leibold', 'Tim Leibold']
# ['V. Karavaev', 'Vyacheslav Karavaev']
# ['I. Fossum', 'Iver Fossum']
# ['D. Bessa', 'Daniel Bessa']
# ['N. Acevedo', 'Nelson Acevedo']
# ['S. Rybalka', 'Sergiy Rybalka']
# ['G. Di Lorenzo', 'Giovanni Di Lorenzo']
# ['H. Diallo', 'Habib Diallo']
# ['B. FernÃ¡ndez', 'Brian FernÃ¡ndez']
# ['J. Basanta', 'JosÃ© MarÃ\xada Basanta']
# ['S. Thioub', 'Sada Thioub']
# ['C. Adams', 'Che Adams']
# ['Jota', 'JosÃ© Ignacio Peleteiro Ramallo']
# ['E. Crivelli', 'Enzo Crivelli']
# ['Etxeita', 'Xabier Etxeita Gorritxategi']
# ['D. Ciofani', 'Daniel Ciofani']
# ['M. Urruti', 'Maximiliano Urruti']
# ['Gerso', 'Gerso Fernandes']
# ['J. Å\xa0ural', 'Josef Å\xa0ural']
# ['B. Celina', 'Bersant Celina']
# ['S. Al Faraj', 'Salman Mohammed Al Faraj']
# ['L. Majer', 'Lovro Majer']
# ['J. St. Juste', 'Jeremiah St. Juste']
# ['M. BolaÃ±os', 'Miler Alejandro BolaÃ±os Reascos']
# ['R. Krishna', 'Roy Krishna']
# ['E. Goldaniga', 'Edoardo Goldaniga']
# ['Suk Hyun Jun', 'ì„\x9dí˜„ì¤€ çŽ„é“‰ä¿Š']
# ['MÃ\xadchel', 'Miguel Alfonso Herrero Javaloyas']
# ['Ã\x81lex Gallar', 'Ã\x81lejandro Gallar Falguero']
# ['Insua', 'Pablo Insua Blanco']
# ['Ignasi Miquel', 'Ignasi Miquel i Pons']
# ['L. Bustamante', 'Luis Gonzalo Bustamante']
# ['E. Schelotto', 'Ezequiel Schelotto']
# ['Paulinho', 'Paulo SÃ©rgio Mota']
# ['F. HÃ¼bner', 'Florian HÃ¼bner']
# ['Castro', 'AndrÃ© de Castro Pereira']
# ['R. Aliendro', 'Rodrigo Aliendro']
# ['M. Kanazaki', 'é‡‘å´Ž å¤¢ç”Ÿ']
# ['S. Sunzu', 'Stoppila Sunzu']
# ['Y. Sanogo', 'Yaya Sanogo']
# ['T. Minamino', 'å\x8d—é‡Ž æ‹“å®Ÿ']
# ['S. Dioudis', 'Sokratis Dioudis']
# ['J. Al Hussien', 'Jehad Fadel Al Hussain']
# ['Raul GarcÃ\xada', 'RaÃºl GarcÃ\xada Carnero']
# ['S. Bertoli', 'SebastiÃ¡n HernÃ¡n Bertoli']
# ['J. GÃ©lin', 'JÃ©rÃ©my GÃ©lin']
# ['J. MiÅ¡iÄ‡', 'Josip MiÅ¡iÄ‡']
# ['Fabiano', 'Fabiano Ribeiro de Freitas']
# ['O. Mangala', 'Orel Mangala']
# ['J. Toljan', 'Jeremy Toljan']
# ['J. Gandolfi', 'Javier Marcelo Gandolfi']
# ['J. Lewis', 'Joe Lewis']
# ['J. BoÅ™il', 'Jan BoÅ™il']
# ['S. Clucas', 'Sam Clucas']
# ['A. GrÃ¼nwald', 'Alexander GrÃ¼nwald']
# ['J. Poulsen', 'Jakob Bendix Uhd Poulsen']
# ['C. Montes', 'CÃ©sar Jasib Montes Castro']
# ['R. Meggiorini', 'Riccardo Meggiorini']
# ['N. Bungert', 'Niko Bungert']
# ['C. KouamÃ©', 'Christian KouamÃ©']
# ['F. Meza', 'Francisco Javier Meza Palma']
# ['A. HenrÃ\xadquez', 'Ã\x81ngelo HenrÃ\xadquez']
# ['NÃ©lson Oliveira', 'NÃ©lson Miguel Castro Oliveira']
# ['E. Terranova', 'Emanuele Terranova']
# ['R. Emond', 'Renaud Emond']
# ['G. Hooper', 'Gary Hooper']
# ['L. Freeman', 'Luke Anthony Freeman']
# ['Miguel Vieira', 'LuÃ\xads Miguel Vieira da Silva']
# ['A. Rispoli', 'Andrea Rispoli']
# ['N. Navarro', 'NicolÃ¡s GastÃ³n Navarro']
# ['A. Barboza', 'Alexander Nahuel Barboza UllÃºa']
# ['A. Maxim', 'Alexandru Iulian Maxim']
# ['O. John', 'Ola John']
# ['A. Smithies', 'Alex Smithies']
# ['P. Barrientos', 'Pablo CÃ©sar Barrientos']
# ['F. Rinaudo', 'FabiÃ¡n AndrÃ©s Rinaudo']
# ['L. Mazzitelli', 'Luca Mazzitelli']
# ['Eduardo', 'Eduardo AntÃ´nio Machado Teixeira']
# ['G. Pazzini', 'Giampaolo Pazzini']
# ['A. Bamba', 'Abdoulaye Bamba']
# ['A. Mina', 'Arturo Mina']
# ['I. Mbaye', 'Ibrahima Mbaye']
# ['M. Tekdemir', 'Mahmut Tekdemir']
# ['L. BuriÃ¡n', 'Leonardo FabiÃ¡n BuriÃ¡n Castro']
# ['Michel Cruceiro', 'Michel David Cruceiro Muscato']
# ['Ricardo', 'Ricardo Jorge Vaz TÃ©']
# ['Y. Gordillo', 'Yeison Stiven Gordillo Vargas']
# ['G. Peruzzi', 'Gino Peruzzi']
# ['Yu Hanchao', 'æ±‰è¶…äºŽ']
# ['K. Westwood', 'Keiren Westwood']
# ['Evandro Rochedo', 'Evandro SÃ©rgio Rochedo Paulino']
# ['Dani Pacheco', 'Daniel Pacheco Lobato']
# ['A. RÃ\xados', 'Antonio RÃ\xados MartÃ\xadnez']
# ['D. Kadah', 'Deniz Kadah']
# ['A. Diakhaby', 'Adama Diakhaby']
# ['Juan Carlos', 'Juan Carlos MartÃ\xadn Corral']
# ['I. Success', 'Isaac Success']
# ['S. Al Dawsari', 'Salem Al Dawsari']
# ['A. Ã–zbiliz', 'Aras Ã–zbiliz']
# ['G. Banguera', 'Geovanni Banguera']
# ['K. Johnsson', 'Karl-Johan Johnsson']
# ['U. Demirok', 'UÄŸur Demirok']
# ['N. Asare', 'Nana Kwesi Asare']
# ['M. Pucciarelli', 'Manuel Pucciarelli']
# ['D. Fagundez', 'Diego Santiago FagÃºndez Pepe']
# ['W. Troost-Ekong', 'William Troost-Ekong']
# ['Paulinho', 'Paulo JosÃ© de Oliveira']
# ['J. Foyth', 'Juan Marcos Foyth']
# ['M. Linnes', 'Martin Linnes']
# ['Serginho', 'SÃ©rgio AntÃ´nio Soler Oliveira Jr']
# ['HÃ©lder Lopes', 'HÃ©lder Filipe Oliveira Lopes']
# ['E. Berg', 'Erik Berg']
# ['R. Bengtsson', 'Rasmus Bengtsson']
# ['F. Forestieri', 'Fernando MartÃ\xadn Forestieri']
# ['K. Wilczek', 'Kamil Wilczek']
# ['G. Cimirot', 'Gojko Cimirot']
# ['I. Bennacer', 'IsmaÃ«l Bennacer']
# ['L. Marrone', 'Luca Marrone']
# ['R. Halliche', 'Rafik Halliche']
# ['V. Vada', 'ValentÃ\xadn Vada']
# ['Y. Bissouma', 'Yves Bissouma']
# ['R. Salinas', 'Rodrigo Salinas Dorantes']
# ['R. Doan', 'å\xa0‚å®‰ å¾‹']
# ['F. Pardo', 'Ã‰dgar Felipe Pardo Castro']
# ['J. Duque', 'Jhon Duque']
# ['D. Jensen', 'David Jensen']
# ['Omar Ramos', 'JuliÃ¡n Omar Ramos SuÃ¡rez']
# ['D. Randolph', 'Darren Randolph']
# ['S. Sensi', 'Stefano Sensi']
# ['A. Ricaurte', 'AndrÃ©s Ricaurte VÃ©lez']
# ['M. Aguirregaray', 'MatÃ\xadas Aguirregaray Guruceaga']
# ['JoÃ£o Carvalho', 'JoÃ£o AntÃ³nio Antunes Carvalho']
# ['A. Zeneli', 'ArbÃ«r Zeneli']
# ['D. Dainelli', 'Dario Dainelli']
# ['K. Hansen', 'Kian Hansen']
# ['R. Bennett', 'Ryan Bennett']
# ['Lee Chung Yong', 'ì\x9d´ì²\xadìš© æ\x9dŽé\x9d’é¾™']
# ['V. Verre', 'Valerio Verre']
# ['Kwoun Sun Tae', 'ê¶Œìˆœíƒœ æ\x9dƒçº¯æ³°']
# ['Mauro Cildinho', 'Mauro Pierre Cildinho Conradi']
# ['Edinho', 'Arnaldo Edi Lopes da Silva']
# ['L. Pisculichi', 'Leonardo NicolÃ¡s Pisculichi']
# ['Y. Benalouane', 'Yohan Benalouane']
# ['A. Ragusa', 'Antonino Ragusa']
# ['F. Lemoine', 'Fabien Lemoine']
# ['C. Roldan', 'Cristian Roldan']
# ['D. Ndong', 'Didier  Ndong Ibrahim']
# ['V. Coufal', 'VladimÃ\xadr Coufal']
# ['M. OrÅ¡iÄ‡', 'Mislav OrÅ¡iÄ‡']
# ['Ã‰dundo Oliveira', 'Ã‰der Marvin Oliveira SimÃ£o']
# ['B. Bannan', 'Barry Bannan']
# ['R. Koch', 'Robin Koch']
# ['N. Pasquini', 'NicolÃ¡s Pasquini']
# ['A. Rosina', 'Alessandro Rosina']
# ['T. Parker', 'Tim Parker']
# ['Marcos Guilherme', 'Marcos G. Santos Matos']
# ['D. Luckassen', 'Derrick Luckassen']
# ['S. Hutchinson', 'Shaun Hutchinson']
# ['Bruno Lamas', 'Bruno JosÃ© Pavani Lamas']
# ['A. BÄƒlutÄƒ', 'Alexandru BÄƒlutÄƒ']
# ['De las Cuevas', 'Miguel Ã\x81ngel De las Cuevas BarberÃ¡']
# ['LÃ©o Bonatini', 'Leonardo B. Lohner Maia']
# ['D. KolÃ¡Å™', 'Daniel KolÃ¡Å™']
# ['T. Aoyama', 'é\x9d’å±± æ•\x8få¼˜']
# ['S. Montoya', 'Santiago Montoya']
# ['V. Aguilera', 'Victor Emanuel Aguilera']
# ['H. Yamaguchi', 'å±±å\x8f£ è›\x8d']
# ['I. Mboyo', 'Ilombe Mboyo']
# ['Bruno Tabata', 'Bruno VinÃ\xadcius Souza Ramos']
# ['B. BariÅ¡iÄ‡', 'Borna BariÅ¡iÄ‡']
# ['Wilson ManafÃ¡', 'Wilson MiguÃ©is ManafÃ¡ JancÃ³']
# ['C. NÃ¸rgaard', 'Christian NÃ¸rgaard']
# ['G. Friend', 'George Friend']
# ['D. Khocholava', 'Davit Khotcholava']
# ['B. Srarfi', 'Bassem  Srarfi']
# ['Romarinho', 'RomÃ¡rio Ricardo da Silva']
# ['Mateus', 'Mateus Galiano da Costa']
# ['W. Hoolahan', 'Wes Hoolahan']
# ['R. Azeez', 'Ramon Olamilekan Azeez']
# ['M. Frey', 'Michael Frey']
# ['J. Akpa Akpro', 'Jean-Daniel Akpa Akpro']
# ['Isaac Cuenca', 'Joan Isaac Cuenca LÃ³pez']
# ['FÃ¡bio Pacheco', 'FÃ¡bio JosÃ© Ferreira Pacheco']
# ['Lucas Piazon', 'Gustavo Lucas Domingues Piazon']
# ['Timo Triano', 'Timoteo Samuel Triano Branco']
# ['A. Scholz', 'Alexander Scholz']
# ['Y. Chibsah', 'Yussif Raman Chibsah']
# ['M. Duffy', 'Mark Duffy']
# ['G. McAuley', 'Gareth McAuley']
# ['N. Al Abed', 'Nawaf Shaker Al Abid']
# ['Alessinito', 'Alessandro Nuno Vaz Laranjeiras']
# ['D. Verde', 'Daniele Verde']
# ['P. Lasogga', 'Pierre-Michel Lasogga']
# ['M. Pack', 'Marlon Pack']
# ['Z. Ferhat', 'Zinedine Ferhat']
# ['C. Marshall', 'Chad Marshall']
# ['J. Bahebeck', 'Jean-Christophe Bahebeck']
# ['R. Espinoza', 'RÃ³ger Espinoza RamÃ\xadrez']
# ['N. GonzÃ¡lez', 'NicolÃ¡s IvÃ¡n GonzÃ¡lez']
# ['Nuno Santos', 'Nuno Miguel Gomes dos Santos']
# ['K. Kusk', 'Kasper Kusk Vangsgaard']
# ['E. Lamanna', 'Eugenio Lamanna']
# ['G. Sunu', 'Gilles Sunu']
# ['E. Berggreen', 'Emil Berggreen']
# ['G. NÃºÃ±ez', 'Jonathan Guillermo NuÃ±ez Espinoza']
# ['L. Aued', 'Luciano Aued']
# ['Hao Junmin', 'è’¿ä¿Šé—µ']
# ['V. GÄƒman', 'Marius ValericÄƒ GÄƒman']
# ['Pulido', 'Jorge Pulido Mayoral']
# ['A. Mobara', 'Abbubaker Mobara']
# ['J. Ledley', 'Joe Ledley']
# ['A. Ã‡alÄ±k', 'Ahmet Ã‡alÄ±k']
# ['A. Cerri', 'Alberto Cerri']
# ['Kim Jin Su', 'í‚´ì§„ìˆ˜ é‡‘ç\x8f\x8dæ´™']
# ['C. GytkjÃ¦r', 'Christian GytkjÃ¦r']
# ['Kangin Lee', 'ì\x9d´ê°•ì\x9d¸ Kangin Lee']
# ['Edigar Junio', 'Edigar Junio Teixeira Lima']
# ['J. Bostock', 'John Bostock']
# ['S. Pellissier', 'Sergio Pellissier']
# ['M. Antonsson', 'Marcus Antonsson']
# ['M. Kean', 'Moise Kean']
# ['J. Collins', 'James  Collins']
# ['N. Mushekwi', 'Nyasha Liberty Mushekwi']
# ['L. JimÃ©nez', 'Leiton JimÃ©nez']
# ["D. N'Dinga", 'Delvin Nâ€™Dinga']
# ['F. Kroos', 'Felix Kroos']
# ['M. Mahi', 'Mimoun Mahi']
# ['J. van Overeem', 'Joris van Overeem']
# ['A. Esswein', 'Alexander Esswein']
# ['J. Moreira', 'Jorge Moreira']
# ['Jorge Carvallinho', 'Jorge Pietro Carvalho PorfÃ\xadrio']
# ['J. Pereira', 'Jair Pereira RodrÃ\xadguez']
# ['N. GaloviÄ‡', 'Nino GaloviÄ‡']
# ['S. Mosquera', 'HÃ¡rold Santiago  Mosquera Caicedo']
# ['J. Nieto', 'Juan Pablo Nieto Salazar']
# ['C. Yacob', 'Claudio Ariel Yacob']
# ['L. Ajorque', 'Ludovic Ajorque']
# ['H. Barcos', 'HernÃ¡n Barcos']
# ['S. Nakamura', 'ä¸\xadæ\x9d‘ ä¿Šè¼”']
# ['M. Doumbia', 'Moussa Doumbia']
# ['G. Tutino', 'Gennaro Tutino']
# ['A. Allione', 'AgustÃ\xadn Allione']
# ['G. Lanaro', 'GermÃ¡n Lanaro']
# ['W. Zimmerman', 'Walker Zimmerman']
# ['L. Rizzo', 'Luca Rizzo']
# ['R. GutiÃ©rrez', 'Roberto Carlos GutiÃ©rrez Gamboa']
# ['M. GavranoviÄ‡', 'Mario GavranoviÄ‡']
# ['O. HurmacÄ±', 'Ã–zer HurmacÄ±']
# ['A. Tello', 'Andres Tello']
# ['S. Gustafson', 'Simon Gustafson']
# ['F. Ceravolo', 'Fabio Giovanni Ceravolo']
# ['F. Coloccini', 'Fabricio Coloccini']
# ['G. Curci', 'Gianluca Curci']
# ['Daniel GuimarÃ£es', 'Daniel Martins GuimarÃ£es']
# ['E. HallfreÃ°sson', 'Emil HallfreÃ°sson']
# ['M. Albornoz', 'Miiko MartÃ\xadn Albornoz Inola']
# ['J. Mercier', 'Juan Ignacio Mercier']
# ['M. Donald', 'Mitchell Glenn Donald']
# ['M. Cuisance', 'MickaÃ«l Cuisance']
# ['A. Warda', 'Amr Warda']
# ['A. TraorÃ©', 'Adama TraorÃ©']
# ['O. McBurnie', 'Oliver McBurnie']
# ['Dankler', 'Dankler LuÃ\xads de Jesus Pedreira']
# ['M. Goicoechea', 'Mauro Daniel Goicoechea Furia']
# ['L. Andersen', 'Lucas  Andersen']
# ['C. Obasi', 'Chinedu Obasi Ogbuke']
# ['T. Howard', 'Tim Howard']
# ['H. Goitom', 'Henok Goitom']
# ['S. Khaoui', 'SaÃ®f-Eddine Khaoui']
# ['R. van La Parra', 'Rajiv van La Parra']
# ['AdriÃ¡n MarÃ\xadn', 'AdriÃ¡n MarÃ\xadn GÃ³mez']
# ['L. Menossi', 'Lucas Menossi']
# ['JosuÃ© SÃ¡', 'JosuÃ© Humberto GonÃ§alves Leal SÃ¡']
# ['A. Chatzigiovanis', 'Anastasios Chatzigiovanis']
# ['Cristian Lodeira', 'Cristian Enzo Lodeira Araujo']
# ['A. Pantic', 'Aleksandar PantiÄ‡']
# ['J. Rojas', 'Jorge Luis Rojas Meza']
# ['F. Klos', 'Fabian Klos']
# ['C. RamÃ\xadrez', 'Cristian Leonel RamÃ\xadrez Zambrano']
# ['J. Boye', 'John Boye']
# ['M. Malyshev', 'Maksym Malyshev']
# ['Douglas', 'Douglas Pereira dos Santos']
# ['K. Boyd', 'Kris Boyd']
# ['D. RodrÃ\xadguez', 'Diego RodrÃ\xadguez']
# ['M. MÃ¸ller DÃ¦hli', 'Mats  MÃ¸ller DÃ¦hli']
# ['S. Polter', 'Sebastian Polter']
# ['R. van Rhijn', 'Ricardo van Rhijn']
# ['N. MaraÅ¡', 'Nikola MaraÅ¡']
# ['L. Castellanos', 'AndrÃ©s Leandro Castellanos Serrano']
# ['A. Biyogo Poko', 'AndrÃ© Biyogo Poko']
# ['J. Otero', 'Juan Ferney Otero Tovar']
# ['N. Boilesen', 'Nicolai MÃ¸ller Boilesen']
# ['D. Lainez', 'Diego Lainez Leyva']
# ['Y. Al Shahrani', 'Yasser Al Shahrani']
# ['I. DiomandÃ©', 'IsmaÃ«l TiÃ©moko DiomandÃ©']
# ['D. Dibusz', 'DÃ©nes Dibusz']
# ['D. KÄ…dzior', 'Damian KÄ…dzior']
# ['J. Bottinelli', 'Jonathan Pablo Bottinelli']
# ['G. Barry', 'Gareth Barry']
# ['R. Kruse', 'Robbie Kruse']
# ['C. Bernardi', 'Cristian Oscar Bernardi']
# ['E. Ã\x81vila', 'Ezequiel Ã\x81vila']
# ['N. RadonjiÄ‡', 'Nemanja RadonjiÄ‡']
# ['Jeff Meirson', 'Jeff Nazario Meire Costinho']
# ['J. GÃ¼emez', 'Javier GÃ¼emez LÃ³pez']
# ['J. Jones', 'Jordan Jones']
# ['D. Guzman', 'David Guzman']
# ['A. ZaldÃ\xadvar', 'Ã\x81ngel ZaldÃ\xadvar Caviedes']
# ['S. Tibbling', 'Simon Tibbling']
# ['Joshuando SÃ¡', 'Joshua Eduardo SÃ¡ Madeira']
# ['A. De Sart', 'Alexis De Sart']
# ['W. Owusu', 'William Owusu']
# ['M. Abarhoun', 'Mohamed Aberhoune']
# ['J. Puncheon', 'Jason Puncheon']
# ['M. Stiepermann', 'Marco Stiepermann']
# ['M. Demir', 'Muhammet Demir']
# ['Salva Sevilla', 'Salvador Sevilla LÃ³pez']
# ['B. Kololli', 'Benjamin Kololli']
# ['J. BÃ¶rner', 'Julian BÃ¶rner']
# ['Ricardo Ryller', 'Ricardo Ryller Ribeiro Lino Silva']
# ['B. BiaÅ‚kowski', 'Bartosz BiaÅ‚kowski']
# ['M. Mantovani', 'MartÃ\xadn Maximiliano Mantovani']
# ['S. Ortega', 'Stefan Ortega Moreno']
# ['S. GÃ¼rler', 'Serdar GÃ¼rler']
# ['J. Bennett', 'Joe Bennett']
# ['Rui Fonte', 'Rui Pedro da Rocha Fonte']
# ['A. Adnan', 'Ali Adnan']
# ['Luismi', 'Luis Miguel SÃ¡nchez BenÃ\xadtez']
# ['L. Garritano', 'Luca Garritano']
# ['A. Cubas', 'AdriÃ¡n AndrÃ©s Cubas']
# ['Jubal', 'Jubal Rocha Mendes Junior']
# ['L. Phiri', 'Lebogang Phiri']
# ['T. Delaine', 'Thomas Delaine']
# ['J. Murphy', 'Jamie Murphy']
# ['Alexandre Frandeira', 'Alex Martin Frandeira Ã\x81lvares']
# ['R. GarcÃ\xada GuerreÃ±o', 'Rolando GarcÃ\xada GuerreÃ±o']
# ['K. Sema', 'Ken Sema']
# ['Reyes', 'JosÃ© Antonio Reyes CalderÃ³n']
# ['I. HajroviÄ‡', 'Izet HajroviÄ‡']
# ['Fernando Boldrin', 'Fernando Henrique Boldrin']
# ['D. Peralta', 'Diego Arturo Peralta GonzÃ¡lez']
# ['SebÃ¡', 'SebastiÃ£o de Freitas Couto JÃºnior']
# ['U. Ä†osiÄ‡', 'UroÅ¡ Ä†osiÄ‡']
# ['F. Pisacane', 'Fabio Pisacane']
# ['D. Rossi', 'Diego Rossi']
# ['R. Alvarado', 'Roberto Alvarado']
# ['J. Brownhill', 'Josh Brownhill']
# ['M. Piedrahita', 'Marlon Javier Piedrahita LondoÃ±o']
# ['M. van der Werff', 'Maikel van der Werff']
# ['D. Dwyer', 'Dom Dwyer']
# ['G. Bettini', 'Gonzalo Bettini']
# ['P. Brlek', 'Petar Brlek']
# ['Miltisco Paulino', 'M. Vanderlei Paulino Kenedy']
# ['Tobias Figueiredo', 'Tobias Pereira Figueiredo']
# ['Erik MorÃ¡n', 'Erik MorÃ¡n Arribas']
# ['David Batanero', 'David Batanero PuigbÃ³']
# ['G. Holtmann', 'Gerrit Holtmann']
# ['A. Caracciolo', 'Antonio Aldo Caracciolo']
# ['A. AjdareviÄ‡', 'Astrit AjdareviÄ‡']
# ['Jung Sung Ryong', 'ì\xa0•ì„±ë£¡ éƒ‘ä¿ŠçŽ„']
# ['A. Kamara', 'Aboubakar Kamara']
# ['A. Preciado', 'Ayrton Preciado']
# ['M. Valenzuela', 'Milton Nahuel Valenzuela']
# ['E. Fernandes', 'Edimilson Fernandes']
# ['L. Memushaj', 'Ledian Memushaj']
# ['E. Kawashima', 'å·\x9då³¶ æ°¸å—£']
# ['J. FilipoviÄ‡', 'Jakov FilipoviÄ‡']
# ['A. Gogia', 'Akaki Gogia']
# ['D. Schmidt', 'Dominik Schmidt']
# ['Rodrigo BecÃ£o', 'Rodrigo Nascimento FranÃ§a']
# ['M. Friedrich', 'Marvin Friedrich']
# ['T. SchÃ¼tz', 'Tom SchÃ¼tz']
# ['S. Tecl', 'Stanislav Tecl']
# ['D. MiliÄ‡eviÄ‡', 'Danijel MiliÄ‡eviÄ‡']
# ['O. Fink', 'Oliver Fink']
# ['A. Tarek', 'Amro Tarek Abdel Aziz']
# ['M. JonjiÄ‡', 'Matej JonjiÄ‡']
# ['B. Heynen', 'Bryan Heynen']
# ['JoÃ£o Pedro', 'JoÃ£o Pedro Maturano dos Santos']
# ['D. Rosero Valencia', 'Daniel Rosero Valencia']
# ['R. Caroca', 'Rafael Antonio Caroca Cordero']
# ['Souza', 'Elierce Barbosa de Souza']
# ['K. Bonifazi', 'Kevin Bonifazi']
# ['D. Williams', 'Daniel Williams']
# ['O. Cabezas', 'Ã“scar Cabezas']
# ['C. Stengs', 'Calvin Stengs']
# ['Borja Lasso', 'Borja Lasso De La Vega']
# ['R. Oudin', 'RÃ©mi Oudin']
# ['R. RodrÃ\xadguez', 'Ribair RodrÃ\xadguez PÃ©rez']
# ['J. Campos', 'Jhasmani Campos']
# ['J. Rhodes', 'Jordan Rhodes']
# ['I. Å\xa0unjiÄ‡', 'Ivan Å\xa0unjiÄ‡']
# ['R. Thelander', 'Rasmus Thelander']
# ['N. Moro', 'Nikola Moro']
# ['M. Lustig', 'Mikael Lustig']
# ['S. Nishikawa', 'è¥¿å·\x9d å‘¨ä½œ']
# ['M. Torsiglieri', 'Marco Natanel Torsiglieri']
# ['P. Å\xa0kuletiÄ‡', 'Petar Å\xa0kuletiÄ‡']
# ['M. Caire', 'Maximiliano Caire']
# ['C. Lucchetti', 'Cristian David Lucchetti']
# ['B. Afobe', 'Benik Afobe']
# ['Carlitos', 'Carlos Alberto Alves Garcia']
# ['J. Bela', 'JÃ©rÃ©mie Bela']
# ['M. Coronel', 'Maximiliano Ã\x81ngel Coronel']
# ['Ricardo Valente', 'Ricardo Jorge Oliveira Valente']
# ['J. Perbet', 'JÃ©rÃ©my Perbet']
# ['A. Callens', 'Alexander MartÃ\xadn Marquinho Callens AsÃ\xadn']
# ['Adriano Facchini', 'Adriano Facchini']
# ['CarraÃ§a', 'Rui Filipe Caetano Moura']
# ['A. Rojas', 'Ariel Mauricio Rojas']
# ['D. Lenihan', 'Darragh Lenihan']
# ['B. McKay', 'Barrie McKay']
# ['N. Ghilas', 'Nabil Ghilas']
# ['Y. Kashiwa', 'æŸ\x8få¥½ æ–‡']
# ['D. DamjanoviÄ‡', 'Dejan DamjanoviÄ‡']
# ['F. Sammaritano', 'FrÃ©dÃ©ric Sammaritano']
# ['V. Fiorillo', 'Vincenzo Fiorillo']
# ['R. Keogh', 'Richard Keogh']
# ['Bressan', 'Matheus Simoneti Bressaneli']
# ['E. BaÅŸsan', 'Emrah BaÅŸsan']
# ['J. QuiÃ±ones', 'JuliÃ¡n AndrÃ©s QuiÃ±ones QuiÃ±ones']
# ['A. Soto', 'Alexis Soto']
# ['H. Novillo', 'Harry Novillo']
# ['C. Brunt', 'Chris Brunt']
# ['D. McGoldrick', 'David McGoldrick']
# ['K. Letica', 'Karlo Letica']
# ['L. Reyes', 'Luis Ricardo Reyes Moreno']
# ['L. Zingerle', 'Leopold Zingerle']
# ['F. MÃ¼ller', 'Florian MÃ¼ller']
# ['R. Tesche', 'Robert Tesche']
# ['U. Emanuelson', 'Urby Emanuelson']
# ['J. Abella', 'JosÃ© Javier Abella Fanjul']
# ['T. Kleindienst', 'Tim Kleindienst']
# ['M. Yumlu', 'Mustafa Yumlu']
# ['M. Matip', 'Marvin Matip']
# ['J. Sambenito', 'JosÃ© Gabriel Sambenito']
# ['S. Prevljak', 'Smail Prevljak']
# ['D. von Ballmoos', 'David von Ballmoos']
# ['A. Nwakaeme', 'Anthony Nwakaeme']
# ['D. Silva', 'David Mackalister Silva Mosquera']
# ['I. Oblyakov', 'Ivan Oblyakov']
# ['M. Fraga', 'Miguel Ã\x81ngel Fraga Licona']
# ['B. BaÅŸaÃ§Ä±koÄŸlu', 'Bilal BaÅŸaÃ§Ä±koÄŸlu']
# ['C. Bryson', 'Craig Bryson']
# ['D. Andrade', 'Darwin Zamir Andrade Marmolejo']
# ['E. Andersen', 'Eirik  Ulland Andersen']
# ['H. Dean', 'Harlee Dean']
# ['Edu Machado', 'Eduardo JosÃ© Borges Machado']
# ['E. Aguirre', 'Erick Germain Aguirre Tafolla']
# ['N. Leiva', 'MatÃ\xadas Nahuel Leiva Esquivel']
# ['Tiago', 'Tiago Alves Sales']
# ['K. Musona', 'Knowledge Musona']
# ['A. GonÃ§alves', 'Anthony GonÃ§alves']
# ['TorrejÃ³n', 'Marc TorrejÃ³n Moya']
# ['C. Pinares', 'CÃ©sar Ignacio Pinares Tamayo']
# ['R. Pucino', 'Raffaele Pucino']
# ['P. Barrera', 'Pablo Edson Barrera Acosta']
# ['Nascimentardo', 'Jonas Welson Orsi de Meneses']
# ['Heltinho Melo', 'Heltinho Melo Chaves']
# ['B. Koita', 'Bengali-FodÃ© Koita']
# ['Canella', 'Roberto Canella SuÃ¡rez']
# ['K. Lee', 'Kieran Lee']
# ['R. Mphahlele', 'Ramahlwe Mphahlele']
# ['K. MÃ¼ller', 'Kevin MÃ¼ller']
# ['J. Cuero', 'Jefferson Cuero Castro']
# ['J. Wallace', 'Jed Wallace']
# ['J. SÃ¡nchez', 'JesÃºs Enrique SÃ¡nchez GarcÃ\xada']
# ['S. Guirassy', 'Serhou Guirassy']
# ['L. Agbenyenu', 'Lumor Agbenyenu']
# ['J. Harrison', 'Jack Harrison']
# ['S. Schwab', 'Stefan Schwab']
# ['D. Burn', 'Dan Burn']
# ['M. Correia', 'Marcel Correia']
# ['Marlion Rolim', 'Marlion RÃ´mulo Rolim Nascimento']
# ['S. Michel', 'Sven Michel']
# ['P. Olkowski', 'PaweÅ‚ Olkowski']
# ['G. Loria', 'Giorgi Loria']
# ['Javi Castellano', 'Javier Castellano Betancor']
# ['M. Fouzair', 'Mohamed Fouzair']
# ['C. YambÃ©rÃ©', 'CÃ©dric YambÃ©rÃ©']
# ['B. Sanneh', 'Bubacarr Sanneh']
# ['H. Reed', 'Harrison Reed']
# ['Fernando', 'Fernando Dos Santos Pedro']
# ['S. PlavÅ¡iÄ‡', 'Srdjan PlavÅ¡iÄ‡']
# ['J. Morrison', 'James  Morrison']
# ['D. Machado', 'Deiver Machado']
# ['P. DÃ\xadaz', 'Paulo CÃ©sar DÃ\xadaz Huincales']
# ['A. Khalili', 'Abdul Rahman Khalili']
# ['K. Kerschbaumer', 'Konstantin Kerschbaumer']
# ['S. MedojeviÄ‡', 'Slobodan MedojeviÄ‡']
# ['G. Berardi', 'Gaetano Berardi']
# ['Thiago Santana', 'Thiago Santos Santana']
# ['M. MaloÄ\x8da', 'Mario MaloÄ\x8da']
# ['Negueba', 'Guilherme Ferreira Pinto']
# ['S. Malone', 'Scott Malone']
# ['J. Cooper', 'Jake Cooper']
# ['H. Abe', 'é˜¿éƒ¨ æµ©ä¹‹']
# ['RaÃºl Lizoain', 'RaÃºl LizoÃ¡in Cruz']
# ['K. Lafferty', 'Kyle Lafferty']
# ['Wiliam Santinho', 'Wiliam Carlos Santoso Sampaio']
# ['T. Beugelsdijk', 'Tom Beugelsdijk']
# ['F. Gulbrandsen', 'Fredrik Gulbrandsen']
# ['L. Bruins', 'Luigi Bruins']
# ['R. Oshima', 'å¤§å³¶ åƒšå¤ª']
# ['Ã\x81lvaro', 'Ã\x81lvaro VÃ¡zquez GarcÃ\xada']
# ['M. Al Buraik', 'Mohammed Al Buraik']
# ['Raphael Rossi', 'Raphael Rossi Branco']
# ['G. Litteri', 'Gianluca Litteri']
# ['M. RodrÃ\xadguez', 'MatÃ\xadas NicolÃ¡s RodrÃ\xadguez']
# ['C. GÃ¼lselam', 'Ceyhun GÃ¼lselam']
# ['M. Le Bihan', 'MickaÃ«l Le Bihan']
# ['R. BajiÄ‡', 'Rijad BajiÄ‡']
# ['F. Navarro', 'Fernando Navarro MorÃ¡n']
# ['B. DrÄ…gowski', 'BartÅ‚omiej DrÄ…gowski']
# ['D. Bentley', 'Daniel Bentley']
# ['Juninho', 'Vitor Gomes Pereira JÃºnior']
# ['Kadu', 'Ricardo Martins de AraÃºjo']
# ['Rafa Mir', 'Rafael Mir Vicente']
# ['M. Autret', 'Mathias Autret']
# ['A. Diomande', 'Adama Valentin Diomande']
# ['B. Jeannot', 'Benjamin Jeannot']
# ...
# ['B. Pavard', 'Benjamin Pavard']
# ['L. Tousart', 'Lucas Tousart']
# ['M. DmitroviÄ‡', 'Marko DmitroviÄ‡']
# ['Soares', 'Francisco das Chagas Soares dos Santos']
# ['L. Pellegrini', 'Lorenzo Pellegrini']
# ['F. Mendy', 'Ferland Mendy']
# ['A. Lunev', 'Andrey Lunev']
# ['Maikel Catarino', 'Maikel Renan Catarino Fagundes']
# ['AntÃ´nio Chiamuloira', 'A. Benjamin Chiamuloira Paes']
# ['Melvin Parrela', 'Melvin Luan Parrela PorfÃ\xadrio']
# ['Gabri PrestÃ£o', 'Bernard Gabriel PrestÃ£o Chaves']
# ['Luimo Boas Santos', 'Luan VÃ¡gner Boas Macedo']
# ['F. KessiÃ©', 'Franck Yannick KessiÃ©']
# ['T. Alexander-Arnold', 'Trent Alexander-Arnold']
# ['L. MartÃ\xadnez', 'Lautaro MartÃ\xadnez']
# ['J. Sancho', 'Jadon Sancho']
# ['Raphinha', 'Raphael Dias Belloli']
# ['Lucas PaquetÃ¡', 'Lucas Tolentino Coelho de Lima']
# ['F. Chiesa', 'Federico Chiesa']
# ['RÃºben Dias', 'RÃºben Alves Dias']
# ['Ã‰der MilitÃ£o', 'Ã‰der Gabriel MilitÃ£o']
# ['V. Tsygankov', 'Viktor Tsygankov']
# ['Loren', 'Lorenzo MorÃ³n GarcÃ\xada']
# ['S. Radu', 'Åžtefan Daniel Radu']
# ['M. Å\xa0krtel', 'Martin Å\xa0krtel']
# ['RaÃºl GarcÃ\xada', 'RaÃºl GarcÃ\xada Escudero']
# ['D. Valeri', 'Diego HernÃ¡n VÃ¡leri']
# ['D. Criscito', 'Domenico Criscito']
# ['A. Candreva', 'Antonio Candreva']
# ['S. Romero', 'Sergio GermÃ¡n Romero']
# ['Marcano', 'IvÃ¡n Marcano Sierra']
# ['Pedro LeÃ³n', 'Pedro LeÃ³n SÃ¡nchez Gil']
# ['V. Birsa', 'Valter Birsa']
# ['I. Piatti', 'Ignacio Piatti']
# ['K. Gameiro', 'KÃ©vin Gameiro']
# ['A. FernÃ¡ndez', 'Augusto MatÃ\xadas FernÃ¡ndez']
# ['M. Valbuena', 'Mathieu Valbuena']
# ['BeÃ±at', 'BeÃ±at Etxebarria Urkiaga']
# ['Nacho Monreal', 'Ignacio Monreal Eraso']
# ['Antunes', 'Vitorino Gabriel  Pacheco Antunes']
# ['Alexandre Pato', 'Alexandre Rodrigues da Silva']
# ['Sidnei', 'Sidnei Rechel da Silva JÃºnior']
# ['A. Modeste', 'Anthony Modeste']
# ['A. Rami', 'Adil Rami']
# ['D. Perotti', 'Diego Perotti']
# ['O. Toprak', 'Ã–mer Toprak']
# ['M. Musacchio', 'Mateo Pablo Musacchio']
# ['S. Ulreich', 'Sven Ulreich']
# ["Y. M'Vila", "Yann GÃ©rard M'Vila"]
# ['Camacho', 'Ignacio Camacho Barnola']
# ['N. Nkoulou', "Nicolas N'Koulou"]
# ['M. Lanzini', 'Manuel Lanzini']
# ['S. Kagawa', 'é¦™å·\x9d çœŸå\x8f¸']
# ['Guaita', 'Vicente Guaita Panadero']
# ['L. de Jong', 'Luuk de Jong']
# ['C. Smalling', 'Chris Smalling']
# ['Iago FalquÃ©', 'Iago FalquÃ© Silva']
# ['J. Zoet', 'Jeroen Zoet']
# ['D. Blind', 'Daley Blind']
# ['Maicon', 'Maicon Pereira Roque']
# ['R. Pereyra', 'Roberto Pereyra']
# ['R. RodrÃ\xadguez', 'Ricardo RodrÃ\xadguez']
# ['G. Pezzella', 'GermÃ¡n Alejandro Pezzella']
# ['D. Didavi', 'Daniel Didavi']
# ['AndrÃ© Almeida', 'AndrÃ© Gomes Magalhaes de Almeida']
# ['A. Yarmolenko', 'Andriy Yarmolenko']
# ['Sergi Enrich', 'Sergio Enrich Ametller']
# ['P. KadeÅ™Ã¡bek', 'Pavel KadeÅ™Ã¡bek']
# ['HÃ©ctor BellerÃ\xadn', 'HÃ©ctor BellerÃ\xadn Moruno']
# ['T. VaclÃ\xadk', 'TomÃ¡Å¡ VaclÃ\xadk']
# ['E. Zahavi', 'Eran Zahavi']
# ['IÃ±igo MartÃ\xadnez', 'Ã\x8dÃ±igo MartÃ\xadnez Berridi']
# ['M. Batshuayi', 'Michy Batshuayi Tunga']
# ['Portu', 'Cristian PortuguÃ©s Manzanera']
# ['T. Inui', 'ä¹¾ è²´å£«']
# ['Bernard', 'Bernard  AnÃ\xadcio Caldeira Duarte']
# ['B. Davies', 'Ben Davies']
# ['L. Shaw', 'Luke Shaw']
# ['T. Stepanenko', 'Taras Stepanenko']
# ['Manu Trigueros', 'Manuel Trigueros MuÃ±oz']
# ['L. Paredes', 'Leandro Paredes']
# ['C. Bacca', 'Carlos Arturo Bacca Ahumada']
# ['Y. Poulsen', 'Yussuf Yurary Poulsen']
# ['H. Ã‡alhanoÄŸlu', 'Hakan Ã‡alhanoÄŸlu']
# ['E. Can', 'Emre Can']
# ['N. AkÃ©', 'Nathan AkÃ©']
# ['Fred', 'Frederico R. de Paula Santos']
# ['Pacheco', 'Fernando Pacheco Flores']
# ['J. Quintero', 'Juan Fernando Quintero']
# ['E. Hysaj', 'Elseid Hysaj']
# ['M. Sanson', 'Morgan Sanson']
# ['N. Tagliafico', 'NicolÃ¡s Alejandro Tagliafico']
# ['AndrÃ© Gomes', 'AndrÃ© Filipe Tavares Gomes']
# ['GayÃ\xa0', 'JosÃ© LuÃ\xads GayÃ\xa0 PeÃ±a']
# ['Santi Mina', 'Santiago Mina Lorenzo']
# ['Rony Lopes', 'Marcos Paulo Mesquita Lopes']
# ['A. Christensen', 'Andreas Christensen']
# ['F. Armani', 'Franco Armani']
# ['G. Rulli', 'GerÃ³nimo Rulli']
# ['K. BaldÃ©', 'Keita BaldÃ©']
# ['Williams', 'IÃ±aki Williams Arthuer']
# ['J. Seri', 'Jean MichaÃ«l Seri']
# ['Rafa', 'Rafael Alexandre Fernandes Ferreira da Silva']
# ['M. Dahoud', 'Mahmoud Dahoud']
# ['M. Vecino', 'Matias Vecino']
# ['A. RebiÄ‡', 'Ante RebiÄ‡']
# ['M. Caldara', 'Mattia Caldara']
# ['RaÃºl', 'RaÃºl Michel Melo da Silva']
# ['Mariano', 'Mariano DÃ\xadaz MejÃ\xada']
# ['J. Weigl', 'Julian Weigl']
# ['M. AcuÃ±a', 'Marcos Javier AcuÃ±a']
# ['David Villa', 'David Villa SÃ¡nchez']
# ['J. Milner', 'James Philip Milner']
# ['Nani', 'LuÃ\xads Carlos Almeida da Cunha']
# ['JesÃºs Navas', 'JesÃºs Navas GonzÃ¡lez']
# ['Santi Cazorla', 'Santiago Cazorla GonzÃ¡lez']
# ['B. Gomis', 'BafÃ©timbi Gomis']
# ['L. FabiaÅ„ski', 'Å\x81ukasz FabiaÅ„ski']
# ['Renato Augusto', 'Renato  Soares de Oliveira Augusto']
# ['C. Vela', 'Carlos Alberto Vela Garrido']
# ['D. Rose', 'Danny Rose']
# ['E. Lamela', 'Erik Lamela']
# ['L. Piszczek', 'Å\x81ukasz Piszczek']
# ['K. Boateng', 'Kevin-Prince Boateng']
# ['S. Bender', 'Sven Bender']
# ['S. KjÃ¦r', 'Simon Thorup KjÃ¦r']
# ['B. HÃ¶wedes', 'Benedikt HÃ¶wedes']
# ['F. Muslera', 'Fernando Muslera']
# ['L. Fejsa', 'Ljubomir Fejsa']
# ['C. Stuani', 'Cristhian Ricardo Stuani Curbelo']
# ['L. Stindl', 'Lars Stindl']
# ['F. Smolov', 'Fyodor Smolov']
# ['S. Nzonzi', "Steven N'Kemboanza Mike Christopher Nzonzi"]
# ['K. Trapp', 'Kevin Trapp']
# ['Hulk', 'Givanildo Vieira de Souza']
# ['Muniain', 'Iker Muniain GoÃ±i']
# ['S. El Shaarawy', 'Stephan El Shaarawy']
# ['E. Salvio', 'Eduardo Antonio Salvio']
# ['J. Pastore', 'Javier MatÃ\xadas Pastore']
# ['Ander Herrera', 'Ander Herrera AgÃ¼era']
# ['M. GÃ¶tze', 'Mario GÃ¶tze']
# ['K. Vogt', 'Kevin Vogt']
# ['A. Areola', 'Alphonse Areola']
# ['J. Corona', 'JesÃºs Corona']
# ['D. Lovren', 'Dejan Lovren']
# ['S. Verdi', 'Simone Verdi']
# ['D. TadiÄ‡', 'DuÅ¡an TadiÄ‡']
# ['C. ArÃ¡nguiz', 'Charles Mariano ArÃ¡nguiz Sandoval']
# ['G. Xhaka', 'Granit Xhaka']
# ['Vitolo', 'VÃ\xadctor MachÃ\xadn PÃ©rez']
# ['L. Digne', 'Lucas Digne']
# ['N. Schulz', 'Nico Schulz']
# ['K. Volland', 'Kevin Volland']
# ['J. IliÄ\x8diÄ‡', 'Josip IliÄ\x8diÄ‡']
# ['F. Ghoulam', 'Faouzi Ghoulam']
# ['JoÃ£o MÃ¡rio', 'JoÃ£o MÃ¡rio Naval Costa Eduardo']
# ['A. Correa', 'Ã\x81ngel Correa']
# ['Dani GarcÃ\xada', 'Daniel GarcÃ\xada Carrillo']
# ['M. BrozoviÄ‡', 'Marcelo BrozoviÄ‡']
# ['Morales', 'JosÃ© Luis Morales Nogales']
# ['T. Bakayoko', 'TiÃ©mouÃ© Bakayoko']
# ['V. LindelÃ¶f', 'Victor Nilsson LindelÃ¶f']
# ['Dani Ceballos', 'Daniel Ceballos FernÃ¡ndez']
# ['RÃºben Neves', 'RÃºben Diogo da Silva Neves']
# ['E. Bailly', 'Eric Bailly']
# ['Pablo Fornals', 'Pablo Fornals Malla']
# ['Gelson Martins', 'Gelson Dany Batalha Martins']
# ['W. Ndidi', 'Onyinye Wilfred Ndidi']
# ['M. Marega', 'Moussa Marega']
# ['NÃ©lson Semedo', 'NÃ©lson Cabral Semedo']
# ['M. Akanji', 'Manuel Obafemi Akanji']
# ['L. Bailey', 'Leon Bailey Butler']
# ['Laure Santeiro', 'Laureano Thomas Santeiro Marre']
# ['M. AlmirÃ³n', 'Miguel AlmirÃ³n']
# ['L. JoviÄ‡', 'Luka JoviÄ‡']
# ['K. Havertz', 'Kai Havertz']
# ['Pepe Reina', 'JosÃ© Manuel  Reina PÃ¡ez']
# ['P. ÄŒech', 'Petr ÄŒech']
# ['Aduriz', 'Aritz Aduriz Zubeldia']
# ['Dani Alves', 'Daniel Alves da Silva']
# ['H. Herrera', 'HÃ©ctor Miguel Herrera LÃ³pez']
# ['L. Biglia', 'Lucas Rodrigo Biglia']
# ['F. Quagliarella', 'Fabio Quagliarella']
# ['M. DembÃ©lÃ©', 'Moussa Sidi Yaya DembÃ©lÃ©']
# ['JoÃ£o Moutinho', 'JoÃ£o Filipe Iria Santos Moutinho']
# ['Cesc FÃ\xa0bregas', 'Francesc FÃ\xa0bregas i Soler']
# ['A. Consigli', 'Andrea Consigli']
# ['S. Mandanda', 'Steve Mandanda']
# ['L. Koscielny', 'Laurent Koscielny']
# ['E. Viviano', 'Emiliano Viviano']
# ['Jardel', 'Jardel Nivaldo Vieira']
# ['E. Garay', 'Ezequiel Marcelo Garay']
# ['A. Guardado', 'JosÃ© AndrÃ©s Guardado HernÃ¡ndez']
# ['AdÃ¡n', 'Antonio AdÃ¡n Garrido']
# ['Juan Mata', 'Juan Manuel Mata GarcÃ\xada']
# ['O. Giroud', 'Olivier Giroud']
# ['R. FÃ¤hrmann', 'Ralf FÃ¤hrmann']
# ['F. Fazio', 'Federico JuliÃ¡n Fazio']
# ['V. Ä†orluka', 'Vedran Ä†orluka']
# ['Pedro', 'Pedro Eliezer RodrÃ\xadguez Ledesma']
# ['K. Strootman', 'Kevin Strootman']
# ['K. Glik', 'Kamil Glik']
# ['S. Mustafi', 'Shkodran Mustafi']
# ['D. SubaÅ¡iÄ‡', 'Danijel SubaÅ¡iÄ‡']
# ['H. Mkhitaryan', 'Henrikh Mkhitaryan']
# ['T. Delaney', 'Thomas Delaney']
# ['X. Shaqiri', 'Xherdan Shaqiri']
# ['MÃ¡rio Fernandes', 'MÃ¡rio Figueira Fernandes']
# ['Willian JosÃ©', 'Willian JosÃ© da Silva']
# ['S. Coates', 'SebastiÃ¡n Coates NiÃ³n']
# ['Bartra', 'Marc Bartra Aregall']
# ['Jonathan Viera', 'Jonathan Viera Ramos']
# ['Luis Alberto', 'Luis Alberto Romero Alconchel']
# ['W. Zaha', 'Wilfried Zaha']
# ['C. Bakambu', 'CÃ©dric Bakambu']
# ['W. Ben Yedder', 'Wissam Ben Yedder']
# ['J. Cillessen', 'Jasper Cillessen']
# ['Paco AlcÃ¡cer', 'Francisco AlcÃ¡cer GarcÃ\xada']
# ['B. Lecomte', 'Benjamin Lecomte']
# ['Morata', 'Ã\x81lvaro Borja Morata MartÃ\xadn']
# ['Gabriel Paulista', 'Gabriel Armando de Abreu']
# ['Rafinha', 'Rafael AlcÃ¢ntara do Nascimento']
# ['S. SanÃ©', 'Salif SanÃ©']
# ['T. Meunier', 'Thomas Meunier']
# ['K. Bellarabi', 'Karim Bellarabi']
# ['H. Maguire', 'Harry Maguire']
# ['A. Florenzi', 'Alessandro  Florenzi']
# ['A. Milik', 'Arkadiusz Milik']
# ['A. RÃ¼diger', 'Antonio RÃ¼diger']
# ['S. Haller', 'SÃ©bastien Haller']
# ['F. VÃ¡zquez', 'Franco VÃ¡zquez']
# ['J. Lingard', 'Jesse Lingard']
# ['J. MartÃ\xadnez', 'Josef Alexander MartÃ\xadnez']
# ['E. Forsberg', 'Emil Forsberg']
# ['A. Belotti', 'Andrea Belotti']
# ['J. Vardy', 'Jamie Vardy']
# ['T. Partey', 'Thomas Partey']
# ['Grimaldo', 'Alejandro Grimaldo GarcÃ\xada']
# ['P. ZieliÅ„ski', 'Piotr ZieliÅ„ski']
# ['D. Rugani', 'Daniele Rugani']
# ['K. Demirbay', 'Kerem Demirbay']
# ['T. Strakosha', 'Thomas Strakosha']
# ['F. Bernardeschi', 'Federico Bernardeschi']
# ['J. Pavlenka', 'JiÅ™Ã\xad Pavlenka']
# ['Casillas', 'Iker Casillas FernÃ¡ndez']
# ['D. De Rossi', 'Daniele De Rossi']
# ['R. Jarstein', 'Rune  Almenning Jarstein']
# ['A. Barzagli', 'Andrea Barzagli']
# ['F. RibÃ©ry', 'Franck Bilal RibÃ©ry']
# ['K. Schmeichel', 'Kasper Schmeichel']
# ['S. Sirigu', 'Salvatore Sirigu']
# ['Sokratis', 'Sokratis Papastathopoulos']
# ['Lucas Leiva', 'Lucas  Pezzini Leiva']
# ['Jonas', 'Jonas GonÃ§alves Oliveira']
# ['D. Payet', 'Dimitri  Payet']
# ['L. Bender', 'Lars Bender']
# ['Javi MartÃ\xadnez', 'Javier MartÃ\xadnez Aginaga']
# ['Rui PatrÃ\xadcio', 'Rui Pedro dos Santos PatrÃ\xadcio']
# ['Sergio Asenjo', 'Sergio  Asenjo AndrÃ©s']
# ['David Luiz', 'David Luiz Moreira Marinho']
# ['G. Wijnaldum', 'Georginio Wijnaldum']
# ['A. Kolarov', 'Aleksandar Kolarov']
# ['Oscar', 'Oscar dos Santos Emboaba JÃºnior']
# ['B. Dost', 'Bas Dost']
# ['Canales', 'Sergio Canales Madrazo']
# ['B. Leno', 'Bernd Leno']
# ['Marcos Alonso', 'Marcos Alonso Mendoza']
# ['K. Casteels', 'Koen Casteels']
# ['I. Gueye', 'Idrissa Gana Gueye']
# ['O. Baumann', 'Oliver Baumann']
# ['Neto', 'Norberto Murara Neto']
# ['K. Kampl', 'Kevin Kampl']
# ['Pizzi', 'LuÃ\xads Miguel Afonso Fernandes']
# ['Rodrigo', 'Rodrigo Moreno Machado']
# ['Pablo Sarabia', 'Pablo Sarabia GarcÃ\xada']
# ['Sergi Roberto', 'Sergio Roberto Carnicer']
# ['F. Acerbi', 'Francesco Acerbi']
# ['T. Horn', 'Timo Horn']
# ['Nacho FernÃ¡ndez', 'JosÃ© Ignacio FernÃ¡ndez Iglesias']
# ['Danilo Pereira', 'Danilo LuÃ\xads HÃ©lio Pereira']
# ['Lucas Moura', 'Lucas Rodrigues M. Silva']
# ['J. Draxler', 'Julian Draxler']
# ['Suso', 'JesÃºs JoaquÃ\xadn FernÃ¡ndez SÃ¡ez']
# ['T. Hazard', 'Thorgan Hazard']
# ['J. Stones', 'John Stones']
# ['S. SaviÄ‡', 'Stefan SaviÄ‡']
# ['J. Pickford', 'Jordan Pickford']
# ['A. Robertson', 'Andrew Robertson']
# ['A. KramariÄ‡', 'Andrej KramariÄ‡']
# ['C. Tolisso', 'Corentin Tolisso']
# ['L. HernÃ¡ndez', 'Lucas HernÃ¡ndez']
# ['N. KeÃ¯ta', 'Naby KeÃ¯ta']
# ['P. Kimpembe', 'Presnel Kimpembe']
# ['Louri Beretta', 'Lourival Adnan Beretta Barbosa']
# ['JosuÃ© Chiamulera', 'JosuÃ© Durval Chiamulera Vaz']
# ['Ronaldo Cabrais', 'Ronaldo Jailson Cabrais Petri']
# ['Gabriel Jesus', 'Gabriel Fernando de Jesus']
# ['G. Donnarumma', 'Gianluigi Donnarumma']
# ['M. Rashford', 'Marcus Rashford']
# ['M. de Ligt', 'Matthijs de Ligt']
# ['A. Robben', 'Arjen Robben']
# ['Quaresma', 'Ricardo Andrade Quaresma Bernardo']
# ['A. GÃ³mez', 'Alejandro DarÃ\xado GÃ³mez']
# ['RaÃºl Albiol', 'RaÃºl Albiol Tortajada']
# ['Falcao', 'Radamel Falcao GarcÃ\xada ZÃ¡rate']
# ['S. Ruffier', 'StÃ©phane Ruffier']
# ['Miranda', 'JoÃ£o Miranda de Souza Filho']
# ['Naldo', 'Ronaldo  Aparecido Rodrigues']
# ['Y. Sommer', 'Yann Sommer']
# ['E. Banega', 'Ã‰ver Maximiliano David Banega']
# ['Diego Costa', 'Diego da Silva Costa']
# ['S. Khedira', 'Sami Khedira']
# ['Willian', 'Willian Borges da Silva']
# ['A. SÃ¡nchez', 'Alexis Alejandro SÃ¡nchez SÃ¡nchez']
# ['JosÃ© CallejÃ³n', 'JosÃ© MarÃ\xada CallejÃ³n Bueno']
# ['I. GÃ¼ndoÄŸan', 'Ä°lkay GÃ¼ndoÄŸan']
# ['K. Walker', 'Kyle Walker']
# ['R. BÃ¼rki', 'Roman BÃ¼rki']
# ['Illarramendi', 'Asier Illarramendi Andonegi']
# ['L. HrÃ¡deckÃ½', 'LukÃ¡Å¡ HrÃ¡deckÃ½']
# ['N. MatiÄ‡', 'Nemanja MatiÄ‡']
# ['N. Otamendi', 'NicolÃ¡s HernÃ¡n Otamendi']
# ['Iago Aspas', 'Iago Aspas Juncal']
# ['J. Cuadrado', 'Juan Cuadrado']
# ['D. Alaba', 'David Olatukunbo Alaba']
# ['M. Perin', 'Mattia Perin']
# ['S. de Vrij', 'Stefan de Vrij']
# ['Allan', 'Allan Marques Loureiro']
# ['Felipe Anderson', 'Felipe  Anderson Pereira Gomes']
# ['M. Depay', 'Memphis Depay']
# ['F. Thauvin', 'Florian Thauvin']
# ['Pepe', 'KÃ©pler Laveran Lima Ferreira']
# ['V. Kompany', 'Vincent Kompany']
# ['Filipe LuÃ\xads', 'Filipe LuÃ\xads Kasmirski']
# ['B. Matuidi', 'Blaise Matuidi']
# ['M. Ã–zil', 'Mesut Ã–zil']
# ['A. Witsel', 'Axel  Witsel']
# ['R. Nainggolan', 'Radja Nainggolan']
# ['E. DÅ¾eko', 'Edin DÅ¾eko']
# ['I. PeriÅ¡iÄ‡', 'Ivan PeriÅ¡iÄ‡']
# ['M. MandÅ¾ukiÄ‡', 'Mario MandÅ¾ukiÄ‡']
# ['A. Vidal', 'Arturo Vidal']
# ['A. Di MarÃ\xada', 'Ã\x81ngel FabiÃ¡n Di MarÃ\xada HernÃ¡ndez']
# ['J. Boateng', 'JÃ©rÃ´me Boateng']
# ['Y. Brahimi', 'Yacine Brahimi']
# ['Paulinho', 'JosÃ© Paulo Bezzera Maciel JÃºnior']
# ['Parejo', 'Daniel Parejo MuÃ±oz']
# ['Douglas Costa', 'Douglas Costa de Souza']
# ['K. Manolas', 'Kostas Manolas']
# ['A. Lacazette', 'Alexandre Lacazette']
# ['Koke', 'Jorge ResurrecciÃ³n Merodio']
# ['A. Lopes', 'Anthony Lopes']
# ['H. Son', 'ì†\x90í\x9d¥ë¯¼ å\xad™å…´æ…œ']
# ['R. Mahrez', 'Riyad Mahrez']
# ['Carvajal', 'Daniel Carvajal Ramos']
# ['Marquinhos', 'Marcos  AoÃ¡s CorrÃªa']
# ['SaÃºl', 'SaÃºl Ã‘Ã\xadguez EsclÃ¡pez']
# ['D. Alli', 'Bamidele Alli']
# ['A. Laporte', 'Aymeric  Laporte']
# ['S. MilinkoviÄ‡-SaviÄ‡', 'Sergej MilinkoviÄ‡-SaviÄ‡']
# ['K. Benzema', 'Karim Benzema']
# ['M. PjaniÄ‡', 'Miralem PjaniÄ‡']
# ['L. Bonucci', 'Leonardo Bonucci']
# ['Azpilicueta', 'CÃ©sar Azpilicueta Tanco']
# ['W. SzczÄ™sny', 'Wojciech  SzczÄ™sny']
# ['T. MÃ¼ller', 'Thomas MÃ¼ller']
# ['Alex Sandro', 'Alex Sandro Lobo Silva']
# ['R. Lukaku', 'Romelu Lukaku']
# ['M. Verratti', 'Marco Verratti']
# ['R. Varane', 'RaphaÃ«l Varane']
# ['Roberto Firmino', 'Roberto Firmino Barbosa de Oliveira']
# ['S. ManÃ©', 'Sadio ManÃ©']
# ['Ederson', 'Ederson Santana de Moraes']
# ['J. Kimmich', 'Joshua Kimmich']
# ['Bernardo Silva', 'Bernardo Mota Veiga de Carvalho e Silva']
# ['L. SanÃ©', 'Leroy SanÃ©']
# ['R. Sterling', 'Raheem Sterling']
# ['S. Umtiti', 'Samuel Umtiti']
# ['Alisson', 'Alisson Ramses Becker']
# ['G. Buffon', 'Gianluigi Buffon']
# ['PiquÃ©', 'Gerard PiquÃ© BernabÃ©u']
# ['S. HandanoviÄ\x8d', 'Samir HandanoviÄ\x8d']
# ['Thiago Silva', 'Thiago Emiliano da Silva']
# ['H. Lloris', 'Hugo Lloris']
# ['G. Bale', 'Gareth Frank Bale']
# ['M. Hummels', 'Mats  Hummels']
# ['M. Reus', 'Marco Reus']
# ['P. Aubameyang', 'Pierre-Emerick Aubameyang']
# ['Coutinho', 'Philippe Coutinho Correia']
# ['N. KantÃ©', "N'Golo KantÃ©"]
# ['G. Chiellini', 'Giorgio Chiellini']
# ['Sergio Ramos', 'Sergio Ramos GarcÃ\xada']
# ['David Silva', 'David JosuÃ© JimÃ©nez Silva']
# ['D. GodÃ\xadn', 'Diego GodÃ\xadn']
# ['T. Kroos', 'Toni Kroos']
# ['R. Lewandowski', 'Robert Lewandowski']
# ['J. Oblak', 'Jan Oblak']
# ['H. Kane', 'Harry Kane']
# ['L. SuÃ¡rez', 'Luis Alberto SuÃ¡rez DÃ\xadaz']
# ['L. ModriÄ‡', 'Luka ModriÄ‡']
# ['E. Hazard', 'Eden Hazard']
# ['K. De Bruyne', 'Kevin De Bruyne']
# ['De Gea', 'David De Gea Quintana']
# ['Neymar Jr', 'Neymar da Silva Santos Junior']
# ['Cristiano Ronaldo', 'Cristiano Ronaldo dos Santos Aveiro']
# ['J. Serra', 'Janni-Luca Serra']
# ['A. Rodriguez', 'Angel Rodriguez']
# ['A. Calisir', 'AndrÃ© Calisir']
# ['R. Torres', 'RÃ³ger Mauricio Torres Hoya']
# ['R. McKenzie', 'Rory  McKenzie']
# ['M. SipÄ¾ak', 'Michal SipÄ¾ak']
# ['J. Bekkema', 'Jan Bekkema']
# ['A. Al Yami', 'Abdulrahman Al Yami']
# ['JÃºnior Brumado', 'JosÃ© Francisco dos Santos JÃºnior']

# %%
# Rules:
# 1) If it starts with an initial + ".", the surname follows
#
# Single word 
#  If single word is in "full name" first location, it's a first name
#     elif in 2nd+ location, it's a surname
#    else, is a nickname
# Careful!: ['H. Son', '손흥민 孙兴慜']

# %%
# Verify rules
for tp in lines:
    numname = len(tp.split(',')[0].split(' '))
    if numname<2:
        print(tp.split(',')[0:2])
# Out:
# ['\ufeffname', 'full_name']
# ['Fernandinho', 'Fernando Luiz Rosa']
# ['Marcelo', 'Marcelo Vieira da Silva JÃºnior']
# ['Thiago', 'Thiago AlcÃ¢ntara do Nascimento']
# ['Isco', 'Francisco RomÃ¡n AlarcÃ³n SuÃ¡rez']
# ['Casemiro', 'Carlos Henrique Venancio Casimiro']
# ['Kepa', 'Kepa Arrizabalaga']
# ['Fabinho', 'FÃ¡bio Henrique Tavares']
# ['Iniesta', 'AndrÃ©s Iniesta LujÃ¡n']
# ['Jorginho', 'Luiz Frello Filho Jorge']
# ['Felipe', 'Felipe Augusto de Almeida Monteiro']
# ['Malcom', 'Malcom Filipe Silva de Oliveira']
# ['FabiÃ¡n', 'FabiÃ¡n Ruiz PeÃ±a']
# ['Arthur', 'Arthur Henrique Ramos Oliveira Melo']
# ['Rodri', 'Rodrigo HernÃ¡ndez Cascante']
# ['Giuliano', 'Giuliano Victor de Paula']
# ['Marlos', 'Marlos Romero Bonfim']
# ['Taison', 'Taison Barcellos Freda']
# ['Oyarzabal', 'Mikel Oyarzabal Ugarte']
# ['Richarlison', 'Richarlison de Andrade']
# ['Odriozola', 'Ã\x81lvaro Odriozola Arzalluz']
# ['JoaquÃ\xadn', 'JoaquÃ\xadn SÃ¡nchez RodrÃ\xadguez']
# ['Ismaily', 'Ismaily GonÃ§alves dos S.']
# ['MoyÃ¡', 'Miguel Ã\x81ngel MoyÃ¡ Rumbo']
# ['Raffael', 'Raffael Caetano de AraÃºjo']
# ['Juanfran', 'Juan Francisco Torres BelÃ©n']
# ['Dante', 'Dante Bonfim da Costa Santos']
# ['OtÃ¡vio', 'OtÃ¡vio Edmilson da Silva Monteiro']
# ['Jonny', 'Jonathan Castro Otto']
# ['Elkeson', 'Elkeson de Oliveira Cardoso']
# ['Escudero', 'Sergio Escudero Palomo']
# ['HerrerÃ\xadn', 'Iago HerrerÃ\xadn BuisÃ¡n']
# ['Charles', 'Charles Dias De Oliveira']
# ['Capa', 'Ander Capa RodrÃ\xadguez']
# ['Fernando', 'Fernando Lucas Martins']
# ['Ã\x81lvaro', 'Ã\x81lvaro GonzÃ¡lez SoberÃ³n']
# ['Jurado', 'JosÃ© Manuel Jurado MarÃ\xadn']
# ['Hilton', 'Vitorino Hilton da Silva']
# ['Granero', 'Esteban FÃ©lix Granero Molina']
# ['Adriano', 'Adriano Correia Claro']
# ['Fabricio', 'Fabricio MartÃ\xadn Agosto RamÃ\xadrez']
# ['Wallace', 'Wallace Fortuna dos Santos']
# ['Djaniny', 'Jorge Djaniny  Tavares Semedo']
# ['Roberto', 'Roberto JimÃ©nez Gago']
# ['CÃ©dric', 'CÃ©dric Ricardo Alves Soares']
# ['Paulinho', 'JoÃ£o Paulo Dias Fernandes']
# ['BarragÃ¡n', 'Antonio BarragÃ¡n FernÃ¡ndez']
# ['Juanpe', 'Juan Pedro RamÃ\xadrez LÃ³pez']
# ['Balenziaga', 'Mikel Balenziaga Oruesagasti']
# ['Caiuby', 'Caiuby Francisco da Silva']
# ['Emerson', 'Emerson Palmieri dos Santos']
# ['RÃ´mulo', 'RÃ´mulo  Souza Orestes Caldeira']
# ['Kenedy', 'Robert Kenedy Nunes do Nascimento']
# ['Guilherme', 'Guilherme dos Santos Torres']
# ['Llorente', 'Fernando Javier Llorente Torres']
# ['CÃ³rdoba', 'IÃ±igo CÃ³rdoba Kerejeta']
# ['Recio', 'JosÃ© Luis GarcÃ\xada del Pozo']
# ['Fernandinho', 'Da ConceiÃ§Ã£o Fernando Henrique']
# ['Felipe', 'Felipe Dias da Silva dal Belo']
# ['MossorÃ³', 'JosÃ© MÃ¡rcio da Costa']
# ['Jozabed', 'Jozabed SÃ¡nchez Ruiz']
# ['Idris', 'Idrissa Mandiang']
# ['Jason', 'David Jason Remeseiro Salgueiro']
# ['Sandro', 'Sandro Ranieri GuimarÃ£es Cordeiro']
# ['Xeka', 'Miguel Ã‚ngelo da Silva Rocha']
# ['Marafona', 'JosÃ© Carlos CoentrÃ£o Marafona']
# ['Burgui', 'Jorge Franco Alviz']
# ['Walace', 'Walace Souza Silva']
# ['Eraso', 'Javier Eraso GoÃ±i']
# ['Paulinho', 'Paulo Henrique Soares dos Santos']
# ['AleÃ±Ã¡', 'Carles AleÃ±Ã¡ Castillo']
# ['Marlon', 'Marlon da Silva Barbosa']
# ['Jefferson', 'Jefferson Moreira Nascimento']
# ['ZaldÃºa', 'Joseba ZaldÃºa Bengoetxea']
# ['FontÃ\xa0s', 'Andreu FontÃ\xa0s Prat']
# ['Arribas', 'Alejandro Arribas Garrido']
# ['ReguilÃ³n', 'Sergio ReguilÃ³n RodrÃ\xadguez']
# ['Marcelo', 'Marcelo dos Santos Ferreira']
# ['Davidson', 'Davidson da Luz Pereira']
# ['Ivo', 'OlÃ\xadvio da Rosa']
# ['Ramalho', 'JonÃ¡s  Ramalho Chimeno']
# ['Luisinho', 'Luis Carlos Correia Pinto']
# ['William', 'William Alves de Oliveira']
# ['BebÃ©', 'Tiago Manuel Dias Correia']
# ['Adrianiscito', 'Adriano Leandro Soares Taffarel']
# ['DÃ³ria', 'Matheus DÃ³ria Macedo']
# ['Nacho', 'JosÃ© Ignacio MartÃ\xadnez GarcÃ\xada']
# ['Luna', 'Antonio Manuel Luna RodrÃ\xadguez']
# ['Djavan', 'Djavan da Silva Ferreira']
# ['Jota', 'JosÃ© Ignacio Peleteiro Ramallo']
# ['Etxeita', 'Xabier Etxeita Gorritxategi']
# ['Gerso', 'Gerso Fernandes']
# ['MÃ\xadchel', 'Miguel Alfonso Herrero Javaloyas']
# ['Insua', 'Pablo Insua Blanco']
# ['Paulinho', 'Paulo SÃ©rgio Mota']
# ['Castro', 'AndrÃ© de Castro Pereira']
# ['Fabiano', 'Fabiano Ribeiro de Freitas']
# ['Eduardo', 'Eduardo AntÃ´nio Machado Teixeira']
# ['Ricardo', 'Ricardo Jorge Vaz TÃ©']
# ['Paulinho', 'Paulo JosÃ© de Oliveira']
# ['Serginho', 'SÃ©rgio AntÃ´nio Soler Oliveira Jr']
# ['Edinho', 'Arnaldo Edi Lopes da Silva']
# ['Romarinho', 'RomÃ¡rio Ricardo da Silva']
# ['Mateus', 'Mateus Galiano da Costa']
# ['Alessinito', 'Alessandro Nuno Vaz Laranjeiras']
# ['Pulido', 'Jorge Pulido Mayoral']
# ['Dankler', 'Dankler LuÃ\xads de Jesus Pedreira']
# ['Douglas', 'Douglas Pereira dos Santos']
# ['Luismi', 'Luis Miguel SÃ¡nchez BenÃ\xadtez']
# ['Jubal', 'Jubal Rocha Mendes Junior']
# ['Reyes', 'JosÃ© Antonio Reyes CalderÃ³n']
# ['SebÃ¡', 'SebastiÃ£o de Freitas Couto JÃºnior']
# ['Souza', 'Elierce Barbosa de Souza']
# ['Carlitos', 'Carlos Alberto Alves Garcia']
# ['CarraÃ§a', 'Rui Filipe Caetano Moura']
# ['Bressan', 'Matheus Simoneti Bressaneli']
# ['Tiago', 'Tiago Alves Sales']
# ['TorrejÃ³n', 'Marc TorrejÃ³n Moya']
# ['Nascimentardo', 'Jonas Welson Orsi de Meneses']
# ['Canella', 'Roberto Canella SuÃ¡rez']
# ['Fernando', 'Fernando Dos Santos Pedro']
# ['Negueba', 'Guilherme Ferreira Pinto']
# ['Ã\x81lvaro', 'Ã\x81lvaro VÃ¡zquez GarcÃ\xada']
# ['Juninho', 'Vitor Gomes Pereira JÃºnior']
# ['Kadu', 'Ricardo Martins de AraÃºjo']
# ['Silvosinho', 'Thomas Nicolas Silva Rangel']
# ['Jonas', 'Jonas Gomes de Sousa']
# ['Defendi', 'Rodrigo Defendi']
# ['Dorca', 'Albert Dorca MasÃ³']
# ['Bremer', 'Gleison Bremer Silva Nascimento']
# ['Rodrigo', 'Rodrigo Alves Soares']
# ['Luso', 'Luis Eduardo Delgado Pacheco']
# ['Eguaras', 'IÃ±igo Eguaras Ã\x81lvarez']
# ['Braga', 'Bruno Manuel AraÃºjo Braga']
# ['OrtuÃ±o', 'Alfredo OrtuÃ±o MartÃ\xadnez']
# ['Bismark', 'Bismark de AraÃºjo Ferreira']
# ['William', 'William Fernando da Silva']
# ['NÃºrio', 'NÃºrio Domingos Matias Fortuna']
# ['CasadesÃºs', 'VÃ\xadctor Manuel CasadesÃºs CastaÃ±o']
# ['Ferro', 'Francisco Reis Ferreira']
# ['Bernardo', 'Bernardo VÃ\xadctor Cruz Torres']
# ['Puertas', 'Antonio JosÃ© RodrÃ\xadguez DÃ\xadaz']
# ['SÃ\xadlvio', 'SÃ\xadlvio Manuel Azevedo Ferreira SÃ¡ Pereira']
# ['NenÃª', 'Ã‚nderson Miguel da Silva']
# ['Toribio', 'Daniel Toribio GutiÃ©rrez']
# ['DodÃ´', 'Domilson Cordeiro dos Santos']
# ['Waguininho', 'Wagner da Silva Souza']
# ['Puado', 'Javier Puado DÃ\xadaz']
# ['Anuar', 'Anuar Mohamed Tuhami']
# ['Campillo', 'Antonio Campillo Medina']
# ['Ã“scar', 'Ã“scar RodrÃ\xadguez Arnaiz']
# ['Rodri', 'Rodrigo RÃ\xados Lozano']
# ['Jhonatan', 'Jhonatan Luiz da Siqueira']
# ['Fidel', 'Fidel Chaves de la Torre']
# ['Juanjo', 'Juan JosÃ© CiÃ©rcoles Sagra']
# ['Denilson', 'Denilson Pereira Junior']
# ['Alberto', 'Alberto JimÃ©nez BenÃ\xadtez']
# ['PÃªpÃª', 'Pedro Filipe Figueiredo Rodrigues']
# ['Ilori', 'Tiago Abiola Delfim Almeida Ilori']
# ['Sandaza', 'Francisco JosÃ© Sandaza Asensio']
# ['Alex', 'Alexandre Henrique GonÃ§alves De Freitas']
# ['Kanu', 'Rubenilson dos Santos da Rocha']
# ['Aguilera', 'Juan Aguilera Aguilera NÃºÃ±ez']
# ['Neris', 'Hueglo dos Santos Neris']
# ['HernÃ¡n', 'HernÃ¡n Daniel Santana Trujillo']
# ['CÃ©sar', 'CÃ©sar Henrique Martins']
# ['RatÃ³n', 'Ã\x81lvaro LÃ³pez RatÃ³n']
# ['Brahim', 'Brahim DÃ\xadaz']
# ['Avto', 'Avtandil Ebralidze']
# ['Gabrielzinho', 'Gabriel Airton de Souza']
# ['Aridai', 'Aridai Cabrera SuÃ¡rez']
# ['Macedo', 'Wanderson de Macedo Costa']
# ['Nando', 'Fernando GarcÃ\xada Puchades']
# ['Juanma', 'Juan Manuel Delgado Lloria']
# ['Chuli', 'Manuel JesÃºs VÃ¡zquez Florido']
# ['Baraka', 'AndrÃ©s Fernandes GonÃ§alves']
# ['Nadjack', 'Eliseu Mendja Nadjack Soares CassamÃ¡']
# ['Olmo', 'JesÃºs Olmo Lozano']
# ['Zequinha', 'JosÃ© Egas dos Santos Branco']
# ['AlemÃ£o', 'FÃ¡gner Ironi Daponte']
# ['Jair', 'Jair Eduardo Britto da Silva']
# ['Ricardinho', 'Ricardo Cavalcante Mendes']
# ['RomÃ¡rio', 'RomÃ¡rio Pereira SipiÃ£o']
# ['Basilio', 'Basilio Sancho Agudo']
# ['Juande', 'Juan de Dios Prados LÃ³pez']
# ['Nacho', 'Ignacio AgustÃ\xadn SÃ¡nchez Romo']
# ['Lucas', 'Lucas Alves de Araujo']
# ['Valverde', 'Carlos Valverde Doblado']
# ['Alfred', 'Alfred Planas MoyÃ\xa0']
# ['Renato', 'Renato Augusto Santos JÃºnior']
# ['Higinio', 'Higinio MarÃ\xadn Escavy']
# ['Trujillo', 'Ã\x81ngel Trujillo Canorea']
# ['Lucas', 'Lucas de Souza Cunha']
# ['AbdÃ³n', 'AbdÃ³n Prats Bastidas']
# ['Hugo', 'Hugo Claudio Vallejo AvilÃ©s']
# ['AvilÃ©s', 'Javier AvilÃ©s CortÃ©s']
# ['Willy', 'Luis Alfonso Ledesma GalÃ¡n']
# ['Allef', 'Allef de Andrade Rodrigues']
# ['Loureiro', 'Miguel Loureiro Ameijenda']
# ['Henrique', 'Henrique de Andrade Silva']
# ['Viti', 'VÃ\xadctor Ã\x81lvarez Rozada']
# ['DamiÃ\xa0', 'DamiÃ\xa0 Sabater Tous']
# ['JaquitÃ©', 'JoÃ£o Lamine JaquitÃ©']
# ['Mayoral', 'David Mayoral Lastras']
# ['Junio', 'Junio Ricardo da Rocha']
# ['Iury', 'Iury Lirio Freitas de Castilho']
# ['Brugui', 'Roger BruguÃ© Ayguade']
# ['PitÃ©', 'LuÃ\xads Pedro de Freitas Pinto Trabulo']
# ['Ã\x81lvaro', 'Ã\x81lvaro FernÃ¡ndez Llorente']
# ['Marcel', 'Marcel Alves Pereira']
# ['Henrique', 'Henrique Gelain CustÃ³dio']
# ['AndÃºjar', 'David AndÃºjar JimÃ©nez']
# ['KakÃ¡', 'Everton Ferreira GuimarÃ£es']
# ['Lolo', 'Emmanuel GonzÃ¡lez RodrÃ\xadguez']
# ['GenÃ\xads', 'GenÃ\xads Montolio Lafuente']
# ['Montero', 'Francisco Montero Rubio']
# ['Leonardo', 'Leonardo Navacchio']
# ['Bura', 'Jorge BraÃ\xadma CandÃ© Nogueira']
# ['JoaquÃ\xadn', 'JoaquÃ\xadn MuÃ±oz Benavides']
# ['Ã\x81ngel', 'Ã\x81ngel Moreno Morcillo']
# ['Endika', 'Endika Irigoien Bravo']
# ['Carlitos', 'Juan Carlos Moreno Rojo']
# ['Ã\x81ngel', 'Ã\x81ngel GarcÃ\xada Cabezali']
# ['Sito', 'AndrÃ©s Pascual Santonja']
# ['Montoro', 'AdriÃ¡n HernÃ¡ndez Montoro']
# ['Jimmy', 'Jaime SuÃ¡rez Juesas']
# ['Kike', 'Enrique GÃ³mez Hermoso']
# ['AntÃ³n', 'AntÃ³n Escobar Tapiias']
# ['Prendes', 'Alejandro Prendes Reina']
# ['Meseguer', 'Luis Meseguer Villanueva']
# ['Parra', 'Carlos Parra Arauzo']
# ['Leja', 'Alberto LejÃ¡rraga Rubio']
# ['Oleaga', 'Hodei Oleaga Alarcia']
# ['Algobia', 'Ã\x81ngel Algobia Esteves']
# ['Altube', 'Diego Altube SuÃ¡rez']
# ['Mollejo', 'VÃ\xadctor Mollejo Carpintero']
# ['Tellado', 'AdriÃ¡n Tellado']
# ['Maikel', 'Antonio Nieves MartÃ\xadn']
# ['Morro', 'Miguel Ã\x81ngel Morro MuÃ±oz']
# ['Ruan', 'Ruan GregÃ³rio Teixeira']
# ['Strefezza', 'Gabriel Tadeu Strefezza Rebecato']
# ['Taliby', 'Taliby Konate DiakitÃ©']
# ['Philippe', 'Philippe Almeida Costa']
# ['Patrick', 'Patrick Ferreira Souza']
# ['Pedrosa', 'Daniel Pedrosa Loureiro']
# ['Javito', 'Javier Almerge ViÃ±uales']
# ['Aparicio', 'Javier Aparicio GÃ³mez']
# ['Lucas', 'Lucas Ribeiro Fonseca']
# ['Grifi', 'David Grifell Monreal']
# ['Reyes', 'David Reyes Segura']
# ['Irizo', 'JosÃ© Manuel Irizo FernÃ¡ndez']
# ['Fabio', 'Fabio De Sousa Silva']
# ['Montes', 'Ãˆric Montes Arce']
# ['RamÃ³n', 'RamÃ³n RodrÃ\xadguez da Silva']
# ['Garijo', 'Jaime Garijo']
# ['Baselga', 'Marcos Baselga GarcÃ\xada']
# ['AdriÃ¡n', 'AdriÃ¡n Real Canales']
# ['Altamirano', 'Diego Altamirano']
# ['Lombo', 'Pablo Lombo SuÃ¡rez']
# ['Salcedo', 'JosÃ© Antonio Salcedo SÃ¡nchez']
# ['Genaro', 'Genaro  RodrÃ\xadguez Serrano']
# ['IbaÃ±ez', 'Roger IbaÃ±ez Da Silva']
# ['Leandro', 'Leandro Montagud Balaguer']
# ['Dome', 'DomÃ¨nec Estorach Ruedas']
# ['IvÃ¡n', 'IvÃ¡n Navarro Mateos']
# ['Kiki', 'Juan Antonio DÃ\xadaz Sanchez']
# ['Campos', 'Gaizka Campos BahÃ\xadllo']
# ['GuillamÃ³n', 'Hugo GuillamÃ³n SammartÃ\xadn']
# ['Cordero', 'Arturo Cordero LÃ³pez']
# ['Ã\x81lex', 'Ã\x81lex PachÃ³n PÃ¡rraga']
# ['AarÃ³n', 'AarÃ³n Escandell']
# ['Kike', 'Enrique PÃ©rez MuÃ±oz']
# ['Edgar', 'Edgar GonzÃ¡lez Estrada']
# ['Moncayola', 'Jon Moncayola Tollar']
# ['MartÃ\xadn', 'MartÃ\xadn Pascual Castillo']
# ['Bueno', 'Wellington Daniel Bueno']
# ['Viti', 'VÃ\xadctor MartÃ\xadnez Manrique']
# ['Samuel', 'Samuel Arbelo HernÃ¡ndez']
# ['Rayco', 'Rayco RodrÃ\xadguez Medina']
# ['Romero', 'Ã\x81lvaro Romero Morillo']
# ['Perera', 'Antonio Perera CalderÃ³n']
# ['Modest', 'Modest Notario Racionero']
# ['Tachi', 'Alberto RodrÃ\xadguez BarÃ³']
# ['Fachendinho', 'Tiago Vanderlei Fagundes Fachini']
# ['Rafinha', 'Rafael Gimenes da Silva']
# ['Abenza', 'Mario NicolÃ¡s Abenza']
# ['Vinicius', 'Caio Vinicius Pirana']
# ['HernÃ¡iz', 'Ã\x81lvaro HernÃ¡iz Perera']
# ['PepÃª', 'JoÃ£o Pedro Vilardi Pinto']
# ['OtaÃ±o', 'Ignacio OtaÃ±o Aranburu']
# ['Thallyson', 'Thallyson Augusto Tavares Dias']
# ['BolaÃ±os', 'Roberto JesÃºs MeliÃ¡n BolaÃ±os']
# ['Chema', 'JosÃ© Manuel NÃºÃ±ez MartÃ\xadn']
# ['JosÃ\xadn', 'Jose Antonio Martinez Ã\x81lvarez']
# ['Robinho', 'Robinho Barbosa de Lisboa']
# ['Wanderson', 'Wanderson Carvalho Oliveira']
# ['Isi', 'Isaac GÃ³mez SÃ¡nchez']
# ['VallÃ¨s', 'Enric VallÃ¨s Prat']
# ['Guerrero', 'Fernando Delgado Guerrero']
# ['UxÃ\xado', 'UxÃ\xado Da Pena GutiÃ©rrez']
# ['QuintillÃ¡', 'Xavier QuintillÃ¡ Guasch']
# ['Clemente', 'Enrique Clemente Maza']
# ['PC', 'Victor Pagliari Giro']
# ['Jauregi', 'Eneko Jauregi Escobar']
# ['Tuta', 'Lucas Silva Melo']
# ['Pistu', 'IvÃ¡n Jorge Vegas']
# ['Miravent', 'Albert Miravent Sans']
# ['Fornos', 'Enrique Fornos DomÃ\xadnguez']
# ['Oribe', 'Jordi Oribe Manzano']
# ['Jaime', 'Jaime SÃ¡nchez MuÃ±oz']
# ['Guerrero', 'AdriÃ\xa0 Guerrero Aguilar']
# ['Arribas', 'Ã“scar Arribas Pasero']
# ['Borja', 'Borja MartÃ\xadnez Giner']
# ['Josemi', 'JosÃ© Miguel CastaÃ±eda Macho']
# ['Neto', 'Alvino Volpi Neto']
# ['Rulo', 'RaÃºl Prieto Odena']
# ['Kikas', 'JoÃ£o Diogo Alves Rodrigues']
# ['Miguel', 'Miguel De la Fuente Escudero']
# ['Diga', 'Diogo Miguel Guedes Almeida']
# ['Vitinho', 'Victor da Silva']
# ['Luan', 'Luan Leite da Silva']
# ['Jeka', 'Yevhenii Serdiuk']
# ['Echu', 'JesÃºs RodrÃ\xadguez OrtuÃ±o']
# ['Stoichkov', 'Juan Diego Molina MartÃ\xadnez']
# ['Pablo', 'Pablo Rey FernÃ¡ndez']
# ['Pascu', 'JosÃ© Pascual Alba Seva']
# ['Jaume', 'Jaume Grau Ciscar']
# ['Robert', 'Roberto GonzÃ¡lez BayÃ³n']
# ['Jesiel', 'Jesiel Cardoso Miranda']
# ['Maguinho', 'Magno JosÃ© da Silva']
# ['Wanderson', 'Wanderson Santos Pereira']
# ['Valery', 'Valery FernÃ¡ndez Estrada']
# ['Mika', 'Micael Filipe Correia Borges']
# ['Romera', 'JosÃ© Antonio Romera Navarro']
# ['Kiki', 'Christian Neiva Afonso']
# ['Cidinho', 'Alcides  de Souza Faria Junior']
# ['Vagner', 'Vagner JosÃ© Dias Goncalves']
# ['Peixotacinho', 'Allison Alan Peixoto Gomes']
# ['Benito', 'Benito RamÃ\xadrez del Toro']
# ['CaÃ\xadque', 'CaÃ\xadque VenÃ¢ncio Lemes']
# ['Felipe', 'Felipe Alfonso Criado']
# ['Fernando', 'Fernando MartÃ\xadnez Rubio']
# ['Marcelo', 'Marcelo Machado dos Santos']
# ['MuÃ±oz', 'Aihen MuÃ±oz CapellÃ¡n']
# ['Berrocal', 'Juan Berrocal GonzÃ¡lez']
# ['Luquinhas', 'Lucas Lima Linhares']
# ['Marquitos', 'Marcos GarcÃ\xada Barreno']
# ['Noblejas', 'Javier GarcÃ\xada-Noblejas']
# ['Igor', 'Igor Julio dos Santos de Paulo']
# ['Aitor', 'Aitor FernÃ¡ndez LÃ³pez']
# ['Aguado', 'Ã\x81lvaro Aguado MÃ©ndez']
# ['Chumi', 'Juan BrandÃ¡riz Movilla']
# ['Ronan', 'Ronan David Jeronimo']
# ['LelÃªu', 'Claudionor Souza de Jesus']
# ['AloÃ\xadsio', 'AloÃ\xadsio Soares Neto']
# ['Yago', 'Yago CÃ©sar da Silva']
# ['Mateus', 'Mateus dos Santos Castro']
# ['Fidalgo', 'Ã\x81lvaro Fidalgo FernÃ¡ndez']
# ['Patrick', 'FÃ¡bio Patrick Santos Fernandes']
# ['Nanu', 'EulÃ¢nio Ã‚ngelo Chipela Gomes']
# ['MarcÃ£o', 'Marcos Wilson da Silva']
# ['Airam', 'Airam LÃ³pez Cabrera']
# ['Guilherme', 'Guilherme Schettine GuimarÃ£es']
# ['Salva', 'Salvador Ferrer Canals']
# ['Danilo', 'Danilo Pereira Da Silva']
# ['Pastrana', 'VÃ\xadctor Pastrana Carrasco']
# ['VÃ\xadctor', 'VÃ\xadctor GarcÃ\xada Raja']
# ['Nathan', 'Nathan Raphael Pelae Cardoso']
# ['Manu', 'JosÃ© Manuel RodrÃ\xadguez Morgade']
# ['Isidoro', 'JosÃ© Isidoro GÃ³mez Torres']
# ['Leandro', 'Weverson Leandro Oliveira Moura']
# ['Judson', 'Judson Silva Tavares']
# ['HÃ©ctor', 'HÃ©ctor HernÃ¡ndez Marrero']
# ['Pardo', 'JosÃ© Antonio Pardo Lucas']
# ['Pipa', 'Gonzalo Ã\x81vila GordÃ³n']
# ['Olabe', 'Roberto Olabe Del Arco']
# ['Varela', 'Francisco Miguel Varela MartÃ\xadn']
# ['Erik', 'Erik Roberto Silva do Nascimento']
# ['Gabriel', 'Gabriel dos Santos MagalhÃ£es']
# ['Pepelu', 'Jose LuÃ\xads GarcÃ\xada VayÃ¡']
# ['Pablo', 'Pablo Diogo Lopes de Lima']
# ['Jano', 'Alejandro Velasco FariÃ±as']
# ['FÃ¡binho', 'Fabio  Alves Macedo']
# ['Euller', 'Elosman Euller Silva Cavalcanti']
# ['Augusto', 'Augusto Pereira Loureiro']
# ['Chuca', 'VÃ\xadctor Moya MartÃ\xadnez']
# ['Klauss', 'JoÃ£o Klauss de Mello']
# ['Joca', 'Jorge Samuel  Figueiredo Fernandes']
# ['Botelhinonsa', 'JoÃ£o Rodolfo Botelho Maia']
# ['Morillas', 'David Morillas JimÃ©nez']
# ['MartÃ\xadnez', 'JosÃ© Antonio MartÃ\xadnez Gil']
# ['Escriche', 'Daniel Escriche Romero']
# ['Miranda', 'Juan Miranda GonzÃ¡lez']
# ['Gaspar', 'Gaspar Panadero Zamora']
# ['Lazo', 'JosÃ© Carlos Lazo Romero']
# ['Ilsinho', 'Ilson Pereira Dias JÃºnior']
# ['Cleylton', 'Jose Cleylton de Morais dos Santos']
# ['Jhonnattann', 'Jhonnattann Benites da ConceiÃ§ao']
# ['Rufo', 'Ruben HerrÃ¡iz Alcaraz']
# ['Corpas', 'JosÃ© Corpas Serna']
# ['Bicho', 'Javier FernÃ¡ndez AbruÃ±edo']
# ['Olavide', 'Miguel Olavide Montes']
# ['Crysan', 'Crysan C. Queiroz Barcelos']
# ['Sancet', 'Oihan Sancet Tirapu']
# ['Derik', 'Derik Osede Prieto']
# ['AdaÃ\xadlton', 'AdaÃ\xadlton dos Santos da Silva']
# ['Abraham', 'Abraham  Minero FernÃ¡ndez']
# ['JaÃ\xadlson', 'JaÃ\xadlson Marques Siqueira']
# ['Quintanilla', 'Ã\x81lex Quintanilla Urionabarrenetxea']
# ['Nano', 'Mariano GonzÃ¡lez Maroto']
# ['Guarrotxena', 'Iker Guarrotxena Vallejo']
# ['Accioly', 'Danildo Jose Sao Pedro Accioly Filho']
# ['EstevÃ£tinho', 'EstevÃ£o Danilo Rios Chiamulera']
# ['Charles', 'Charles Fernando Basilio da Silva']
# ['Tekio', 'Sergio BlÃ¡zquez SÃ¡nchez']
# ['Camacho', 'Juan JosÃ© Camacho Barnola']
# ['Zubiaurre', 'Andoni Zubiaurre Dorronsoro']
# ['Castro', 'Carlos Castro GarcÃ\xada']
# ['Serginho', 'SÃ©rgio Gabriel da Silva Andrade']
# ['Freire', 'Leandro Freire de AraÃºjo']
# ['FÃ¡bio', 'FÃ¡bio Szymonek']
# ['FabrÃ\xadcio', 'FabrÃ\xadcio Silva Dornellas']
# ['TochÃ©', 'JosÃ© VerdÃº NicolÃ¡s']
# ['Getterson', 'Getterson Alves dos Santos']
# ['Samu', 'FÃ¡bio Samuel Amorim Silva']
# ['Akieme', 'Sergio Akieme RodrÃ\xadguez']
# ['Assis', 'Assis Giovanaz']
# ['Tyronne', 'Tyronne Gustavo Del Pino Ramos']
# ['Douglas', 'Douglas da Silva Vieira']
# ['Clemente', 'Paulo Clemente Ventura Raimundo']
# ['Josan', 'JosÃ© Antonio FerrÃ¡ndez Pomares']
# ['Bastos', 'Ã\x81ngel Bastos Teijeira']
# ['Yago', 'Yago Henrique Severino dos Santos']
# ['Caro', 'JosÃ© Antonio Caro DÃ\xadaz']
# ['Josema', 'JosÃ© Manuel SÃ¡nchez GuillÃ©n']
# ['Guruzeta', 'Gorka Guruzeta RodrÃ\xadguez']
# ['Wellington', 'Wellington LuÃ\xads de Sousa']
# ['Cristiano', 'Cristiano Pereira Figueiredo']
# ['Carbonell', 'Alejandro Carbonell VallÃ©s']
# ['Hicham', 'Hicham Boussefiane']
# ['Toquero', 'Gaizka Toquero Pinedo']
# ['Edgar', 'Edgar Bruno da Silva']
# ['Pedrosa', 'AndrÃ© Alexandre Antunes Pedrosa']
# ['EtxeberrÃ\xada', 'Markel EtxeberrÃ\xada Mendiola']
# ['Ã\x81lvaro', 'Ã\x81lvaro GimÃ©nez Candela']
# ['HÃ©ctor', 'HÃ©ctor HernÃ¡ndez Ortega']
# ['Cesinha', 'Cesar Fernando Silva Melo']
# ['JoaquÃ\xadn', 'JoaquÃ\xadn FernÃ¡ndez Moreno']
# ['Mandi', 'Armando Sosa PeÃ±a']
# ['Ã\x8dcaro', 'Ã\x8dcaro do Carmo Silva']
# ['VinÃ\xadcius', 'Paulo VinÃ\xadcius Souza dos Santos']
# ['Campabadal', 'Eduard Campabadal Claros']
# ['Matos', 'JosÃ© JoaquÃ\xadn Matos GarcÃ\xada']
# ['Dalmau', 'AdriÃ\xa0n Dalmau Vaquer']
# ['DelmÃ¡s', 'JuliÃ¡n Javier DelmÃ¡s GermÃ¡n']
# ['FernÃ¡ndez', 'JosÃ© Manuel FernÃ¡ndez Reyes']
# ['Nouhou', 'Nouhou Tolo']
# ['BellvÃ\xads', 'Carlos BellvÃ\xads Llorens']
# ['Gorosabel', 'Andoni Gorosabel Espinosa']
# ['Caro', 'JosÃ© Antonio Caro MartÃ\xadnez']
# ['Querol', 'David Querol Blanco']
# ['Messias', 'Messias Rodrigues Silva Jr.']
# ['Pacheco', 'Pedro Miguel  Salgadinho Pacheco de Melo']
# ['Rafinha', 'Rafael Scapini de Almeida']
# ['BernabÃ©', 'BernabÃ© BarragÃ¡n Maestre']
# ['Elgezabal', 'Unai Elgezabal Udondo']
# ['Lillo', 'Manuel  Castellano Castro']
# ['Pleguezuelo', 'Julio JosÃ© Pleguezuelo Selva']
# ['Kevin', 'Kevin VÃ¡zquez ComesaÃ±a']
# ['Carrillo', 'JosÃ© Ã\x81ngel Carrillo Casamayor']
# ['GalÃ¡n', 'Ernesto GalÃ¡n IÃ±igo']
# ['Alcatraz', 'Gilberto GarcÃ\xada Olarte']
# ['Jairo', 'Jairo Izquierdo GonzÃ¡lez']
# ['PejiÃ±o', 'Francisco JesÃºs Crespo GarcÃ\xada']
# ['DÃ¡lcio', 'EuciodÃ¡lcio Gomes']
# ['Soriano', 'Juan Soriano Oropesa']
# ['Carlinhos', 'Carlos Antonio de Souza JÃºnior']
# ['Casto', 'Casto Espinosa Barriga']
# ['Merquelanz', 'MartÃ\xadn Merquelanz']
# ['Quini', 'JoaquÃ\xadn MarÃ\xadn Ruiz']
# ['Jadson', 'Jadson Silva de Morais']
# ['Evander', 'Evander da Silva Ferreira']
# ['Catena', 'Alejandro Catena MarugÃ¡n']
# ['Muralha', 'Luiz Philipe Lima de Oliveira']
# ['Jael', 'Jael Ferreira Vieira']
# ['Rochinha', 'Diogo Filipe Rocha Costa']
# ['Undabarrena', 'Iker Undabarrena MartÃ\xadnez']
# ['TomanÃ©', 'AntÃ³nio Manuel Fernandes Mendes']
# ['CotÃ¡n', 'Antonio JesÃºs CotÃ¡n PÃ©rez']
# ['Verdasca', 'Diogo Sousa Verdasca']
# ['Raillo', 'Antonio JosÃ© Raillo Arenas']
# ['Aguza', 'Sergio Aguza Santiago']
# ['Nicolas', 'David Nicolas Andrade']
# ['Niltinho', 'Nilton Soares Rodrigues']
# ['Emerson', 'Emerson Leite De Souza']
# ['Auro', 'Auro Alvaro da Cruz Junior']
# ['Buatu', 'Jonathan Buatu Mananga']
# ['Momo', 'JerÃ³nimo Figueroa Cabrera']
# ['Servando', 'Servando SÃ¡nchez Barahona']
# ['Cris', 'Bruno Cristiano Carvalho Santos']
# ['Pomares', 'Carlos Pomares Rayo']
# ['Verza', 'JosÃ© Antonio GarcÃ\xada Rabasco']
# ['Wellington', 'Wellington Nascimento Carvalho']
# ['Mika', 'Michael SimÃµes Domingues']
# ['Baena', 'JosÃ© RaÃºl Baena Urdiales']
# ['Farley', 'Farley Vieira Rosa']
# ['Palanca', 'Miguel Palanca FernÃ¡ndez']
# ['Josete', 'JosÃ© Antonio MalagÃ³n Rubio']
# ['Ripa', 'AdriÃ¡n Ripa Cruz']
# ['MiguelÃ³n', 'Miguel Juan Llambrich']
# ['Leandrinho', 'Leandro de Lima Silva']
# ['SantamarÃ\xada', 'Roberto SantamarÃ\xada CipriÃ¡n']
# ['Alfaro', 'Alejandro Alfaro Ligero']
# ['Carvamelinho', 'Samuel Thomas Carvalho Melo']
# ['Linares', 'Miguel Linares CÃ³lera']
# ['Enzo', 'Enzo Alan Zidane FernÃ¡ndez']
# ['GÃ©gÃ©', 'Admilson E. Dias de Barros']
# ['Iago', 'Iago Azevedo dos Santos']
# ['Cifu', 'Miguel Ã\x81ngel Garrido Cifuentes']
# ['Reinildo', 'Reinildo Isnard Mandava']
# ['Nano', 'Alexander Mesa Travieso']
# ['Pinillos', 'Daniel Pinillos GonzÃ¡lez']
# ['Magno', 'Magno Damasceno Santos da Cruz']
# ['Villalibre', 'Asier Villalibre Molina']
# ['Zapater', 'Alberto Zapater Arjol']
# ['Crivellaro', 'Rafael Schuler Crivellaro']
# ['Minhoca', 'NÃ©lson Alexandre Farpelha Estrela']
# ['Fali', 'Rafael JimÃ©nez Jarque']
# ['Matheus', 'Matheus Borges Domingues']
# ['FlÃ¡vio', 'FlÃ¡vio da Silva Ramos']
# ['Luisinho', 'Luis Gustavo Melere da Silva']
# ['LicÃ¡', 'Luis Carlos Pereira Carneiro']
# ['RogÃ©rio', 'RogÃ©rio Oliveira da Silva']
# ['Ademilson', 'Ademilson Braga Bispo JÃºnior']
# ['Kalindi', 'Kalindi Alves de Souza']
# ['Platiny', 'Higor InÃ¡cio Platiny de Oliveira Rodrigues']
# ['JoÃ£ozinho', 'JoÃ£o Carlos Reis GraÃ§a']
# ['Aketxe', 'Ager Aketxe Barrutia']
# ['Johannesson', 'Diego Johannesson Pando']
# ['Witi', 'Witiness Chimoio Joao Quembo']
# ['Alef', 'Alef dos Santos Saldanha']
# ['BÃ³veda', 'Eneko BÃ³veda Altube']
# ['Derley', 'Vanderley Dias Marinho']
# ['Xisco', 'Francisco JimÃ©nez Tejada']
# ['Lasure', 'Daniel Lasure Briz']
# ['Nino', 'Juan Francisco MartÃ\xadnez Modesto']
# ['Iriome', 'Iriome GonzÃ¡lez GonzÃ¡lez']
# ['GermÃ¡n', 'GermÃ¡n SÃ¡nchez Barahona']
# ['Nolaskoain', 'Peru Nolaskoain Esnal']
# ['SaÃºl', 'SaÃºl GarcÃ\xada Cabrero']
# ['Lionn', 'JosÃ© Lionn Barbosa de Lucena']
# ['RubÃ©n', 'RubÃ©n IvÃ¡n MartÃ\xadnez Andrade']
# ['Nono', 'David GonzÃ¡lez Plata']
# ['Aridane', 'Aridane HernÃ¡ndez UmpiÃ©rrez']
# ['Akapo', 'Carlos Akapo MartÃ\xadnez']
# ['Ewandro', 'Ewandro Felipe de Lima Costa']
# ['LombÃ¡n', 'David RodrÃ\xadguez LombÃ¡n']
# ['Barbosaldinho', 'Luciano Renato Barbosa Baumer']
# ['Felipe', 'Felipe Aliste Lopes']
# ['ArsÃ©nio', 'ArsÃ©nio Martins Lafuente Nunes']
# ['Patrick', 'Patrick De Oliveira Vieira']
# ['Deivid', 'David Omar RodrÃ\xadguez Barrera']
# ['Pombaxinho', 'Arturo Jonaldo Pombal de Faria']
# ['Mano', 'LuÃ\xads Miguel Lopes Mendes']
# ['Arroyo', 'Ã\x81lvaro Arroyo MartÃ\xadnez']
# ['Tito', 'Roberto RomÃ¡n Triguero']
# ['Adriano', 'Carlos Adriano de Souza Cruz']
# ['Tramontinaldo', 'MÃ¡rcio Anderson Tramontino SÃ¡']
# ['Ukra', 'AndrÃ© Filipe Alves Monteiro']
# ['Adryan', 'Adryan Oliveira Tavares']
# ['Nauzet', 'Cecilio Nauzet PÃ©rez GonzÃ¡lez']
# ['BotÃ\xada', 'Alberto TomÃ¡s BotÃ\xada Rabasco']
# ['Dorado', 'JosÃ© Antonio Dorado RamÃ\xadrez']
# ['Evandro', 'Evandro Goebel']
# ['Fredy', 'Alfredo Kulembe Ribeiro']
# ['Bueno', 'Alberto  Bueno Calvo']
# ['Fede', 'Federico San Emeterio DÃ\xadaz']
# ['Gumbau', 'Gerard Gumbau Garriga']
# ['AntoÃ±ito', 'Antonio JesÃºs Regal Angulo']
# ['Jota', 'JoÃ£o Tiago SerrÃ£o GarcÃªs']
# ['VinÃ\xadcius', 'Carlos VinÃ\xadcius Alves Morais']
# ['Artur', 'JosÃ© Artur de Lima Junior']
# ['Varela', 'Silvestre Manuel GonÃ§alves Varela']
# ['Pita', 'Carlos Pita GonzÃ¡lez']
# ['Escassi', 'Alberto Escassi Oliva']
# ['Elsinho', 'Elson Ferreira de Souza']
# ['Garrido', 'Jon Ander Garrido Moracia']
# ['Guillermo', 'Guillermo FernÃ¡ndez Hierro']
# ['Paulinho', 'Paulo Henrique Sampaio Filho']
# ['Welinton', 'Welinton Souza Silva']
# ['Mossa', 'JosÃ© MarÃ\xada Angresola JimÃ©nez']
# ['Paulolettinho', 'Paulo Bernard Alves Coelho']
# ['Shikabala', 'Mahmoud Abdel Razek Fadlallah']
# ['Felipe', 'Felipe Trevizan Martins']
# ['Jota', 'JoÃ£o Pedro Neves Filipe']
# ['Ewerton', 'Ewerton da Silva Pereira']
# ['Cyriac', 'Cyriac Gohi Bi Zoro']
# ['Osmar', 'Osmar IbÃ¡Ã±ez Barba']
# ['Susaeta', 'NÃ©stor Susaeta Jaurrieta']
# ['SomÃ¡lia', 'Calmon Wergiton do RosÃ¡rio']
# ['Rodolfo', 'Rodolfo Almeida GuimarÃ£es']
# ['Babanco', 'Elvis Manuel Monteiro Macedo']
# ['Eugeni', 'Eugeni Valderrama DomÃ¨nech']
# ['Lyanco', 'Lyanco Neves Vojnovic']
# ['Naranjo', 'JosÃ© Manuel GarcÃ\xada Naranjo']
# ['Serginho', 'SÃ©rgio AntÃ´nio Borges JÃºnior']
# ['Sivera', 'Antonio Sivera SalvÃ¡']
# ['CafÃº', 'Carlos Miguel Ribeiro Dias']
# ['Elustondo', 'Gorka Elustondo Urkola']
# ['Djalma', 'Djalma Braume Manuel Abel Campos']
# ['FÃ¡bio', 'FÃ¡bio Pereira da Silva']
# ['Xavier', 'AntÃ³nio Manuel Pereira Xavier']
# ['Vigaray', 'Carlos MartÃ\xadn Vigaray']
# ['Oier', 'Oier Sanjurjo MatÃ©']
# ['Danilo', 'Danilo Teodoro Soares']
# ['Ontiveros', 'Javier Ontiveros Parra']
# ['Tiago', 'Tiago Pagnussat']
# ['Maycon', 'Maycon de Andrade Barberan']
# ['Camacho', 'JoÃ£o Pedro Gomes Camacho']
# ['Jandrei', 'Jandrei Chitolina Carniel']
# ['Ayrton', 'Ayrton Lucas Dantas de Medeiros']
# ['MarcÃ£o', 'Marcos Nascimento Teixeira']
# ['Allano', 'Allano Brendon de Souza Lima']
# ['Martos', 'Francisco Javier Martos Espigares']
# ['Murilo', 'Murilo de Souza Costa']
# ['RenÃ©', 'RenÃ© RomÃ¡n Hinojo']
# ['Bracali', 'Rafael Wihby Bracalli']
# ['Charles', 'Charles Marcelo da Silva']
# ['Rogerinho', 'Rogerio De Assis Silva Coutinho']
# ['Felipe', 'Felipe Martins']
# ['Simy', 'Simeon Tochukwu Nwankwo']
# ['Costinha', 'JoÃ£o JosÃ©  Pereira da Costa']
# ['Claiton', 'Claiton Machado dos Santos']
# ['SalomÃ£o', 'Diogo Ferreira SalomÃ£o']
# ['Jairinhazo', 'Jairo Ralph Resende dos Santos']
# ['Clerc', 'Carlos Clerc MartÃ\xadnez']
# ['GuitiÃ¡n', 'Alberto GuitiÃ¡n Ceballos']
# ['Angulo', 'Igor Angulo AlbÃ³niga']
# ['Joselu', 'JosÃ© LuÃ\xads Moreno Barroso']
# ['Montoro', 'Ã\x81ngel Montoro SÃ¡nchez']
# ['Alberto', 'Alberto GarcÃ\xada Cabrera']
# ['Fernandinho', 'Luiz Fernando Pereira da Silva']
# ['Porphirinho', 'R. Nicholas PorfÃ\xadrio Jardim']
# ['Carlos', 'Carlos Alberto Carvalho Silva Jr.']
# ['Juankar', 'Juan Carlos PÃ©rez LÃ³pez']
# ['Pimentiscinho', 'Miguel Edson Pimenta Baia']
# ['Dener', 'Dener Gomes Clemente']
# ['Patric', 'Patricio GabarrÃ³n Gil']
# ['IsaÃ\xadas', 'IsaÃ\xadas SÃ¡nchez CortÃ©s']
# ['Molinero', 'Francisco JosÃ© Molinero CalderÃ³n']
# ['Laure', 'Laureano Sanabria Ruiz']
# ['Ailton', 'Ailton Ferreira Silva']
# ['BobÃ´', 'Deivson RogÃ©rio Da Silva']
# ['HervÃ\xadas', 'Pablo HervÃ\xadas Rubio']
# ['Juanfran', 'Juan Francisco Moreno Fuertes']
# ['Chiquinho', 'Francisco Leonel Lima Silva Machado']
# ['PelÃ©', 'Judilson Mamadu TuncarÃ¡ Gomes']
# ['Wallace', 'Wallace Reis da Silva']
# ['Douglas', 'Douglas Chagas Matos']
# ['Amilton', 'Amilton Minervino da Silva']
# ['Calero', 'Fernando Calero Villa']
# ['Kuca', 'JaÃ\xadlton Alves Miranda']
# ['Cucurella', 'Marc Cucurella Saseta']
# ['Galeno', 'Wenderson Nascimento Galeno']
# ['PerdigÃ£o', 'Jeferson Fernandes Macedo']
# ['Cristiano', 'Cristiano da Silva']
# ['Samir', 'Samir Caetano de Souza Santos']
# ['Munir', 'Munir Mohand Mohamedi']
# ['Jorge', 'Jorge Marco de Oliveira Moraes']
# ['Ã‰lton', 'Ã‰lton JosÃ© Xavier  Gomes']
# ['Alexis', 'Alexis Ruano Delgado']
# ['Cifuentes', 'Alberto Cifuentes MartÃ\xadnez']
# ['Aitor', 'Aitor FernÃ¡ndez']
# ['Vadillo', 'Ã\x81lvaro Vadillo Cifuentes']
# ['Manquillo', 'Javier Manquillo GaitÃ¡n']
# ['Guerrero', 'Miguel Ã\x81ngel Guerrero MartÃ\xadn']
# ['Vesga', 'Mikel Vesga Arruti']
# ['Welthon', 'Welthon Fiel Sampaio']
# ['Camilo', 'Camilo da Silva Sanvezzo']
# ['Baiano', 'Wanderson  Souza Carneiro']
# ['Ricardo', 'Ricardo Jorge Novo Nunes']
# ['GabrÃ¬el', 'Gabriel Vasconelos Ferreira']
# ['Adama', 'Adama TraorÃ© Diarra']
# ['Padilhisco', 'Adolfo Heitor Padilha Alves']
# ['Dentinho', 'Bruno Ferreira Bonfim']
# ['Carmona', 'Carlos Carmona Bonet']
# ['Quique', 'Enrique GonzÃ¡lez CasÃ\xadn']
# ['Patric', 'Anderson Patric Aguiar Oliveira']
# ['Zainadine', 'Zainadine Chavango JÃºnior']
# ['Arana', 'Guilherme Arana Lopes']
# ['Bigas', 'Pedro Bigas Rigo']
# ['Rafael', 'Rafael Cabral Barbosa']
# ['Crespo', 'JosÃ© Ã\x81ngel Crespo RincÃ³n']
# ['Ewerton', 'Ewerton JosÃ© Almeida Santos']
# ['Riesgo', 'Asier Riesgo Unamuno']
# ['Pozo', 'JosÃ© Ã\x81ngel Pozo la Rosa']
# ['MaurÃ\xadcio', 'MaurÃ\xadcio de Carvalho AntÃ³nio']
# ['Edvaldisco', 'Edvaldo FlÃ¡vio Rebelo de Freit']
# ['William', 'William de Asevedo Furtado']
# ['Bojan', 'Bojan KrkiÄ‡ PÃ©rez']
# ['Renatinho', 'Renato Ribeiro Calixto Aguiar']
# ['Kahraba', 'Mahmoud Abdel Moneim']
# ['Seoane', 'Fernando Seoane Antelo']
# ['Lato', 'Antonio Latorre Grueso']
# ['RÃ³ber', 'Roberto SuÃ¡rez Pier']
# ['GÃ¡lvez', 'Alejandro GÃ¡lvez Jimena']
# ['Jairo', 'Jairo Samperio Bustara']
# ['Joselu', 'JosÃ© Luis SanmartÃ\xadn Mato']
# ['Gerson', 'Gerson Santos da Silva']
# ['Eduardo', 'Eduardo dos Reis Carvalho']
# ['Anselmo', 'Anselmo de Moraes']
# ['Zubeldia', 'Igor Zubeldia Elorza']
# ['Bebeto', 'Roberto Jesus Machado Beto Alves']
# ['Ivi', 'IvÃ¡n LÃ³pez Ã\x81lvarez']
# ['Francis', 'Francisco Javier Guerrero MartÃ\xadn']
# ['MedrÃ¡n', 'Ã\x81lvaro MedrÃ¡n Just']
# ['Guilherme', 'Guilherme Costa Marques']
# ['Lekue', 'IÃ±igo Lekue MartÃ\xadnez']
# ['Titi', 'Cristian Chagas Tarouco']
# ['Tarantini', 'Ricardo JosÃ© Vaz Alves Monteiro']
# ['Pedraza', 'Alfonso Pedraza Sag']
# ['Lafortiscinho', 'Erick SebastiÃ£o Laforte Medeiros']
# ['Sequeira', 'Nuno Miguel Ribeiro da Cruz JerÃ³nimo Sequeira']
# ['Rochina', 'RubÃ©n  Rochina Naixes']
# ['Mosquera', 'Pedro Mosquera Parada']
# ['Mexer', 'Edson AndrÃ© Sitoe']
# ['Melero', 'Gonzalo JuliÃ¡n Melero Manzanares']
# ['HernÃ¢ni', 'HernÃ¢ni Jorge Santos Fortes']
# ['Zeca', 'JosÃ© Carlos GonÃ§alves Rodrigues']
# ['Merino', 'Mikel Merino ZazÃ³n']
# ['MartÃ\xadn', 'MartÃ\xadn Aguirregabiria']
# ['Timor', 'David Timor CopovÃ\xad']
# ['CÃ¡ssio', 'CÃ¡ssio Albuquerque dos Anjos']
# ['Melendo', 'Ã“scar Melendo JimÃ©nez']
# ['Sandro', 'Sandro  RamÃ\xadrez Castillo']
# ['Keko', 'Sergio GontÃ¡n Gallardo']
# ['Postigo', 'Sergio Postigo Redondo']
# ['FabrÃ\xadcio', 'FabrÃ\xadcio dos Santos Messias']
# ['Carlitos', 'Carlos Daniel LÃ³pez Huesca']
# ['Jorginhson', 'Jorgino Silas Ruiz Prestes']
# ['Oier', 'Oier OlazÃ¡bal Paredes']
# ['Bernardo', 'Bernardo Fernandes da Silva Junior']
# ['Bustinza', 'Unai Bustinza MartÃ\xadnez']
# ['Ã‰der', 'Ã‰derzito AntÃ³nio Macedo Lopes']
# ['Iraizoz', 'Gorka Iraizoz Moreno']
# ['Kaku', 'Alejandro Romero Gamarra']
# ['Portillo', 'Francisco Portillo Soler']
# ['Rafael', 'Rafael  de Andrade Bittencourt Pinheiro']
# ['Danilo', 'Danilo Barbosa da Silva']
# ['FransÃ©rgio', 'FransÃ©rgio Rodrigues Barbosa']
# ['Palhinha', 'JoÃ£o Maria Lobo Alves Palhinha GonÃ§alves']
# ['AlcalÃ¡', 'Pedro AlcalÃ¡ Guirado']
# ['Rolando', 'Rolando Jorge Pires da Fonseca']
# ['AdriÃ¡n', 'AdriÃ¡n LÃ³pez Ã\x81lvarez']
# ['Jonathas', 'Jonathas de Jesus MaurÃ\xadcio']
# ['Jemerson', 'Jemerson de Jesus Nascimento']
# ['Victildinho', 'Victor Martin Maia Padilha']
# ['Jaume', 'Jaume Domenech SÃ¡nchez']
# ['Camarasa', 'VÃ\xadctor Camarasa Ferrando']
# ['Rafinha', 'MÃ¡rcio Rafael Ferreira de Souza']
# ['Vieirinha', 'Adelino AndrÃ© Vieira de Freitas']
# ['Iturraspe', 'Ander Iturraspe Derteano']
# ['Joelinton', 'Joelinton ApolinÃ¡rio de Lira']
# ['Beto', 'AntÃ³nio Alberto Bastos Pimparel']
# ['Yoel', 'Yoel RodrÃ\xadguez Oterino']
# ['Gil', 'Carlos Gilberto do Nascimento Silva']
# ['Soldado', 'Roberto Soldado Rillo']
# ['Naldo', 'Edinaldo Gomes Pereira']
# ['JosuÃ©', 'JosuÃ© Filipe Soares Pesqueira']
# ['Claudemir', 'Claudemir Domingues de Souza']
# ['Embarba', 'AdriÃ¡n Embarba Blazquez']
# ['HÃ©ldon', 'HÃ©ldon Augusto Almeida Ramos']
# ['Dalbert', 'Dalbert Henrique Chagas EstevÃ£o']
# ['Gomes', 'Heurelho da Silva Gomes']
# ['JesÃ©', 'JesÃ© RodrÃ\xadguez Ruiz']
# ['Juanmi', 'Juan Miguel JimÃ©nez LÃ³pez']
# ['OtÃ¡vio', 'OtÃ¡vio Henrique Passos Santos']
# ['TozÃ©', 'AntÃ³nio JosÃ© Pinheiro Carvalho']
# ['Vieirundinho', 'Danilo Manuel Vieira EspÃ\xadndola']
# ['AngeliÃ±o', 'JosÃ© Ã\x81ngel Esmoris Tasende']
# ['Jony', 'Jonathan RodrÃ\xadguez MenÃ©ndez']
# ['Sergio', 'Sergio Ã\x81lvarez Conde']
# ['Sidcley', 'Sidcley Ferreira Pereira']
# ['Cote', 'JosÃ© Ã\x81ngel ValdÃ©s DÃ\xadaz']
# ['Danilo', 'Danilo Larangeira']
# ['Varela', 'Fernando Lopes dos Santos Varela']
# ['Douglas', 'Douglas Renato de Jesus']
# ['Laguardia', 'VÃ\xadctor Laguardia Cisneros']
# ['MaurÃ\xadcio', 'MaurÃ\xadcio JosÃ© da Silveira JÃºnior']
# ['Wendell', 'Wendell Nascimento Borges']
# ['Vallejo', 'JesÃºs Vallejo LÃ¡zaro']
# ['Formosandrinho', 'EstevÃ£o Daniel Formoso Serpa']
# ['Pablo', 'Pablo Nascimento Castro']
# ['JÃ´', 'JoÃ£o Alves de Assis Silva']
# ['Munir', 'Munir El Haddadi']
# ['MarÃ§al', 'Fernando MarÃ§al de Oliveira']
# ['Mata', 'Jaime Mata Arnaiz']
# ['Montoya', 'MartÃ\xadn Montoya Torralbo']
# ['Arbilla', 'Anaitz Arbilla Zabala']
# ['Gazzolisco', 'GÃ©rson Adriano Gutierres Serra']
# ['Bruno', 'Bruno GonzÃ¡lez Cabrera']
# ['Wendel', 'Marcus Wendel Valle da Silva']
# ['Gervinho', 'Gervais Lombe Yao Kouassi']
# ['Guilherme', 'Guilherme Alvim Marinato']
# ['Bernat', 'Juan Bernat Velasco']
# ['Matheus', 'Matheus Lima MagalhÃ£es']
# ['Gabriel', 'Gabriel Appelt Pires']
# ['Bruma', 'Armindo TuÃ© Na Bangna']
# ['Bastos', 'Bartolomeu Jacinto Quissanga']
# ['Petros', 'Petros Matheus dos Santos Araujo']
# ['Granell', 'Ã€lex Granell NoguÃ©']
# ['Trezeguet', 'Mahmoud Hassan']
# ['Yeray', 'Yeray Ã\x81lvarez LÃ³pez']
# ['Everticinho', 'Everton Jorge SimÃ£o Resende']
# ['Wesley', 'Wesley Moraes Ferreira da Silva']
# ['Ã\x81ngel', 'Ã\x81ngel LuÃ\xads RodrÃ\xadguez DÃ\xadaz']
# ['Eder', 'Eder Citadin Martins']
# ['Marcelo', 'Marcelo AntÃ´nio Guedes Filho']
# ['Bruno', 'Bruno  Soriano Llido']
# ['Fernando', 'Fernando Francisco Reges']
# ['Mariano', 'Mariano Ferreira Filho']
# ['Susaeta', 'Markel Susaeta Laskurain']
# ['Souza', 'Josef de Souza Dias']
# ['Iborra', 'Vicente Iborra de la Fuente']
# ['Rafael', 'Rafael Pereira da Silva']
# ['Danilo', 'Danilo Luiz da Silva']
# ['Nolito', 'Manuel Agudo DurÃ¡n']
# ['CampaÃ±a', 'JosÃ© Ã\x81ngel GÃ³mez CampaÃ±a']
# ['Deulofeu', 'Gerard Deulofeu LÃ¡zaro']
# ['Pozuelo', 'Alejandro Pozuelo Melero']
# ['Roger', 'Roger MartÃ\xad Salvador']
# ['Soares', 'Francisco das Chagas Soares dos Santos']
# ['Raphinha', 'Raphael Dias Belloli']
# ['Loren', 'Lorenzo MorÃ³n GarcÃ\xada']
# ['Marcano', 'IvÃ¡n Marcano Sierra']
# ['BeÃ±at', 'BeÃ±at Etxebarria Urkiaga']
# ['Antunes', 'Vitorino Gabriel  Pacheco Antunes']
# ['Sidnei', 'Sidnei Rechel da Silva JÃºnior']
# ['Camacho', 'Ignacio Camacho Barnola']
# ['Guaita', 'Vicente Guaita Panadero']
# ['Maicon', 'Maicon Pereira Roque']
# ['Portu', 'Cristian PortuguÃ©s Manzanera']
# ['Bernard', 'Bernard  AnÃ\xadcio Caldeira Duarte']
# ['Fred', 'Frederico R. de Paula Santos']
# ['Pacheco', 'Fernando Pacheco Flores']
# ['GayÃ\xa0', 'JosÃ© LuÃ\xads GayÃ\xa0 PeÃ±a']
# ['Williams', 'IÃ±aki Williams Arthuer']
# ['Rafa', 'Rafael Alexandre Fernandes Ferreira da Silva']
# ['RaÃºl', 'RaÃºl Michel Melo da Silva']
# ['Mariano', 'Mariano DÃ\xadaz MejÃ\xada']
# ['Nani', 'LuÃ\xads Carlos Almeida da Cunha']
# ['Hulk', 'Givanildo Vieira de Souza']
# ['Muniain', 'Iker Muniain GoÃ±i']
# ['Vitolo', 'VÃ\xadctor MachÃ\xadn PÃ©rez']
# ['Morales', 'JosÃ© Luis Morales Nogales']
# ['Aduriz', 'Aritz Aduriz Zubeldia']
# ['Jardel', 'Jardel Nivaldo Vieira']
# ['AdÃ¡n', 'Antonio AdÃ¡n Garrido']
# ['Pedro', 'Pedro Eliezer RodrÃ\xadguez Ledesma']
# ['Bartra', 'Marc Bartra Aregall']
# ['Morata', 'Ã\x81lvaro Borja Morata MartÃ\xadn']
# ['Rafinha', 'Rafael AlcÃ¢ntara do Nascimento']
# ['Grimaldo', 'Alejandro Grimaldo GarcÃ\xada']
# ['Casillas', 'Iker Casillas FernÃ¡ndez']
# ['Sokratis', 'Sokratis Papastathopoulos']
# ['Jonas', 'Jonas GonÃ§alves Oliveira']
# ['Oscar', 'Oscar dos Santos Emboaba JÃºnior']
# ['Canales', 'Sergio Canales Madrazo']
# ['Neto', 'Norberto Murara Neto']
# ['Pizzi', 'LuÃ\xads Miguel Afonso Fernandes']
# ['Rodrigo', 'Rodrigo Moreno Machado']
# ['Suso', 'JesÃºs JoaquÃ\xadn FernÃ¡ndez SÃ¡ez']
# ['Quaresma', 'Ricardo Andrade Quaresma Bernardo']
# ['Falcao', 'Radamel Falcao GarcÃ\xada ZÃ¡rate']
# ['Miranda', 'JoÃ£o Miranda de Souza Filho']
# ['Naldo', 'Ronaldo  Aparecido Rodrigues']
# ['Willian', 'Willian Borges da Silva']
# ['Illarramendi', 'Asier Illarramendi Andonegi']
# ['Allan', 'Allan Marques Loureiro']
# ['Pepe', 'KÃ©pler Laveran Lima Ferreira']
# ['Paulinho', 'JosÃ© Paulo Bezzera Maciel JÃºnior']
# ['Parejo', 'Daniel Parejo MuÃ±oz']
# ['Koke', 'Jorge ResurrecciÃ³n Merodio']
# ['Carvajal', 'Daniel Carvajal Ramos']
# ['Marquinhos', 'Marcos  AoÃ¡s CorrÃªa']
# ['SaÃºl', 'SaÃºl Ã‘Ã\xadguez EsclÃ¡pez']
# ['Azpilicueta', 'CÃ©sar Azpilicueta Tanco']
# ['Ederson', 'Ederson Santana de Moraes']
# ['Alisson', 'Alisson Ramses Becker']
# ['PiquÃ©', 'Gerard PiquÃ© BernabÃ©u']
# ['Coutinho', 'Philippe Coutinho Correia']

# %%
# Check assertion 1
for tp in lines:
    numname = len(tp.split(',')[0].split(' '))
    if numname==2:
        fn = tp.split(',')[0].split(' ')[0]
        surname = tp.split(',')[0].split(' ')[1]
        fullname = tp.split(',')[1]
        if surname in fullname.split(' '):
            if fullname.split(' ').index(surname)==0:
                print(surname + ' ---> ' + fullname)
# Out:
# AndrÃ© ---> AndrÃ© Filipe BrÃ¡s AndrÃ©
# Chan ---> Chan Kim
# Gang ---> Gang Feng
# Xiaoxuan ---> Xiaoxuan Ji
# Yuqin ---> Yuqin Gao
# Shilong ---> Shilong Wang
# Hui ---> Hui Zhang
# Guoyuan ---> Guoyuan Yang
# Peilei ---> Peilei Cai
# Jinze ---> Jinze Wang
# Liuyu ---> Liuyu Duan
# Jianfei ---> Jianfei Zhao
# Tang ---> Tang Chen
# Junlin ---> Junlin Chen
# Seong-Hoon ---> Seong-Hoon Cheon
# Lario ---> Lario MartÃ­nez JerÃ³nimo Manuel
# Wai-Tsun ---> Wai-Tsun Dai
# Weicheng ---> Weicheng Wang
# Ilgyu ---> Ilgyu Park
# Ogude ---> Ogude Emmanuel Ifeanyi
# DjenÃ© ---> DjenÃ© Dakonam Ortega

# %%
['A', 'Bv', 'Def'].index('Bv')
