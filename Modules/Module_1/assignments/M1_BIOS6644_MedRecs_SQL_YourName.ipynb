# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Wrangle Synthetic Medical Record Data -- Part 2
#
##########################################################################################

# %% [markdown]
# ## Fetch data
# (This is the same data used in the previous homework--no need to re-fetch it)
# Go here: https://drive.google.com/drive/folders/0B5Wu8z15TIbiLUhvcWxaMDJCRGs
#
# Get this data set: 10000-Patients.zip
#
# unzip it into the Data folder

# %%
import pandas as pd
import pylab as plt
import numpy as np
import datetime as dt

# %%
##  ###################################################################################################################
#
# You do:  
#    Ensure you have SQLite3 available to your system.  If not, install it via pip, conda, etc.
import sqlite3

# %%
# Read data in to data frames

p = pd.read_csv('../BIOS6644/Data/PatientCorePopulatedTable.txt', header=0,sep = '\t')
a = pd.read_csv('../BIOS6644/Data/AdmissionsCorePopulatedTable.txt', header=0, sep='\t')
d = pd.read_csv('../BIOS6644/Data/AdmissionsDiagnosesCorePopulatedTable.txt', header=0, sep='\t')  
l = pd.read_csv('../BIOS6644/Data/LabsCorePopulatedTable.txt', header=0, sep='\t')

# %%
#p.loc[p.PatientID=='915BC24E-8C44-4D33-A386-CEA965B83F32']

# %%
# Convert date columns to pandas date objects
# Show the type
type(p.PatientDateOfBirth[3])

for table in [p,a,d,l]:
    for col in table.columns:
        if 'date' in col.lower():
            print('Converting {}'.format(col))
            table[col] = pd.to_datetime(table[col])
# Out:
# Converting PatientDateOfBirth
# Converting AdmissionStartDate
# Converting AdmissionEndDate
# Converting LabDateTime

# %% [markdown]
#  SQLite3 is a "lightweight" database management system.  Within Python you create a "connection" to the dabaase
#  (here we called it "conn") and you can then send SQL queries to the connection, getting standard data frames in
#  return.

# %%
conn = sqlite3.connect(':memory:')  # this makes an "in memory" database that isn't written to a disk.  You 
                                    # can replace this with a file name if you want to store the data for later
                                    # use.

print('Loading data into in-memory db--this could take a minute or two')
l.to_sql('L', conn, if_exists='replace')
d.to_sql('D', conn, if_exists='replace')
a.to_sql('A', conn, if_exists='replace')
p.to_sql('P', conn, if_exists='replace')
# Out:
# Loading data into in-memory db--this could take a minute or two

# %% [markdown]
# ## Basic SQL queries

# %%
# To query via SQLite3, write a query as a Python string and "execute it" read_sql_query() method.
#
# Note:  If you are accessing data already in a different database managemnt system (MySQL/Access/etc) there are
#  interfaces available which give you a "conn" to that data as well.  You're not limited to SQLite with this
#  method.


sql = """
SELECT * from L
LIMIT 10
"""

df2 = pd.read_sql_query(sql, conn)
df2
# Out:
#    index                             PatientID  AdmissionID  \
# 0      0  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 1      1  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 2      2  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 3      3  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 4      4  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 5      5  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 6      6  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 7      7  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 8      8  915BC24E-8C44-4D33-A386-CEA965B83F32            1
# 9      9  915BC24E-8C44-4D33-A386-CEA965B83F32            1
#
#                 LabName  LabValue LabUnits                 LabDateTime
# 0       CBC: HEMATOCRIT      40.7        %  1946-09-07 22:20:26.677000
# 1  METABOLIC: ANION GAP       8.4   mmol/L  1946-09-07 11:52:58.600000
# 2      CBC: LYMPHOCYTES       4.7   k/cumm  1946-09-07 06:08:57.303000
# 3       CBC: HEMOGLOBIN      15.9    gm/dl  1946-09-07 19:16:10.057000
# 4     METABOLIC: SODIUM     146.6   mmol/L  1946-09-07 14:03:11.003000
# 5    METABOLIC: ALBUMIN       3.3    gm/dL  1946-09-08 04:06:53.967000
# 6        METABOLIC: BUN      17.1    mg/dL  1946-09-07 19:41:39.247000
# 7      CBC: NEUTROPHILS       8.4   k/cumm  1946-09-07 05:33:34.320000
# 8    METABOLIC: CALCIUM       8.7    mg/dL  1946-09-07 16:23:41.213000
# 9    METABOLIC: GLUCOSE     110.5    mg/dL  1946-09-07 09:40:39.467000

# %%
# Use the WHERE statement

# Example: Query all labs from admission-id #3

sql = """
SELECT *
FROM L
WHERE AdmissionID==3;
"""
pd.read_sql_query(sql, conn)
#df2
# Out:
#             index                             PatientID  AdmissionID  \
# 0             163  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 1             164  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 2             165  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 3             166  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 4             167  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 5             168  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 6             169  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 7             170  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 8             171  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 9             172  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 10            173  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 11            174  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 12            175  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 13            176  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 14            177  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 15            178  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 16            179  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 17            180  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 18            181  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 19            182  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 20            183  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 21            184  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 22            185  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 23            186  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 24            187  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 25            188  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 26            189  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 27            190  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 28            191  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# 29            192  915BC24E-8C44-4D33-A386-CEA965B83F32            3
# ...           ...                                   ...          ...
# 2233549  10725981  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233550  10725982  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233551  10725983  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233552  10725984  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233553  10725985  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233554  10725986  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233555  10725987  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233556  10725988  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233557  10725989  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233558  10725990  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233559  10725991  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233560  10725992  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233561  10725993  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233562  10725994  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233563  10725995  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233564  10725996  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233565  10725997  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233566  10725998  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233567  10725999  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233568  10726000  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233569  10726001  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233570  10726002  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233571  10726003  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233572  10726004  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233573  10726005  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233574  10726006  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233575  10726007  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233576  10726008  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233577  10726009  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
# 2233578  10726010  79F36FCF-9126-4D17-B42C-DDD9922FC3EF            3
#
#                                LabName  LabValue LabUnits  \
# 0                            CBC: MCHC      31.6     g/dl
# 1                             CBC: MCH      29.6       pg
# 2                METABOLIC: CREATININE       0.6    mg/dL
# 3          CBC: WHITE BLOOD CELL COUNT      11.4   k/cumm
# 4                       METABOLIC: BUN      14.5    mg/dL
# 5                             CBC: RDW      11.1        %
# 6          URINALYSIS: RED BLOOD CELLS       0.3  rbc/hpf
# 7            CBC: ABSOLUTE LYMPHOCYTES      23.1        %
# 8            METABOLIC: CARBON DIOXIDE      20.9   mmol/L
# 9                   METABOLIC: GLUCOSE      93.1    mg/dL
# 10                    CBC: LYMPHOCYTES       4.1   k/cumm
# 11                     CBC: HEMATOCRIT      48.9        %
# 12           CBC: RED BLOOD CELL COUNT       5.3   m/cumm
# 13                 METABOLIC: AST/SGOT      18.2      U/L
# 14                 METABOLIC: CHLORIDE     104.7   mmol/L
# 15                METABOLIC: ANION GAP      12.0   mmol/L
# 16                 METABOLIC: ALK PHOS      63.0      U/L
# 17                   METABOLIC: SODIUM     139.7   mmol/L
# 18                 CBC: PLATELET COUNT     150.8   k/cumm
# 19            METABOLIC: TOTAL PROTEIN       6.4    gm/dL
# 20        CBC: MEAN CORPUSCULAR VOLUME      85.9       fl
# 21       URINALYSIS: WHITE BLOOD CELLS       4.3  wbc/hpf
# 22        URINALYSIS: SPECIFIC GRAVITY       1.0  no unit
# 23                  METABOLIC: CALCIUM       9.8    mg/dL
# 24           CBC: ABSOLUTE NEUTROPHILS      79.7        %
# 25                    CBC: EOSINOPHILS       0.2   k/cumm
# 26               METABOLIC: BILI TOTAL       0.6    mg/dL
# 27                     CBC: HEMOGLOBIN      17.1    gm/dl
# 28                    CBC: NEUTROPHILS       6.9   k/cumm
# 29                      CBC: MONOCYTES       0.2   k/cumm
# ...                                ...       ...      ...
# 2233549                 CBC: MONOCYTES       0.8   k/cumm
# 2233550      CBC: ABSOLUTE LYMPHOCYTES      16.4        %
# 2233551           METABOLIC: POTASSIUM       3.2   mmol/L
# 2233552             METABOLIC: CALCIUM       8.1    mg/dL
# 2233553          METABOLIC: BILI TOTAL       0.4    mg/dL
# 2233554                 URINALYSIS: PH       7.4  no unit
# 2233555    URINALYSIS: RED BLOOD CELLS       0.9  rbc/hpf
# 2233556             METABOLIC: GLUCOSE     112.7    mg/dL
# 2233557             METABOLIC: ALBUMIN       5.8    gm/dL
# 2233558            METABOLIC: ALT/SGPT      24.7      U/L
# 2233559                 CBC: BASOPHILS       0.1   k/cumm
# 2233560   URINALYSIS: SPECIFIC GRAVITY       1.0  no unit
# 2233561      CBC: ABSOLUTE NEUTROPHILS      75.0        %
# 2233562            CBC: PLATELET COUNT     313.9   k/cumm
# 2233563             METABOLIC: CALCIUM       9.2    mg/dL
# 2233564                 METABOLIC: BUN      27.5    mg/dL
# 2233565                       CBC: MCH      34.4       pg
# 2233566                CBC: HEMOGLOBIN      14.7    gm/dl
# 2233567            METABOLIC: ALK PHOS      49.4      U/L
# 2233568           METABOLIC: POTASSIUM       5.5   mmol/L
# 2233569    CBC: WHITE BLOOD CELL COUNT      11.5   k/cumm
# 2233570               CBC: NEUTROPHILS       5.8   k/cumm
# 2233571                      CBC: MCHC      38.9     g/dl
# 2233572                CBC: HEMATOCRIT      41.0        %
# 2233573          METABOLIC: CREATININE       0.7    mg/dL
# 2233574            METABOLIC: AST/SGOT      20.4      U/L
# 2233575  URINALYSIS: WHITE BLOOD CELLS       3.6  wbc/hpf
# 2233576                 CBC: MONOCYTES       1.0   k/cumm
# 2233577            METABOLIC: CHLORIDE     109.1   mmol/L
# 2233578                       CBC: RDW      14.7        %
#
#                         LabDateTime
# 0        2008-10-08 10:11:47.543000
# 1        2008-10-08 17:55:31.247000
# 2        2008-10-08 15:36:59.533000
# 3        2008-10-08 09:31:41.360000
# 4        2008-10-08 07:56:07.697000
# 5        2008-10-08 03:24:55.450000
# 6        2008-10-08 23:39:43.667000
# 7        2008-10-08 18:41:18.467000
# 8        2008-10-08 04:50:40.677000
# 9        2008-10-08 16:40:24.897000
# 10       2008-10-08 08:00:13.640000
# 11       2008-10-08 20:53:19.207000
# 12       2008-10-08 11:32:55.427000
# 13       2008-10-08 18:48:01.083000
# 14       2008-10-08 08:58:09.967000
# 15       2008-10-08 23:21:26.843000
# 16       2008-10-08 08:34:52.200000
# 17       2008-10-08 14:37:10.157000
# 18       2008-10-08 07:24:54.830000
# 19       2008-10-08 18:39:39.447000
# 20       2008-10-09 01:14:28.547000
# 21       2008-10-08 21:28:16.323000
# 22       2008-10-08 23:44:22.673000
# 23       2008-10-08 23:40:59.667000
# 24       2008-10-08 07:16:26.673000
# 25       2008-10-08 14:26:13.910000
# 26       2008-10-08 13:29:03.403000
# 27       2008-10-08 02:46:20.227000
# 28       2008-10-08 16:46:24.573000
# 29       2008-10-08 20:07:56.720000
# ...                             ...
# 2233549         2000-11-17 21:51:05
# 2233550  2000-11-17 15:10:17.037000
# 2233551  2000-11-18 12:39:58.280000
# 2233552  2000-11-18 01:21:39.147000
# 2233553  2000-11-18 16:58:42.987000
# 2233554  2000-11-18 17:15:48.783000
# 2233555  2000-11-18 18:06:25.157000
# 2233556  2000-11-18 14:38:10.687000
# 2233557  2000-11-18 16:01:42.670000
# 2233558  2000-11-18 15:17:20.423000
# 2233559  2000-11-18 14:23:07.410000
# 2233560  2000-11-18 13:35:24.497000
# 2233561  2000-11-18 17:31:32.093000
# 2233562  2000-11-18 16:18:35.130000
# 2233563  2000-11-18 16:14:23.290000
# 2233564  2000-11-18 17:21:37.717000
# 2233565  2000-11-18 13:29:42.503000
# 2233566  2000-11-18 13:16:09.337000
# 2233567  2000-11-18 17:04:14.707000
# 2233568  2000-11-18 15:51:00.477000
# 2233569  2000-11-18 13:04:40.683000
# 2233570  2000-11-18 15:23:30.103000
# 2233571  2000-11-18 17:01:36.517000
# 2233572  2000-11-18 13:16:08.257000
# 2233573  2000-11-18 17:16:08.573000
# 2233574  2000-11-18 13:04:53.680000
# 2233575  2000-11-18 17:01:03.940000
# 2233576  2000-11-18 17:16:30.883000
# 2233577  2000-11-18 13:09:46.813000
# 2233578  2000-11-18 15:03:38.533000
#
# [2233579 rows x 7 columns]

# %%
# Example: 
# Query just the time and value for CBC: MCHC labs from admission-id #3, ensuring they are sorted in time order


sql = """
SELECT LabDateTime AS Time, LabValue as Value
FROM L
WHERE AdmissionID=3 AND LabName LIKE "%MCHC"
ORDER BY Time
"""

df3 = pd.read_sql_query(sql, conn)
df3.head()
# Out:
#                          Time  Value
# 0  1948-10-17 08:30:55.433000   35.8
# 1  1948-10-18 23:34:59.213000   39.9
# 2  1948-10-19 09:20:36.913000   31.1
# 3  1948-10-21 22:42:59.537000   33.0
# 4  1948-10-23 05:08:27.097000   31.4

# %%
# You would like to explore the relationship between lab-orders and depression
#
###################################################################################################################
#
# You do:
#  1) 
#   Generate a list of all (unique) diagnosis codes with the term "Major depressive disorder" in the description
#
#  2) Using a JOIN statement, join the Diagosis and Labs tables on PatientID and print the first 40 results

# %%
# 1)

# %%
# 2)

# %%
###################################################################################################################
#
# You do:
#  1) Create a list of each lab name ordered and it's count for any patient who also had a diagnosis which 
#     includes the term "Major depressive disorder"
