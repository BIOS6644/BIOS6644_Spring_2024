# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Slicing and Parsing
#
##########################################################################################

# %%
##################################################################################################################
#
# YouDo:
#    1) Make a copy of this notebook with your name as a suffix:  
#       BIOS6644_CSV_Sugar_Metabolomics_FirstLast.ipynb
#    2) Do all work in this new notebook.
#    3) Place completed work in students/Module_1/Your_Name
#    4) Push to your branch on GitHub to submit
#
##################################################################################################################

# %% [markdown]
# # Wrangling Sugar Metabolomics Data

# %%
import pandas as pd
import pylab as plt
import numpy as np
# %matplotlib inline
# Out:
# /var/folders/lt/fpvz1f3j6wgf7hzmdnzyb6440000gn/T/ipykernel_46792/1403196198.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# General info here:
#   https://data.mendeley.com/datasets/9z7ncwvxnz/1
#
# Data here:
#   https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/9z7ncwvxnz-1.zip

# I renamed mine to "sugar_metabolomics.csv" so I could remember what it is
data = '../Data/sugar_metabolomics.csv'

# %%
##################################################################################################################
#
# YouDo:
# 
#    1) Read the csv into a dataframe called df
#######################################  BEGIN STUDENT CODE  #####################################################

# 1) 
# df = pd.read_csv('sugar_metabolomics.csv')

df = pd.read_csv('sugar_metabolomics.csv')

#######################################   END STUDENT CODE   #####################################################


df
# Out:
#     Unnamed: 0  Label   Pyruvate  MethylSuccinate  Phosphoglyceric Acid  \
# 0           20      0  14.158545        15.624522             13.383600
# 1           24      0  14.180287        15.325665             13.468363
# 2           29      0  13.921329        16.156867             14.615061
# 3           52      0  13.785605        15.939535             13.206615
# 4           54      0  13.674234        15.743668             11.542008
# ..         ...    ...        ...              ...                   ...
# 88         100      1  13.911391        15.808535             13.255651
# 89         101      1  14.004190        15.578057             15.050097
# 90         102      1  13.782098        15.628488             13.800509
# 91         103      1  13.841570        15.697214             14.467861
# 92         104      1  13.621706        15.483609             14.060104
#
#     Glucose 1-phosphate  Malonic Acid  Fumaric Acid  Alpha-Ketoglutaric Acid  \
# 0             11.923638     13.933560     12.787696                14.981440
# 1             12.046294     13.043221     12.536227                14.593418
# 2             13.051929     13.381985     12.419600                14.701978
# 3             12.342156     12.448068     12.211098                14.860913
# 4             11.807872     14.582068     11.635154                14.970451
# ..                  ...           ...           ...                      ...
# 88            12.072060     12.829308     12.518926                14.914205
# 89            12.955338     12.021058     12.698247                14.838858
# 90            12.324283     13.557521     13.930284                15.010427
# 91            12.549533     13.157717     14.309882                14.518098
# 92            12.237578     13.847064     13.140827                14.923120
#
#     Sarcosine  ...  3-Hydroxybenzoic acid  Succinate              Glucose  \
# 0   11.739484  ...               3.161390   2.165842          8.310291624
# 1   11.833211  ...               2.355910   2.260621          8.423733003
# 2   12.232070  ...               2.472365   2.295447          8.357070943
# 3   11.949448  ...               1.844567   2.278589          8.414503996
# 4   11.457569  ...               3.773262   2.136011          8.193979575
# ..        ...  ...                    ...        ...                  ...
# 88  12.009783  ...               2.099744   2.460060          8.268259167
# 89  11.864216  ...               1.215855   2.716850          8.382160574
# 90  11.877001  ...               2.567097   2.339410          8.362964723
# 91  12.173317  ...               1.637428   2.147184          8.379107727
# 92  12.129161  ...               3.024477   2.641430  8.477305855""""""""
#
#                   V127                V128                V129  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# ..                 ...                 ...                 ...
# 88                 NaN                 NaN                 NaN
# 89                 NaN                 NaN                 NaN
# 90                 NaN                 NaN                 NaN
# 91                 NaN                 NaN                 NaN
# 92  """"""""NA""""""""  """"""""NA""""""""  """"""""NA""""""""
#
#                   V130                V131                V132  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# ..                 ...                 ...                 ...
# 88                 NaN                 NaN                 NaN
# 89                 NaN                 NaN                 NaN
# 90                 NaN                 NaN                 NaN
# 91                 NaN                 NaN                 NaN
# 92  """"""""NA""""""""  """"""""NA""""""""  """"""""NA""""""""
#
#                  V133
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 88                NaN
# 89                NaN
# 90                NaN
# 91                NaN
# 92  """"""""0""""""""
#
# [93 rows x 133 columns]

# %%
##################################################################################################################
#
# YouDo:
# 
#    1) Notice that the import is wonky -- examine the data set
#       manually and figure out how to make it import cleanly.
#      
#       Ensure your data frame has the following handled correctly
#         a) the column names (1st row of the csv)
#.        b) The unlabeled first column is read as an index
#         c) The final row is totally weird--don't import it
#
#       (hint: pd.read_csv? lists various import options)
#
#######################################  BEGIN STUDENT CODE  #####################################################

# 1) 
df = pd.read_csv('sugar_metabolomics.csv', index_col=0, skipfooter=1, engine='python')

#######################################   END STUDENT CODE   #####################################################
assert df.shape == (92, 132)

# %%
##################################################################################################################
#
# YouDo:
# 
#    1) Get rid of any columns that have only NaN values
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
#
#######################################  BEGIN STUDENT CODE  #####################################################

df = df.dropna(axis='columns', how='all')


#######################################   END STUDENT CODE   #####################################################

assert df.shape == (92, 125)

# %%
##################################################################################################################
#
# YouDo:
# 
#    1) Generate boxplots of Tryptophan levels separated based on 
#        the "Label" value
#
#      Use whatever plotting library you like.   
#      Hint 1: matplotlib has a boxplot tool
#          help(plt.boxplot)
#      Hint 2: pandas data frames have a built-in boxplot tool
#          help(df.boxplot)
#
#######################################  BEGIN STUDENT CODE  #####################################################

df.boxplot(column = 'Tryptophan', by = 'Label')
plt.suptitle('')
plt.show()

#######################################   END STUDENT CODE   #####################################################

# %%
##################################################################################################################
#
# YouDo:
# Make a pair of plots as follows:
#    1) Show the correlation matrix between columns of the data
#        (hint 1: it should be 124x124, hint 2: check out plt.imshow() 
#         Hint 2: numpy has a function for generating the correlation matrix)
#
#    2) Make a similar plot showing correlation > 90%
#
#  Stretch goal:  using plt.subplot()  make a single figure with both plots side-by-side
#
#######################################  BEGIN STUDENT CODE  #####################################################

cor = df.drop('Label', axis = 1)
cor = cor.corr()

cor90 = cor[abs(cor) > 0.9] 
    # Structure from https://datagy.io/python-correlation-matrix/

cor90

#######################################   END STUDENT CODE   #####################################################
# Out:
#                        Pyruvate  MethylSuccinate  Phosphoglyceric Acid  \
# Pyruvate                    1.0              NaN                   NaN
# MethylSuccinate             NaN              1.0                   NaN
# Phosphoglyceric Acid        NaN              NaN                   1.0
# Glucose 1-phosphate         NaN              NaN                   NaN
# Malonic Acid                NaN              NaN                   NaN
# ...                         ...              ...                   ...
# Cystine                     NaN              NaN                   NaN
# lactate                     NaN              NaN                   NaN
# 3-Hydroxybenzoic acid       NaN              NaN                   NaN
# Succinate                   NaN              NaN                   NaN
# Glucose                     NaN              NaN                   NaN
#
#                        Glucose 1-phosphate  Malonic Acid  Fumaric Acid  \
# Pyruvate                               NaN           NaN           NaN
# MethylSuccinate                        NaN           NaN           NaN
# Phosphoglyceric Acid                   NaN           NaN           NaN
# Glucose 1-phosphate                    1.0           NaN           NaN
# Malonic Acid                           NaN      1.000000           NaN
# ...                                    ...           ...           ...
# Cystine                                NaN           NaN           NaN
# lactate                                NaN           NaN           NaN
# 3-Hydroxybenzoic acid                  NaN      0.920592           NaN
# Succinate                              NaN           NaN           NaN
# Glucose                                NaN           NaN           NaN
#
#                        Alpha-Ketoglutaric Acid  Sarcosine  Cadaverine  \
# Pyruvate                                   NaN        NaN         NaN
# MethylSuccinate                            NaN        NaN         NaN
# Phosphoglyceric Acid                       NaN        NaN         NaN
# Glucose 1-phosphate                        NaN        NaN         NaN
# Malonic Acid                               NaN        NaN         NaN
# ...                                        ...        ...         ...
# Cystine                                    NaN        NaN         NaN
# lactate                                    NaN        NaN         NaN
# 3-Hydroxybenzoic acid                      NaN        NaN         NaN
# Succinate                                  NaN        NaN         NaN
# Glucose                                    NaN        NaN         NaN
#
#                        5-Aminovaleric Acid  ...  Histidine  Phenylalanine  \
# Pyruvate                               NaN  ...        NaN            NaN
# MethylSuccinate                        NaN  ...        NaN            NaN
# Phosphoglyceric Acid                   NaN  ...        NaN            NaN
# Glucose 1-phosphate                    NaN  ...        NaN            NaN
# Malonic Acid                           NaN  ...        NaN            NaN
# ...                                    ...  ...        ...            ...
# Cystine                                NaN  ...        NaN            NaN
# lactate                                NaN  ...        NaN            NaN
# 3-Hydroxybenzoic acid                  NaN  ...        NaN            NaN
# Succinate                              NaN  ...        NaN            NaN
# Glucose                                NaN  ...        NaN            NaN
#
#                        Arginine  Tyrosine  Tryptophan  Cystine  lactate  \
# Pyruvate                    NaN       NaN         NaN      NaN      NaN
# MethylSuccinate             NaN       NaN         NaN      NaN      NaN
# Phosphoglyceric Acid        NaN       NaN         NaN      NaN      NaN
# Glucose 1-phosphate         NaN       NaN         NaN      NaN      NaN
# Malonic Acid                NaN       NaN         NaN      NaN      NaN
# ...                         ...       ...         ...      ...      ...
# Cystine                     NaN       NaN         NaN      1.0      NaN
# lactate                     NaN       NaN         NaN      NaN      1.0
# 3-Hydroxybenzoic acid       NaN       NaN         NaN      NaN      NaN
# Succinate                   NaN       NaN         NaN      NaN      NaN
# Glucose                     NaN       NaN         NaN      NaN      NaN
#
#                        3-Hydroxybenzoic acid  Succinate  Glucose
# Pyruvate                                 NaN        NaN      NaN
# MethylSuccinate                          NaN        NaN      NaN
# Phosphoglyceric Acid                     NaN        NaN      NaN
# Glucose 1-phosphate                      NaN        NaN      NaN
# Malonic Acid                        0.920592        NaN      NaN
# ...                                      ...        ...      ...
# Cystine                                  NaN        NaN      NaN
# lactate                                  NaN        NaN      NaN
# 3-Hydroxybenzoic acid               1.000000        NaN      NaN
# Succinate                                NaN        1.0      NaN
# Glucose                                  NaN        NaN      1.0
#
# [124 rows x 124 columns]

# %%
##################################################################################################################
#
# YouDo:
#  1) Remove any rows with na values
# 
#  2) Split the data into "test" and "train" bits with ~30% in the test set.
#       The "Label" column is the "y" data.  All other columns are the "X" data
#       Give them these names:
#       X_train, X_test, y_train, y_test

#######################################  BEGIN STUDENT CODE  #####################################################

# 1)

dfdrop = df.dropna(axis = 0)
 
#2)
#referencing https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html 
from sklearn.model_selection import train_test_split

X_Train, X_Test, y_train, y_test = train_test_split(dfdrop.iloc[:, 1:125], dfdrop.iloc[:, 0:1], test_size = 0.3, random_state = 0) 


#######################################   END STUDENT CODE   #####################################################

# %%
#Build a model to classify the Label based on the other columns

from sklearn.ensemble import RandomForestClassifier
    #referencing https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html 

clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=8675309)

clf.fit(X_Train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=2, random_state=8675309)

# %%
# Test the model
predictions = clf.predict(X_Test)
reality = y_test

# %%
# YouDo:
#  1) Evaluate the "goodness" of the predictions and write a paragraph describing the results as a markdown.
#
#######################################  BEGIN STUDENT CODE  #####################################################
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

accuracy = accuracy_score(reality, predictions)
precision = precision_score(reality, predictions)
recall = recall_score(reality, predictions)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')

#######################################   END STUDENT CODE   #####################################################
# Out:
# Accuracy: 0.875
# Precision: 1.0
# Recall: 0.85

# %% [markdown]
# # Analysis
# It goes here.

# %% [markdown]
# The predictions have an accuracy of 0.875, precision of 1.0, and a recall of 0.85.
#
# - For accuracy, this means we would correctly predict 87.5 out of 100 cases, or 875 out of 1000 cases.
# - For precision, this means when the model made a prediction that the label value was 1, there were no cases of false positives.
# - For recall, this means that the cases the model had a prediction of 0, the real value was 1 about 15% of the time (i.e. it was correct 85% of the time).
