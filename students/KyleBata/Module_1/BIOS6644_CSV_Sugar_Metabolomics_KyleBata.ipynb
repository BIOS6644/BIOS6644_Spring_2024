# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Slicing and Parsing
#
##########################################################################################

# %%
##################################################################################################################
#
# YouDo:
#    1) Make a copy of this notebook with your name as a suffix:  
#       BIOS6644_CSV_Sugar_Metabolomics_FirstLast.ipynb
#    2) Do all work in this new notebook.
#    3) Submit completed work via GitHub pull request
#
##################################################################################################################

# %% [markdown]
# # Wrangling Sugar Metabolomics Data

# %%
# Libraries I need
import pandas as pd
import pylab as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
# %matplotlib notebook

# %%
# General info here:
#   https://data.mendeley.com/datasets/9z7ncwvxnz/1
#
# Data here:
#   https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/9z7ncwvxnz-1.zip

# I renamed mine to "sugar_metabolomics.csv" so I could remember what it is
data = "C:\\Users\\batak\\OneDrive\\GradCertHealthcareAnalyticsAndDataScience\\BIOS_6644_001\\BIOS6644_GitHub\\BIOS6644_Spring_2024\\students\\KyleBata\\Module_1\\sugar_metabolomics.csv"

# %%
##################################################################################################################
#
# YouDo:
# 
#    1) Read the csv into a dataframe
#######################################  BEGIN STUDENT CODE  #####################################################

# 1) 
df = pd.read_csv(data)

# Easy sample dataframe for testing
sample_data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
samp1 = pd.DataFrame(sample_data)
#######################################   END STUDENT CODE   #####################################################


df
# Out:
#     Unnamed: 0  Label   Pyruvate  MethylSuccinate  Phosphoglyceric Acid  \
# 0           20      0  14.158545        15.624522             13.383600
# 1           24      0  14.180287        15.325665             13.468363
# 2           29      0  13.921329        16.156867             14.615061
# 3           52      0  13.785605        15.939535             13.206615
# 4           54      0  13.674234        15.743668             11.542008
# ..         ...    ...        ...              ...                   ...
# 88         100      1  13.911391        15.808535             13.255651
# 89         101      1  14.004190        15.578057             15.050097
# 90         102      1  13.782098        15.628488             13.800509
# 91         103      1  13.841570        15.697214             14.467861
# 92         104      1  13.621706        15.483609             14.060104
#
#     Glucose 1-phosphate  Malonic Acid  Fumaric Acid  Alpha-Ketoglutaric Acid  \
# ...

# %%
##################################################################################################################
#
# YouDo:
# 
#    1) Notice that the import is wonky -- examine the data set
#       manually and figure out how to make it import cleanly.
#      
#       Ensure your data frame has the following handled correctly
#         a) the column names (1st row of the csv)
#.        b) The unlabeled first column is read as an index
#         c) The final row is totally weird--don't import it
#
#
#######################################  BEGIN STUDENT CODE  #####################################################

# Data Clean up
## Change Column 0 to "index"
df1 = df.set_index(df.columns[0])

## drop last row
df1 = df1[:-1]

# Double check output
#print(df1)
#print(samp1)
#print(df1.shape)
#######################################   END STUDENT CODE   #####################################################
assert df1.shape == (92, 132)

# %%
##################################################################################################################
#
# YouDo:
# 
#    1) Get rid of any columns that have only NaN values
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
#
#######################################  BEGIN STUDENT CODE  #####################################################
# check for columns that are only nan (92 nans)
#pd.options.display.max_rows = 999
#df1_nans = df1.isna().sum(axis = 0)
#filtered_df = df1_nans.loc[df1_nans[:] == 92]
#print(filtered_df)

# Drop columns
#df2 = df1.drop(['V127','V128','V129','V130','V131','V132','V133'], axis = 1)

# Maybe next time just read the hint... because this was much easier
df2 = df1.dropna(axis = 'columns', how = 'all')

# Check Shape
#print(df2.shape)

#######################################   END STUDENT CODE   #####################################################
assert df2.shape == (92, 125)

# %%
##################################################################################################################
#
# YouDo:
# 
#    1) Generate boxplots of Tryptophan levels separated based on 
#        the "Label" value
#
#      Use whatever plotting library you like.   
#      Hint 1: matplotlib has a boxplot tool
#          help(plt.boxplot)
#      Hint 2: pandas data frames have a built-in boxplot tool
#          help(df.boxplot)
#
#######################################  BEGIN STUDENT CODE  #####################################################
# creat a boxplot
plt.figure()
sns.boxplot(x="Label", y="Tryptophan", data=df2)
plt.title("Tryptophan levels by Label")
plt.xlabel("Label")
plt.ylabel("Tryptophan levels")
plt.suptitle('')
plt.show()

#######################################   END STUDENT CODE   #####################################################
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##################################################################################################################
#
# YouDo:
# Make a pair of plots as follows:
#    1) Show the correlation matrix between columns of the data
#        (hint 1: it should be 124x124, hint 2: check out plt.imshow() 
#         Hint 2: numpy has a function for generating the correlation matrix)
#
#    2) Make a similar plot showing correlation > 90%
#
#  Stretch goal:  using plt.subplot()  make a single figure with both plots side-by-side
#
#######################################  BEGIN STUDENT CODE  #####################################################
# Data Cleaning
## Get rid of NA text
### https://stackoverflow.com/questions/60998451/python-treating-the-string-na-as-null-or-nan-to-do-fillna
df3 = df2.replace('NA', np.nan)

## Change everything to a float since some columns are saved as strings
df3 = df3.astype(float)

## Calculate correlation matrix
df3_corr = df3.corr()

## filter to correlations > .90
### absolute values since -1 to 1
df3_high = np.abs(df3_corr) > 0.9
#print(df3_corr)
#print(df3_high)



# Figure 1
## Coding help from Gemini
plt.figure()
plt.imshow(df3_corr)
#sns.heatmap(df3_corr, annot=True)
#plt.colorbar()
#plt.xticks(range(len(df3.columns)), df3.columns, rotation=45)
#plt.yticks(range(len(df3.columns)), df3.columns)
plt.title("Correlation Matrix")
plt.show()

# Figure 2
## Coding help from Gemini
plt.figure()
plt.imshow(df3_high)
#plt.colorbar()
#plt.xticks(range(len(df3.columns)), df3.columns, rotation=45)
#plt.yticks(range(len(df3.columns)), df3.columns)
plt.title("Correlation > 90%")
plt.show()
#######################################   END STUDENT CODE   #####################################################
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
##################################################################################################################
#
# YouDo:
#  1) Remove any rows with na values
# 
#  2) Split the data into "test" and "train" bits with ~30% in the test set.
#       The "Label" column is the "y" data.  All other columns are the "X" data
#       Give them these names:
#       X_train, X_test, y_train, y_test

#######################################  BEGIN STUDENT CODE  #####################################################

# 1) Already Did this to get the correlation matrix
# Data Cleaning
## Get rid of NaN rows
df4 = df3.dropna(axis = 'rows', how = 'any')

#2) Help from Gemini
# Split data into features and target
X = df4.drop('Label', axis=1)
y = df4['Label']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print the shapes of the split data
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
#######################################   END STUDENT CODE   #####################################################
# Out:
# X_train shape: (53, 124)
# X_test shape: (24, 124)
# y_train shape: (53,)
# y_test shape: (24,)

# %%
#Build a model to classify the Label based on the other columns

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=8675309)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=8675309)

# %%
# Test the model
predictions = clf.predict(X_test)
reality = y_test

# %%
# YouDo:
#  1) Evaluate the "goodness" of the predictions and write a paragraph describing the results as a markdown.
#
#######################################  BEGIN STUDENT CODE  #####################################################
# Calculate accuracy
accuracy = accuracy_score(reality, predictions)

# Calculate precision
precision = precision_score(reality, predictions)

# Calculate recall
recall = recall_score(reality, predictions)

# Calculate F1-score
f1 = f1_score(reality, predictions)

# Calculate AUC-ROC
auc = roc_auc_score(reality, predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc)
#######################################   END STUDENT CODE   #####################################################
# Out:
# Accuracy: 0.9583333333333334
# Precision: 1.0
# Recall: 0.9333333333333333
# F1-score: 0.9655172413793104
# AUC-ROC: 0.9666666666666667

# %% [markdown]
# # Analysis
# Not knowing anything about the data:
# Using all the columns is a good indicator of correctingly labeling the outcome, Label. Using a general rule of thumb of having a AUC-ROC of >0.9 means the model most likely performed very well. This is hard to verify not having domain knowledge, and an expert biostatistican with this knowledge is needed for further verification. Also the ROC drastically changes when I try different Random Seeds; so this output may be pure luck..
#
# In addition, more exploration should be done to make sure the model is performing well without overfitting.
